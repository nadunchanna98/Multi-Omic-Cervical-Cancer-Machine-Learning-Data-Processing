# %%
import pandas as pd

# %%
file_path = "G:/academic/sem 7/Research - Multi-omic data in the cervical cancer studies/notebooks/methilation/200_features_methilation450K.csv" 
df = pd.read_csv(file_path)

# %%
df.drop(df.columns[0], axis=1, inplace=True)
df
# Out:
#                   id  histological_type  cg26961332  cg01847620  cg01814098  \
# 0    TCGA-EK-A3GK-01                  1      0.9904      0.9860      0.0247
# 1    TCGA-GH-A9DA-01                  0      0.9910      0.9909      0.0150
# 2    TCGA-VS-A94Y-01                  0      0.9883      0.9424      0.0174
# 3    TCGA-MY-A5BF-11                  0      0.9901      0.9858      0.0174
# 4    TCGA-VS-A94Z-01                  0      0.8803      0.6852      0.0172
# ..               ...                ...         ...         ...         ...
# 300  TCGA-C5-A1MF-01                  0      0.9870      0.9878      0.0217
# 301  TCGA-C5-A1BF-01                  0      0.9801      0.9022      0.0208
# 302  TCGA-C5-A1BK-01                  0      0.9879      0.6833      0.1408
# 303  TCGA-C5-A1BI-01                  0      0.9434      0.9259      0.0244
# 304  TCGA-C5-A1M9-01                  1      0.9896      0.9833      0.0207
#
#      cg17812026  cg25800170  cg13682477  cg23889391  cg26082557  ...  \
# 0        0.9570      0.0166      0.0166      0.0158      0.0160  ...
# 1        0.9914      0.0139      0.0172      0.6539      0.0113  ...
# 2        0.9776      0.2976      0.6157      0.0132      0.0454  ...
# 3        0.9898      0.0137      0.0211      0.0169      0.0147  ...
# 4        0.5670      0.2188      0.5187      0.4858      0.4888  ...
# ..          ...         ...         ...         ...         ...  ...
# 300      0.7349      0.0180      0.0252      0.0168      0.6354  ...
# 301      0.9823      0.0190      0.0239      0.0146      0.0140  ...
# 302      0.8738      0.0223      0.4855      0.1336      0.5528  ...
# 303      0.7724      0.2028      0.0350      0.4781      0.0268  ...
# 304      0.9896      0.0278      0.0202      0.0149      0.0159  ...
#
#      cg08643007  cg08367083  cg00810836  cg04087237  cg25379026  cg08839858  \
# 0        0.0317      0.0183      0.0621      0.0652      0.0122      0.0224
# 1        0.0377      0.0147      0.0170      0.0191      0.0162      0.6017
# 2        0.0257      0.0224      0.0190      0.0687      0.4693      0.5097
# 3        0.0208      0.0264      0.0267      0.0112      0.0208      0.0193
# 4        0.0282      0.2056      0.0174      0.0142      0.5561      0.4190
# ..          ...         ...         ...         ...         ...         ...
# 300      0.0292      0.0340      0.0227      0.0179      0.3376      0.0217
# 301      0.0362      0.0259      0.0416      0.0232      0.0197      0.5360
# 302      0.0244      0.0297      0.0349      0.1042      0.0997      0.2280
# 303      0.0463      0.0372      0.1238      0.0198      0.5899      0.3088
# 304      0.0285      0.0168      0.0329      0.3369      0.0174      0.0167
#
#      cg15794252  cg09806118  cg04020999  cg06960784
# 0        0.0124      0.0120      0.9778      0.0128
# 1        0.0623      0.4581      0.9914      0.3205
# 2        0.0144      0.0115      0.9845      0.0163
# 3        0.0158      0.0144      0.9860      0.0212
# 4        0.0168      0.0121      0.9844      0.0603
# ..          ...         ...         ...         ...
# 300      0.0150      0.0149      0.9810      0.0186
# 301      0.0134      0.4100      0.9786      0.0184
# 302      0.2108      0.3921      0.9809      0.5083
# 303      0.2795      0.0145      0.9673      0.0293
# 304      0.0177      0.0143      0.9846      0.3213
#
# [305 rows x 202 columns]

# %%
column_values = df['histological_type']
total_count = column_values.count()
value_counts = column_values.value_counts()
value_counts
# Out:
# histological_type
# 0    257
# 1     48
# Name: count, dtype: int64

# %%
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier  # Import XGBoost
from sklearn.feature_selection import RFE
from sklearn.model_selection import cross_val_score
from sklearn.utils import resample
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Assuming df is your DataFrame

xgb_classifier = XGBClassifier(objective='binary:logistic', random_state=42)  # Use binary:logistic for binary classification
K = np.arange(start=5, stop=90, step=5)
iterations = 10  # Number of iterations
feature_numbers = []
mean_accuracies = []

# Loop through the selected features
for idx, k in enumerate(K):
    accuracies_iter = []

    for iteration in range(iterations):
        # Feature selection using RFE
        X = df.iloc[:, 2:202]
        y = df["histological_type"]

        selector = RFE(xgb_classifier, n_features_to_select=k)
        X_selected = selector.fit_transform(X, y)
        selected_features = X.columns[selector.support_]

        df_selected = df[['id', 'histological_type'] + list(selected_features)].copy()

        # Undersample the dataset with a random seed between 0 and 100 for each iteration
        undersample_seed = np.random.randint(101)  # Generate a random seed between 0 and 100
        cervical_squamous_df = df_selected[df_selected['histological_type'] == 0]
        if len(cervical_squamous_df) > 48:
            cervical_squamous_df = resample(cervical_squamous_df, n_samples=48, random_state=undersample_seed)
        adeno_df = df_selected[df_selected['histological_type'] == 1]
        df2 = pd.concat([cervical_squamous_df, adeno_df])

        # Split the data into features (X) and target (y)
        X_selected = df2.iloc[:, 2:]
        y_selected = df2["histological_type"]

        # Perform 5-fold cross-validation
        scores = cross_val_score(xgb_classifier, X_selected, y_selected, cv=5, scoring='accuracy')

        # Calculate average accuracy across folds
        accuracy = np.mean(scores)
        accuracies_iter.append(accuracy)

        # Print update after each iteration
        print(f"Iteration {iteration + 1}/{iterations} for k={k}: Accuracy = {accuracy:.4f}, Undersample Seed = {undersample_seed}")

    # Store the feature number and its mean accuracy across iterations
    feature_numbers.append(k)
    mean_accuracies.append(np.mean(accuracies_iter))

    # Print update after each feature number
    print(f"Finished iteration for k={k}: Mean Accuracy = {mean_accuracies[-1]:.4f}\n")

# Plotting the feature numbers and their corresponding mean accuracies
plt.figure(figsize=(10, 6))
plt.plot(feature_numbers, mean_accuracies, marker='o', linestyle='-')

# Annotate each point with its accuracy
for i in range(len(feature_numbers)):
    plt.text(feature_numbers[i], mean_accuracies[i], f'{mean_accuracies[i]:.4f}', fontsize=8, ha='right', va='bottom')

plt.title('Mean Accuracy for each Feature Number (RFE + Undersampling + XGBoost with 5-Fold Cross-Validation)')
plt.xlabel('Number of Features')
plt.ylabel('Mean Accuracy')
plt.grid(True)
plt.show()
# Out:
# Iteration 1/10 for k=5: Accuracy = 0.8753, Undersample Seed = 6
# Iteration 2/10 for k=5: Accuracy = 0.8226, Undersample Seed = 5
# Iteration 3/10 for k=5: Accuracy = 0.8647, Undersample Seed = 37
# Iteration 4/10 for k=5: Accuracy = 0.8747, Undersample Seed = 24
# Iteration 5/10 for k=5: Accuracy = 0.8642, Undersample Seed = 49
# Iteration 6/10 for k=5: Accuracy = 0.8426, Undersample Seed = 41
# Iteration 7/10 for k=5: Accuracy = 0.8226, Undersample Seed = 75
# Iteration 8/10 for k=5: Accuracy = 0.8532, Undersample Seed = 86
# Iteration 9/10 for k=5: Accuracy = 0.8753, Undersample Seed = 87
# Iteration 10/10 for k=5: Accuracy = 0.8432, Undersample Seed = 23
# Finished iteration for k=5: Mean Accuracy = 0.8538
#
# Iteration 1/10 for k=10: Accuracy = 0.8858, Undersample Seed = 34
# Iteration 2/10 for k=10: Accuracy = 0.8642, Undersample Seed = 24
# Iteration 3/10 for k=10: Accuracy = 0.8316, Undersample Seed = 25
# Iteration 4/10 for k=10: Accuracy = 0.8537, Undersample Seed = 22
# Iteration 5/10 for k=10: Accuracy = 0.8858, Undersample Seed = 5
# Iteration 6/10 for k=10: Accuracy = 0.8858, Undersample Seed = 34
# Iteration 7/10 for k=10: Accuracy = 0.8547, Undersample Seed = 18
# Iteration 8/10 for k=10: Accuracy = 0.8426, Undersample Seed = 93
# Iteration 9/10 for k=10: Accuracy = 0.8647, Undersample Seed = 65
# Iteration 10/10 for k=10: Accuracy = 0.8316, Undersample Seed = 25
# Finished iteration for k=10: Mean Accuracy = 0.8601
#
# Iteration 1/10 for k=15: Accuracy = 0.9058, Undersample Seed = 83
# Iteration 2/10 for k=15: Accuracy = 0.8232, Undersample Seed = 16
# Iteration 3/10 for k=15: Accuracy = 0.8532, Undersample Seed = 31
# Iteration 4/10 for k=15: Accuracy = 0.8963, Undersample Seed = 27
# Iteration 5/10 for k=15: Accuracy = 0.8221, Undersample Seed = 55
# Iteration 6/10 for k=15: Accuracy = 0.8537, Undersample Seed = 77
# Iteration 7/10 for k=15: Accuracy = 0.8532, Undersample Seed = 31
# Iteration 8/10 for k=15: Accuracy = 0.8437, Undersample Seed = 17
# Iteration 9/10 for k=15: Accuracy = 0.8537, Undersample Seed = 77
# Iteration 10/10 for k=15: Accuracy = 0.8437, Undersample Seed = 17
# Finished iteration for k=15: Mean Accuracy = 0.8548
#
# Iteration 1/10 for k=20: Accuracy = 0.8958, Undersample Seed = 39
# Iteration 2/10 for k=20: Accuracy = 0.8747, Undersample Seed = 100
# Iteration 3/10 for k=20: Accuracy = 0.8332, Undersample Seed = 25
# Iteration 4/10 for k=20: Accuracy = 0.9068, Undersample Seed = 40
# Iteration 5/10 for k=20: Accuracy = 0.8753, Undersample Seed = 96
# Iteration 6/10 for k=20: Accuracy = 0.8747, Undersample Seed = 37
# Iteration 7/10 for k=20: Accuracy = 0.8753, Undersample Seed = 3
# Iteration 8/10 for k=20: Accuracy = 0.8111, Undersample Seed = 93
# Iteration 9/10 for k=20: Accuracy = 0.8953, Undersample Seed = 63
# Iteration 10/10 for k=20: Accuracy = 0.9068, Undersample Seed = 32
# Finished iteration for k=20: Mean Accuracy = 0.8749
#
# Iteration 1/10 for k=25: Accuracy = 0.8542, Undersample Seed = 65
# Iteration 2/10 for k=25: Accuracy = 0.8337, Undersample Seed = 30
# Iteration 3/10 for k=25: Accuracy = 0.9168, Undersample Seed = 20
# Iteration 4/10 for k=25: Accuracy = 0.9163, Undersample Seed = 76
# Iteration 5/10 for k=25: Accuracy = 0.9063, Undersample Seed = 49
# Iteration 6/10 for k=25: Accuracy = 0.8121, Undersample Seed = 9
# Iteration 7/10 for k=25: Accuracy = 0.8747, Undersample Seed = 69
# Iteration 8/10 for k=25: Accuracy = 0.8642, Undersample Seed = 38
# Iteration 9/10 for k=25: Accuracy = 0.8121, Undersample Seed = 9
# Iteration 10/10 for k=25: Accuracy = 0.8321, Undersample Seed = 41
# Finished iteration for k=25: Mean Accuracy = 0.8623
#
# Iteration 1/10 for k=30: Accuracy = 0.8542, Undersample Seed = 37
# Iteration 2/10 for k=30: Accuracy = 0.9068, Undersample Seed = 1
# Iteration 3/10 for k=30: Accuracy = 0.8747, Undersample Seed = 85
# Iteration 4/10 for k=30: Accuracy = 0.8642, Undersample Seed = 33
# Iteration 5/10 for k=30: Accuracy = 0.8953, Undersample Seed = 23
# Iteration 6/10 for k=30: Accuracy = 0.9268, Undersample Seed = 56
# Iteration 7/10 for k=30: Accuracy = 0.8963, Undersample Seed = 70
# Iteration 8/10 for k=30: Accuracy = 0.8642, Undersample Seed = 22
# Iteration 9/10 for k=30: Accuracy = 0.9058, Undersample Seed = 99
# Iteration 10/10 for k=30: Accuracy = 0.8632, Undersample Seed = 82
# Finished iteration for k=30: Mean Accuracy = 0.8852
#
# Iteration 1/10 for k=35: Accuracy = 0.8637, Undersample Seed = 19
# Iteration 2/10 for k=35: Accuracy = 0.8011, Undersample Seed = 10
# Iteration 3/10 for k=35: Accuracy = 0.8947, Undersample Seed = 79
# Iteration 4/10 for k=35: Accuracy = 0.8847, Undersample Seed = 5
# Iteration 5/10 for k=35: Accuracy = 0.8426, Undersample Seed = 11
# Iteration 6/10 for k=35: Accuracy = 0.8842, Undersample Seed = 99
# Iteration 7/10 for k=35: Accuracy = 0.8637, Undersample Seed = 84
# Iteration 8/10 for k=35: Accuracy = 0.8221, Undersample Seed = 93
# Iteration 9/10 for k=35: Accuracy = 0.9158, Undersample Seed = 94
# Iteration 10/10 for k=35: Accuracy = 0.8853, Undersample Seed = 37
# Finished iteration for k=35: Mean Accuracy = 0.8658
#
# Iteration 1/10 for k=40: Accuracy = 0.8858, Undersample Seed = 46
# Iteration 2/10 for k=40: Accuracy = 0.8326, Undersample Seed = 24
# Iteration 3/10 for k=40: Accuracy = 0.8847, Undersample Seed = 23
# Iteration 4/10 for k=40: Accuracy = 0.8647, Undersample Seed = 87
# Iteration 5/10 for k=40: Accuracy = 0.8647, Undersample Seed = 45
# Iteration 6/10 for k=40: Accuracy = 0.9053, Undersample Seed = 21
# Iteration 7/10 for k=40: Accuracy = 0.8958, Undersample Seed = 37
# Iteration 8/10 for k=40: Accuracy = 0.8747, Undersample Seed = 98
# Iteration 9/10 for k=40: Accuracy = 0.9053, Undersample Seed = 63
# Iteration 10/10 for k=40: Accuracy = 0.9268, Undersample Seed = 89
# Finished iteration for k=40: Mean Accuracy = 0.8841
#
# Iteration 1/10 for k=45: Accuracy = 0.9374, Undersample Seed = 94
# Iteration 2/10 for k=45: Accuracy = 0.8758, Undersample Seed = 36
# Iteration 3/10 for k=45: Accuracy = 0.8963, Undersample Seed = 40
# Iteration 4/10 for k=45: Accuracy = 0.8126, Undersample Seed = 16
# Iteration 5/10 for k=45: Accuracy = 0.9168, Undersample Seed = 1
# Iteration 6/10 for k=45: Accuracy = 0.8853, Undersample Seed = 5
# Iteration 7/10 for k=45: Accuracy = 0.8537, Undersample Seed = 58
# Iteration 8/10 for k=45: Accuracy = 0.8637, Undersample Seed = 24
# Iteration 9/10 for k=45: Accuracy = 0.9058, Undersample Seed = 21
# Iteration 10/10 for k=45: Accuracy = 0.9374, Undersample Seed = 13
# Finished iteration for k=45: Mean Accuracy = 0.8885
#
# Iteration 1/10 for k=50: Accuracy = 0.9058, Undersample Seed = 86
# Iteration 2/10 for k=50: Accuracy = 0.8853, Undersample Seed = 15
# Iteration 3/10 for k=50: Accuracy = 0.8537, Undersample Seed = 24
# Iteration 4/10 for k=50: Accuracy = 0.8226, Undersample Seed = 14
# Iteration 5/10 for k=50: Accuracy = 0.8432, Undersample Seed = 58
# Iteration 6/10 for k=50: Accuracy = 0.8421, Undersample Seed = 11
# Iteration 7/10 for k=50: Accuracy = 0.8947, Undersample Seed = 19
# Iteration 8/10 for k=50: Accuracy = 0.8337, Undersample Seed = 16
# Iteration 9/10 for k=50: Accuracy = 0.8221, Undersample Seed = 52
# Iteration 10/10 for k=50: Accuracy = 0.8442, Undersample Seed = 54
# Finished iteration for k=50: Mean Accuracy = 0.8547
#
# Iteration 1/10 for k=55: Accuracy = 0.8958, Undersample Seed = 8
# Iteration 2/10 for k=55: Accuracy = 0.8853, Undersample Seed = 81
# Iteration 3/10 for k=55: Accuracy = 0.8332, Undersample Seed = 91
# Iteration 4/10 for k=55: Accuracy = 0.8226, Undersample Seed = 35
# Iteration 5/10 for k=55: Accuracy = 0.8537, Undersample Seed = 17
# Iteration 6/10 for k=55: Accuracy = 0.8537, Undersample Seed = 83
# Iteration 7/10 for k=55: Accuracy = 0.8332, Undersample Seed = 69
# Iteration 8/10 for k=55: Accuracy = 0.8537, Undersample Seed = 17
# Iteration 9/10 for k=55: Accuracy = 0.8947, Undersample Seed = 28
# Iteration 10/10 for k=55: Accuracy = 0.8747, Undersample Seed = 15
# Finished iteration for k=55: Mean Accuracy = 0.8601
#
# Iteration 1/10 for k=60: Accuracy = 0.8847, Undersample Seed = 67
# Iteration 2/10 for k=60: Accuracy = 0.8847, Undersample Seed = 57
# Iteration 3/10 for k=60: Accuracy = 0.9168, Undersample Seed = 89
# Iteration 4/10 for k=60: Accuracy = 0.7905, Undersample Seed = 64
# Iteration 5/10 for k=60: Accuracy = 0.9374, Undersample Seed = 13
# Iteration 6/10 for k=60: Accuracy = 0.8758, Undersample Seed = 48
# Iteration 7/10 for k=60: Accuracy = 0.8537, Undersample Seed = 19
# Iteration 8/10 for k=60: Accuracy = 0.8653, Undersample Seed = 54
# Iteration 9/10 for k=60: Accuracy = 0.8432, Undersample Seed = 52
# Iteration 10/10 for k=60: Accuracy = 0.8653, Undersample Seed = 54
# Finished iteration for k=60: Mean Accuracy = 0.8717
#
# Iteration 1/10 for k=65: Accuracy = 0.8126, Undersample Seed = 35
# Iteration 2/10 for k=65: Accuracy = 0.9174, Undersample Seed = 92
# Iteration 3/10 for k=65: Accuracy = 0.8653, Undersample Seed = 54
# Iteration 4/10 for k=65: Accuracy = 0.8337, Undersample Seed = 24
# Iteration 5/10 for k=65: Accuracy = 0.8653, Undersample Seed = 54
# Iteration 6/10 for k=65: Accuracy = 0.8958, Undersample Seed = 74
# Iteration 7/10 for k=65: Accuracy = 0.8116, Undersample Seed = 38
# Iteration 8/10 for k=65: Accuracy = 0.8958, Undersample Seed = 81
# Iteration 9/10 for k=65: Accuracy = 0.8121, Undersample Seed = 93
# Iteration 10/10 for k=65: Accuracy = 0.8532, Undersample Seed = 80
# Finished iteration for k=65: Mean Accuracy = 0.8563
#
# Iteration 1/10 for k=70: Accuracy = 0.9053, Undersample Seed = 100
# Iteration 2/10 for k=70: Accuracy = 0.8853, Undersample Seed = 61
# Iteration 3/10 for k=70: Accuracy = 0.9058, Undersample Seed = 94
# Iteration 4/10 for k=70: Accuracy = 0.9168, Undersample Seed = 20
# Iteration 5/10 for k=70: Accuracy = 0.7905, Undersample Seed = 64
# Iteration 6/10 for k=70: Accuracy = 0.8958, Undersample Seed = 63
# Iteration 7/10 for k=70: Accuracy = 0.9074, Undersample Seed = 50
# Iteration 8/10 for k=70: Accuracy = 0.8532, Undersample Seed = 77
# Iteration 9/10 for k=70: Accuracy = 0.8842, Undersample Seed = 26
# Iteration 10/10 for k=70: Accuracy = 0.7905, Undersample Seed = 64
# Finished iteration for k=70: Mean Accuracy = 0.8735
#
# Iteration 1/10 for k=75: Accuracy = 0.8758, Undersample Seed = 36
# Iteration 2/10 for k=75: Accuracy = 0.8853, Undersample Seed = 61
# Iteration 3/10 for k=75: Accuracy = 0.8963, Undersample Seed = 18
# Iteration 4/10 for k=75: Accuracy = 0.8742, Undersample Seed = 23
# Iteration 5/10 for k=75: Accuracy = 0.8121, Undersample Seed = 93
# Iteration 6/10 for k=75: Accuracy = 0.8647, Undersample Seed = 65
# Iteration 7/10 for k=75: Accuracy = 0.8747, Undersample Seed = 74
# Iteration 8/10 for k=75: Accuracy = 0.8537, Undersample Seed = 47
# Iteration 9/10 for k=75: Accuracy = 0.8847, Undersample Seed = 79
# Iteration 10/10 for k=75: Accuracy = 0.8853, Undersample Seed = 85
# Finished iteration for k=75: Mean Accuracy = 0.8707
#
# Iteration 1/10 for k=80: Accuracy = 0.8653, Undersample Seed = 43
# Iteration 2/10 for k=80: Accuracy = 0.8642, Undersample Seed = 2
# Iteration 3/10 for k=80: Accuracy = 0.9168, Undersample Seed = 98
# Iteration 4/10 for k=80: Accuracy = 0.8326, Undersample Seed = 51
# Iteration 5/10 for k=80: Accuracy = 0.8232, Undersample Seed = 24
# Iteration 6/10 for k=80: Accuracy = 0.8232, Undersample Seed = 24
# Iteration 7/10 for k=80: Accuracy = 0.8116, Undersample Seed = 64
# Iteration 8/10 for k=80: Accuracy = 0.8958, Undersample Seed = 49
# Iteration 9/10 for k=80: Accuracy = 0.8963, Undersample Seed = 46
# Iteration 10/10 for k=80: Accuracy = 0.8653, Undersample Seed = 0
# Finished iteration for k=80: Mean Accuracy = 0.8594
#
# Iteration 1/10 for k=85: Accuracy = 0.8637, Undersample Seed = 99
# Iteration 2/10 for k=85: Accuracy = 0.8437, Undersample Seed = 58
# Iteration 3/10 for k=85: Accuracy = 0.8853, Undersample Seed = 34
# Iteration 4/10 for k=85: Accuracy = 0.8863, Undersample Seed = 40
# Iteration 5/10 for k=85: Accuracy = 0.9374, Undersample Seed = 13
# Iteration 6/10 for k=85: Accuracy = 0.8637, Undersample Seed = 79
# Iteration 7/10 for k=85: Accuracy = 0.8432, Undersample Seed = 83
# Iteration 8/10 for k=85: Accuracy = 0.8011, Undersample Seed = 51
# Iteration 9/10 for k=85: Accuracy = 0.8753, Undersample Seed = 0
# Iteration 10/10 for k=85: Accuracy = 0.9274, Undersample Seed = 32
# Finished iteration for k=85: Mean Accuracy = 0.8727
