# %%
import pandas as pd

# %%
file_path = "G:/academic/sem 7/Research - Multi-omic data in the cervical cancer studies/notebooks/New folder/methilation\Feature_selection_method_1/200_features_methilation450K.csv" 
df = pd.read_csv(file_path)

# %%
df.drop(df.columns[0], axis=1, inplace=True)
df
# Out:
#                   id  histological_type  cg26961332  cg01847620  cg01814098  \
# 0    TCGA-EK-A3GK-01                  1      0.9904      0.9860      0.0247
# 1    TCGA-GH-A9DA-01                  0      0.9910      0.9909      0.0150
# 2    TCGA-VS-A94Y-01                  0      0.9883      0.9424      0.0174
# 3    TCGA-MY-A5BF-11                  0      0.9901      0.9858      0.0174
# 4    TCGA-VS-A94Z-01                  0      0.8803      0.6852      0.0172
# ..               ...                ...         ...         ...         ...
# 300  TCGA-C5-A1MF-01                  0      0.9870      0.9878      0.0217
# 301  TCGA-C5-A1BF-01                  0      0.9801      0.9022      0.0208
# 302  TCGA-C5-A1BK-01                  0      0.9879      0.6833      0.1408
# 303  TCGA-C5-A1BI-01                  0      0.9434      0.9259      0.0244
# 304  TCGA-C5-A1M9-01                  1      0.9896      0.9833      0.0207
#
#      cg17812026  cg25800170  cg13682477  cg23889391  cg26082557  ...  \
# 0        0.9570      0.0166      0.0166      0.0158      0.0160  ...
# 1        0.9914      0.0139      0.0172      0.6539      0.0113  ...
# 2        0.9776      0.2976      0.6157      0.0132      0.0454  ...
# 3        0.9898      0.0137      0.0211      0.0169      0.0147  ...
# 4        0.5670      0.2188      0.5187      0.4858      0.4888  ...
# ..          ...         ...         ...         ...         ...  ...
# 300      0.7349      0.0180      0.0252      0.0168      0.6354  ...
# 301      0.9823      0.0190      0.0239      0.0146      0.0140  ...
# 302      0.8738      0.0223      0.4855      0.1336      0.5528  ...
# 303      0.7724      0.2028      0.0350      0.4781      0.0268  ...
# 304      0.9896      0.0278      0.0202      0.0149      0.0159  ...
#
#      cg08643007  cg08367083  cg00810836  cg04087237  cg25379026  cg08839858  \
# 0        0.0317      0.0183      0.0621      0.0652      0.0122      0.0224
# 1        0.0377      0.0147      0.0170      0.0191      0.0162      0.6017
# 2        0.0257      0.0224      0.0190      0.0687      0.4693      0.5097
# 3        0.0208      0.0264      0.0267      0.0112      0.0208      0.0193
# 4        0.0282      0.2056      0.0174      0.0142      0.5561      0.4190
# ..          ...         ...         ...         ...         ...         ...
# 300      0.0292      0.0340      0.0227      0.0179      0.3376      0.0217
# 301      0.0362      0.0259      0.0416      0.0232      0.0197      0.5360
# 302      0.0244      0.0297      0.0349      0.1042      0.0997      0.2280
# 303      0.0463      0.0372      0.1238      0.0198      0.5899      0.3088
# 304      0.0285      0.0168      0.0329      0.3369      0.0174      0.0167
#
#      cg15794252  cg09806118  cg04020999  cg06960784
# 0        0.0124      0.0120      0.9778      0.0128
# 1        0.0623      0.4581      0.9914      0.3205
# 2        0.0144      0.0115      0.9845      0.0163
# 3        0.0158      0.0144      0.9860      0.0212
# 4        0.0168      0.0121      0.9844      0.0603
# ..          ...         ...         ...         ...
# 300      0.0150      0.0149      0.9810      0.0186
# 301      0.0134      0.4100      0.9786      0.0184
# 302      0.2108      0.3921      0.9809      0.5083
# 303      0.2795      0.0145      0.9673      0.0293
# 304      0.0177      0.0143      0.9846      0.3213
#
# [305 rows x 202 columns]

# %%
column_values = df['histological_type']
total_count = column_values.count()
value_counts = column_values.value_counts()
value_counts
# Out:
# histological_type
# 0    257
# 1     48
# Name: count, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_selection import chi2
from sklearn.model_selection import cross_val_score
from sklearn.utils import resample
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Assuming df is your DataFrame

knn_classifier = KNeighborsClassifier()  # Use KNN
K = np.arange(start=5, stop=90, step=5)
iterations = 10  # Number of iterations
feature_numbers = []
mean_accuracies = []
std_accuracies = []

# Loop through the selected features
for idx, k in enumerate(K):
    accuracies_iter = []

    for iteration in range(iterations):
        # Feature selection using Chi-squared
        X = df.iloc[:, 2:202]
        y = df["histological_type"]

        # Calculate chi-squared scores for each feature
        chi2_scores, _ = chi2(X, y)

        # Select the top k features based on chi-squared scores
        selected_features_idx = np.argsort(chi2_scores)[-k:]
        selected_features = X.columns[selected_features_idx]

        df_selected = df[['id', 'histological_type'] + list(selected_features)].copy()

        # Undersample the dataset with a random seed between 0 and 100 for each iteration
        undersample_seed = np.random.randint(101)  # Generate a random seed between 0 and 100
        cervical_squamous_df = df_selected[df_selected['histological_type'] == 0]
        if len(cervical_squamous_df) > 48:
            cervical_squamous_df = resample(cervical_squamous_df, n_samples=48, random_state=undersample_seed)
        adeno_df = df_selected[df_selected['histological_type'] == 1]
        df2 = pd.concat([cervical_squamous_df, adeno_df])

        # Split the data into features (X) and target (y)
        X_selected = df2.iloc[:, 2:]
        y_selected = df2["histological_type"]

        # Perform 5-fold cross-validation
        scores = cross_val_score(knn_classifier, X_selected, y_selected, cv=5, scoring='accuracy')

        # Calculate average accuracy and standard deviation across folds
        accuracy = np.mean(scores)
        std_accuracy = np.std(scores)
        accuracies_iter.append(accuracy)

        # Print update after each iteration
        print(f"Iteration {iteration + 1}/{iterations} for k={k}: Accuracy = {accuracy:.4f}, Std Dev = {std_accuracy:.4f}, Undersample Seed = {undersample_seed}")

    # Store the feature number and its mean accuracy and standard deviation across iterations
    feature_numbers.append(k)
    mean_accuracies.append(np.mean(accuracies_iter))
    std_accuracies.append(np.std(accuracies_iter))

    # Print update after each feature number
    print(f"Finished iteration for k={k}: Mean Accuracy = {mean_accuracies[-1]:.4f}, Mean Std Dev = {std_accuracies[-1]:.4f}\n")

# Increase the width and height of the graph
plt.figure(figsize=(15, 8))

# Plotting the feature numbers, mean accuracies, and standard deviations
plt.errorbar(feature_numbers, mean_accuracies, yerr=std_accuracies, fmt='o-', label='Accuracy', capsize=5, markersize=8)

# Annotate each point with its accuracy and std inside a colored box
for i in range(len(feature_numbers)):
    box_properties = dict(boxstyle='round', facecolor='lightgray', alpha=0.7)
    plt.text(
        feature_numbers[i],
        mean_accuracies[i],
        f'{mean_accuracies[i]:.4f}\n±{std_accuracies[i]:.4f}',
        fontsize=8,
        ha='right',
        va='bottom',
        bbox=box_properties
    )

plt.title('Mean Accuracy with Std Dev for each Feature Number (Chi-squared + Undersampling + K-Nearest Neighbors with 5-Fold Cross-Validation)')
plt.xlabel('Number of Features')
plt.ylabel('Mean Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Iteration 1/10 for k=5: Accuracy = 0.7516, Std Dev = 0.0952, Undersample Seed = 34
# Iteration 2/10 for k=5: Accuracy = 0.7811, Std Dev = 0.0522, Undersample Seed = 91
# Iteration 3/10 for k=5: Accuracy = 0.7826, Std Dev = 0.0847, Undersample Seed = 71
# Iteration 4/10 for k=5: Accuracy = 0.7184, Std Dev = 0.0437, Undersample Seed = 95
# Iteration 5/10 for k=5: Accuracy = 0.8237, Std Dev = 0.1211, Undersample Seed = 72
# Iteration 6/10 for k=5: Accuracy = 0.7705, Std Dev = 0.0861, Undersample Seed = 81
# Iteration 7/10 for k=5: Accuracy = 0.7305, Std Dev = 0.1216, Undersample Seed = 86
# Iteration 8/10 for k=5: Accuracy = 0.8232, Std Dev = 0.1026, Undersample Seed = 7
# Iteration 9/10 for k=5: Accuracy = 0.8137, Std Dev = 0.0810, Undersample Seed = 90
# Iteration 10/10 for k=5: Accuracy = 0.7705, Std Dev = 0.0547, Undersample Seed = 80
# Finished iteration for k=5: Mean Accuracy = 0.7766, Mean Std Dev = 0.0347
#
# Iteration 1/10 for k=10: Accuracy = 0.8005, Std Dev = 0.0851, Undersample Seed = 51
# Iteration 2/10 for k=10: Accuracy = 0.8237, Std Dev = 0.0497, Undersample Seed = 38
# Iteration 3/10 for k=10: Accuracy = 0.8153, Std Dev = 0.1422, Undersample Seed = 20
# Iteration 4/10 for k=10: Accuracy = 0.8121, Std Dev = 0.0722, Undersample Seed = 65
# Iteration 5/10 for k=10: Accuracy = 0.8442, Std Dev = 0.0449, Undersample Seed = 12
# Iteration 6/10 for k=10: Accuracy = 0.8016, Std Dev = 0.0913, Undersample Seed = 44
# Iteration 7/10 for k=10: Accuracy = 0.8332, Std Dev = 0.0399, Undersample Seed = 4
# Iteration 8/10 for k=10: Accuracy = 0.7826, Std Dev = 0.0778, Undersample Seed = 69
# Iteration 9/10 for k=10: Accuracy = 0.7800, Std Dev = 0.0857, Undersample Seed = 33
# Iteration 10/10 for k=10: Accuracy = 0.7905, Std Dev = 0.0596, Undersample Seed = 56
# Finished iteration for k=10: Mean Accuracy = 0.8084, Mean Std Dev = 0.0202
#
# Iteration 1/10 for k=15: Accuracy = 0.7400, Std Dev = 0.0643, Undersample Seed = 58
# Iteration 2/10 for k=15: Accuracy = 0.7821, Std Dev = 0.0566, Undersample Seed = 28
# Iteration 3/10 for k=15: Accuracy = 0.7916, Std Dev = 0.1000, Undersample Seed = 72
# Iteration 4/10 for k=15: Accuracy = 0.8111, Std Dev = 0.0797, Undersample Seed = 31
# Iteration 5/10 for k=15: Accuracy = 0.8226, Std Dev = 0.0430, Undersample Seed = 8
# Iteration 6/10 for k=15: Accuracy = 0.8126, Std Dev = 0.0530, Undersample Seed = 38
# Iteration 7/10 for k=15: Accuracy = 0.8332, Std Dev = 0.0520, Undersample Seed = 95
# Iteration 8/10 for k=15: Accuracy = 0.7916, Std Dev = 0.0578, Undersample Seed = 27
# Iteration 9/10 for k=15: Accuracy = 0.8121, Std Dev = 0.0278, Undersample Seed = 4
# Iteration 10/10 for k=15: Accuracy = 0.7821, Std Dev = 0.0458, Undersample Seed = 47
# Finished iteration for k=15: Mean Accuracy = 0.7979, Mean Std Dev = 0.0253
#
# Iteration 1/10 for k=20: Accuracy = 0.7926, Std Dev = 0.0701, Undersample Seed = 69
# Iteration 2/10 for k=20: Accuracy = 0.8216, Std Dev = 0.0863, Undersample Seed = 21
# Iteration 3/10 for k=20: Accuracy = 0.8132, Std Dev = 0.0376, Undersample Seed = 83
# Iteration 4/10 for k=20: Accuracy = 0.8232, Std Dev = 0.0911, Undersample Seed = 80
# Iteration 5/10 for k=20: Accuracy = 0.7589, Std Dev = 0.0872, Undersample Seed = 77
# Iteration 6/10 for k=20: Accuracy = 0.8342, Std Dev = 0.0468, Undersample Seed = 47
# Iteration 7/10 for k=20: Accuracy = 0.7816, Std Dev = 0.0831, Undersample Seed = 99
# Iteration 8/10 for k=20: Accuracy = 0.8226, Std Dev = 0.0272, Undersample Seed = 52
# Iteration 9/10 for k=20: Accuracy = 0.8437, Std Dev = 0.0577, Undersample Seed = 61
# Iteration 10/10 for k=20: Accuracy = 0.7400, Std Dev = 0.0797, Undersample Seed = 35
# Finished iteration for k=20: Mean Accuracy = 0.8032, Mean Std Dev = 0.0322
#
# Iteration 1/10 for k=25: Accuracy = 0.8021, Std Dev = 0.0904, Undersample Seed = 15
# Iteration 2/10 for k=25: Accuracy = 0.8232, Std Dev = 0.0622, Undersample Seed = 36
# Iteration 3/10 for k=25: Accuracy = 0.8321, Std Dev = 0.0971, Undersample Seed = 21
# Iteration 4/10 for k=25: Accuracy = 0.8011, Std Dev = 0.1181, Undersample Seed = 2
# Iteration 5/10 for k=25: Accuracy = 0.8437, Std Dev = 0.0577, Undersample Seed = 89
# Iteration 6/10 for k=25: Accuracy = 0.7916, Std Dev = 0.1290, Undersample Seed = 48
# Iteration 7/10 for k=25: Accuracy = 0.8332, Std Dev = 0.0221, Undersample Seed = 52
# Iteration 8/10 for k=25: Accuracy = 0.8232, Std Dev = 0.0622, Undersample Seed = 36
# Iteration 9/10 for k=25: Accuracy = 0.8126, Std Dev = 0.0413, Undersample Seed = 91
# Iteration 10/10 for k=25: Accuracy = 0.8026, Std Dev = 0.0485, Undersample Seed = 24
# Finished iteration for k=25: Mean Accuracy = 0.8165, Mean Std Dev = 0.0162
#
# Iteration 1/10 for k=30: Accuracy = 0.7916, Std Dev = 0.0336, Undersample Seed = 44
# Iteration 2/10 for k=30: Accuracy = 0.8232, Std Dev = 0.0911, Undersample Seed = 72
# Iteration 3/10 for k=30: Accuracy = 0.7795, Std Dev = 0.1270, Undersample Seed = 31
# Iteration 4/10 for k=30: Accuracy = 0.7189, Std Dev = 0.0703, Undersample Seed = 64
# Iteration 5/10 for k=30: Accuracy = 0.8342, Std Dev = 0.0814, Undersample Seed = 60
# Iteration 6/10 for k=30: Accuracy = 0.8132, Std Dev = 0.1258, Undersample Seed = 53
# Iteration 7/10 for k=30: Accuracy = 0.8237, Std Dev = 0.0761, Undersample Seed = 34
# Iteration 8/10 for k=30: Accuracy = 0.7800, Std Dev = 0.0716, Undersample Seed = 66
# Iteration 9/10 for k=30: Accuracy = 0.8232, Std Dev = 0.0234, Undersample Seed = 0
# Iteration 10/10 for k=30: Accuracy = 0.8332, Std Dev = 0.0520, Undersample Seed = 26
# Finished iteration for k=30: Mean Accuracy = 0.8021, Mean Std Dev = 0.0339
#
# Iteration 1/10 for k=35: Accuracy = 0.8116, Std Dev = 0.0553, Undersample Seed = 56
# Iteration 2/10 for k=35: Accuracy = 0.7716, Std Dev = 0.1161, Undersample Seed = 2
# Iteration 3/10 for k=35: Accuracy = 0.8642, Std Dev = 0.0637, Undersample Seed = 39
# Iteration 4/10 for k=35: Accuracy = 0.7916, Std Dev = 0.1290, Undersample Seed = 48
# Iteration 5/10 for k=35: Accuracy = 0.7921, Std Dev = 0.0866, Undersample Seed = 34
# Iteration 6/10 for k=35: Accuracy = 0.8126, Std Dev = 0.0244, Undersample Seed = 10
# Iteration 7/10 for k=35: Accuracy = 0.8126, Std Dev = 0.0244, Undersample Seed = 10
# Iteration 8/10 for k=35: Accuracy = 0.8111, Std Dev = 0.1278, Undersample Seed = 31
# Iteration 9/10 for k=35: Accuracy = 0.7600, Std Dev = 0.0551, Undersample Seed = 91
# Iteration 10/10 for k=35: Accuracy = 0.8016, Std Dev = 0.0412, Undersample Seed = 89
# Finished iteration for k=35: Mean Accuracy = 0.8029, Mean Std Dev = 0.0268
#
# Iteration 1/10 for k=40: Accuracy = 0.7395, Std Dev = 0.0474, Undersample Seed = 14
# Iteration 2/10 for k=40: Accuracy = 0.8653, Std Dev = 0.0608, Undersample Seed = 78
# Iteration 3/10 for k=40: Accuracy = 0.7805, Std Dev = 0.0631, Undersample Seed = 73
# Iteration 4/10 for k=40: Accuracy = 0.8321, Std Dev = 0.0781, Undersample Seed = 62
# Iteration 5/10 for k=40: Accuracy = 0.8011, Std Dev = 0.0787, Undersample Seed = 77
# Iteration 6/10 for k=40: Accuracy = 0.7816, Std Dev = 0.1064, Undersample Seed = 92
# Iteration 7/10 for k=40: Accuracy = 0.8116, Std Dev = 0.0799, Undersample Seed = 49
# Iteration 8/10 for k=40: Accuracy = 0.7395, Std Dev = 0.0474, Undersample Seed = 14
# Iteration 9/10 for k=40: Accuracy = 0.7911, Std Dev = 0.0592, Undersample Seed = 45
# Iteration 10/10 for k=40: Accuracy = 0.7911, Std Dev = 0.0592, Undersample Seed = 45
# Finished iteration for k=40: Mean Accuracy = 0.7933, Mean Std Dev = 0.0363
#
# Iteration 1/10 for k=45: Accuracy = 0.7200, Std Dev = 0.0634, Undersample Seed = 18
# Iteration 2/10 for k=45: Accuracy = 0.7200, Std Dev = 0.0634, Undersample Seed = 18
# Iteration 3/10 for k=45: Accuracy = 0.8026, Std Dev = 0.0485, Undersample Seed = 6
# Iteration 4/10 for k=45: Accuracy = 0.7926, Std Dev = 0.0617, Undersample Seed = 30
# Iteration 5/10 for k=45: Accuracy = 0.7711, Std Dev = 0.0621, Undersample Seed = 92
# Iteration 6/10 for k=45: Accuracy = 0.7600, Std Dev = 0.0439, Undersample Seed = 14
# Iteration 7/10 for k=45: Accuracy = 0.8116, Std Dev = 0.0553, Undersample Seed = 87
# Iteration 8/10 for k=45: Accuracy = 0.8337, Std Dev = 0.0500, Undersample Seed = 23
# Iteration 9/10 for k=45: Accuracy = 0.8547, Std Dev = 0.0593, Undersample Seed = 78
# Iteration 10/10 for k=45: Accuracy = 0.8437, Std Dev = 0.0577, Undersample Seed = 39
# Finished iteration for k=45: Mean Accuracy = 0.7910, Mean Std Dev = 0.0455
#
# Iteration 1/10 for k=50: Accuracy = 0.7611, Std Dev = 0.0597, Undersample Seed = 36
# Iteration 2/10 for k=50: Accuracy = 0.7916, Std Dev = 0.0667, Undersample Seed = 55
# Iteration 3/10 for k=50: Accuracy = 0.8337, Std Dev = 0.0601, Undersample Seed = 39
# Iteration 4/10 for k=50: Accuracy = 0.8232, Std Dev = 0.0407, Undersample Seed = 94
# Iteration 5/10 for k=50: Accuracy = 0.7500, Std Dev = 0.1217, Undersample Seed = 7
# Iteration 6/10 for k=50: Accuracy = 0.7495, Std Dev = 0.1083, Undersample Seed = 48
# Iteration 7/10 for k=50: Accuracy = 0.8216, Std Dev = 0.0925, Undersample Seed = 62
# Iteration 8/10 for k=50: Accuracy = 0.6984, Std Dev = 0.0338, Undersample Seed = 27
# Iteration 9/10 for k=50: Accuracy = 0.8037, Std Dev = 0.0961, Undersample Seed = 63
# Iteration 10/10 for k=50: Accuracy = 0.7495, Std Dev = 0.1083, Undersample Seed = 48
# Finished iteration for k=50: Mean Accuracy = 0.7782, Mean Std Dev = 0.0411
#
# Iteration 1/10 for k=55: Accuracy = 0.7705, Std Dev = 0.0547, Undersample Seed = 0
# Iteration 2/10 for k=55: Accuracy = 0.8321, Std Dev = 0.1311, Undersample Seed = 67
# Iteration 3/10 for k=55: Accuracy = 0.7495, Std Dev = 0.1083, Undersample Seed = 48
# Iteration 4/10 for k=55: Accuracy = 0.8021, Std Dev = 0.0513, Undersample Seed = 6
# Iteration 5/10 for k=55: Accuracy = 0.7595, Std Dev = 0.0990, Undersample Seed = 21
# Iteration 6/10 for k=55: Accuracy = 0.7805, Std Dev = 0.0536, Undersample Seed = 79
# Iteration 7/10 for k=55: Accuracy = 0.7595, Std Dev = 0.0990, Undersample Seed = 21
# Iteration 8/10 for k=55: Accuracy = 0.7926, Std Dev = 0.0701, Undersample Seed = 30
# Iteration 9/10 for k=55: Accuracy = 0.7911, Std Dev = 0.0951, Undersample Seed = 37
# Iteration 10/10 for k=55: Accuracy = 0.7816, Std Dev = 0.0895, Undersample Seed = 29
# Finished iteration for k=55: Mean Accuracy = 0.7819, Mean Std Dev = 0.0231
#
# Iteration 1/10 for k=60: Accuracy = 0.8547, Std Dev = 0.0892, Undersample Seed = 12
# Iteration 2/10 for k=60: Accuracy = 0.7916, Std Dev = 0.0473, Undersample Seed = 91
# Iteration 3/10 for k=60: Accuracy = 0.7805, Std Dev = 0.0536, Undersample Seed = 73
# Iteration 4/10 for k=60: Accuracy = 0.7821, Std Dev = 0.0657, Undersample Seed = 43
# Iteration 5/10 for k=60: Accuracy = 0.7589, Std Dev = 0.1147, Undersample Seed = 93
# Iteration 6/10 for k=60: Accuracy = 0.7626, Std Dev = 0.1186, Undersample Seed = 20
# Iteration 7/10 for k=60: Accuracy = 0.7805, Std Dev = 0.0536, Undersample Seed = 73
# Iteration 8/10 for k=60: Accuracy = 0.8232, Std Dev = 0.0407, Undersample Seed = 96
# Iteration 9/10 for k=60: Accuracy = 0.6884, Std Dev = 0.0501, Undersample Seed = 27
# Iteration 10/10 for k=60: Accuracy = 0.7205, Std Dev = 0.0885, Undersample Seed = 18
# Finished iteration for k=60: Mean Accuracy = 0.7743, Mean Std Dev = 0.0446
#
# Iteration 1/10 for k=65: Accuracy = 0.7505, Std Dev = 0.0584, Undersample Seed = 24
# Iteration 2/10 for k=65: Accuracy = 0.7811, Std Dev = 0.0703, Undersample Seed = 37
# Iteration 3/10 for k=65: Accuracy = 0.8021, Std Dev = 0.0390, Undersample Seed = 84
# Iteration 4/10 for k=65: Accuracy = 0.7711, Std Dev = 0.0404, Undersample Seed = 54
# Iteration 5/10 for k=65: Accuracy = 0.8021, Std Dev = 0.0963, Undersample Seed = 42
# Iteration 6/10 for k=65: Accuracy = 0.7100, Std Dev = 0.0826, Undersample Seed = 18
# Iteration 7/10 for k=65: Accuracy = 0.8221, Std Dev = 0.1039, Undersample Seed = 81
# Iteration 8/10 for k=65: Accuracy = 0.7505, Std Dev = 0.0885, Undersample Seed = 15
# Iteration 9/10 for k=65: Accuracy = 0.8342, Std Dev = 0.1051, Undersample Seed = 5
# Iteration 10/10 for k=65: Accuracy = 0.8132, Std Dev = 0.0688, Undersample Seed = 85
# Finished iteration for k=65: Mean Accuracy = 0.7837, Mean Std Dev = 0.0366
#
# Iteration 1/10 for k=70: Accuracy = 0.7811, Std Dev = 0.0619, Undersample Seed = 92
# Iteration 2/10 for k=70: Accuracy = 0.8221, Std Dev = 0.0926, Undersample Seed = 65
# Iteration 3/10 for k=70: Accuracy = 0.7705, Std Dev = 0.0278, Undersample Seed = 80
# Iteration 4/10 for k=70: Accuracy = 0.8026, Std Dev = 0.0353, Undersample Seed = 47
# Iteration 5/10 for k=70: Accuracy = 0.7700, Std Dev = 0.0559, Undersample Seed = 45
# Iteration 6/10 for k=70: Accuracy = 0.7389, Std Dev = 0.1064, Undersample Seed = 48
# Iteration 7/10 for k=70: Accuracy = 0.8116, Std Dev = 0.0553, Undersample Seed = 68
# Iteration 8/10 for k=70: Accuracy = 0.7811, Std Dev = 0.0619, Undersample Seed = 92
# Iteration 9/10 for k=70: Accuracy = 0.7605, Std Dev = 0.0708, Undersample Seed = 70
# Iteration 10/10 for k=70: Accuracy = 0.7921, Std Dev = 0.0727, Undersample Seed = 58
# Finished iteration for k=70: Mean Accuracy = 0.7831, Mean Std Dev = 0.0236
#
# Iteration 1/10 for k=75: Accuracy = 0.8337, Std Dev = 0.0601, Undersample Seed = 47
# Iteration 2/10 for k=75: Accuracy = 0.7084, Std Dev = 0.0528, Undersample Seed = 64
# Iteration 3/10 for k=75: Accuracy = 0.7600, Std Dev = 0.1234, Undersample Seed = 21
# Iteration 4/10 for k=75: Accuracy = 0.7821, Std Dev = 0.0808, Undersample Seed = 58
# Iteration 5/10 for k=75: Accuracy = 0.7600, Std Dev = 0.0551, Undersample Seed = 37
# Iteration 6/10 for k=75: Accuracy = 0.7900, Std Dev = 0.1531, Undersample Seed = 31
# Iteration 7/10 for k=75: Accuracy = 0.8332, Std Dev = 0.1174, Undersample Seed = 40
# Iteration 8/10 for k=75: Accuracy = 0.7405, Std Dev = 0.0694, Undersample Seed = 28
# Iteration 9/10 for k=75: Accuracy = 0.7700, Std Dev = 0.0449, Undersample Seed = 10
# Iteration 10/10 for k=75: Accuracy = 0.7800, Std Dev = 0.0857, Undersample Seed = 61
# Finished iteration for k=75: Mean Accuracy = 0.7758, Mean Std Dev = 0.0364
#
# Iteration 1/10 for k=80: Accuracy = 0.7600, Std Dev = 0.0286, Undersample Seed = 10
# Iteration 2/10 for k=80: Accuracy = 0.7921, Std Dev = 0.0555, Undersample Seed = 36
# Iteration 3/10 for k=80: Accuracy = 0.8232, Std Dev = 0.0407, Undersample Seed = 94
# Iteration 4/10 for k=80: Accuracy = 0.7921, Std Dev = 0.0555, Undersample Seed = 36
# Iteration 5/10 for k=80: Accuracy = 0.8547, Std Dev = 0.0361, Undersample Seed = 50
# Iteration 6/10 for k=80: Accuracy = 0.7595, Std Dev = 0.1193, Undersample Seed = 22
# Iteration 7/10 for k=80: Accuracy = 0.7805, Std Dev = 0.0631, Undersample Seed = 45
# Iteration 8/10 for k=80: Accuracy = 0.8342, Std Dev = 0.0468, Undersample Seed = 3
# Iteration 9/10 for k=80: Accuracy = 0.8437, Std Dev = 0.0334, Undersample Seed = 89
# Iteration 10/10 for k=80: Accuracy = 0.8011, Std Dev = 0.1031, Undersample Seed = 81
# Finished iteration for k=80: Mean Accuracy = 0.8041, Mean Std Dev = 0.0319
#
# Iteration 1/10 for k=85: Accuracy = 0.8332, Std Dev = 0.0221, Undersample Seed = 89
# Iteration 2/10 for k=85: Accuracy = 0.7905, Std Dev = 0.0759, Undersample Seed = 97
# Iteration 3/10 for k=85: Accuracy = 0.8342, Std Dev = 0.0742, Undersample Seed = 85
# Iteration 4/10 for k=85: Accuracy = 0.7489, Std Dev = 0.1185, Undersample Seed = 22
# Iteration 5/10 for k=85: Accuracy = 0.8116, Std Dev = 0.0985, Undersample Seed = 81
# Iteration 6/10 for k=85: Accuracy = 0.8221, Std Dev = 0.0798, Undersample Seed = 42
# Iteration 7/10 for k=85: Accuracy = 0.8337, Std Dev = 0.0601, Undersample Seed = 94
# Iteration 8/10 for k=85: Accuracy = 0.8332, Std Dev = 0.0520, Undersample Seed = 13
# Iteration 9/10 for k=85: Accuracy = 0.8342, Std Dev = 0.0742, Undersample Seed = 85
# Iteration 10/10 for k=85: Accuracy = 0.8126, Std Dev = 0.0413, Undersample Seed = 96
# Finished iteration for k=85: Mean Accuracy = 0.8154, Mean Std Dev = 0.0260

# %%
import matplotlib.pyplot as plt

line_color = 'black'
box_color = 'lightgray'
highlight_color = 'red'  # Color for the point with the highest accuracy
fontweight = 'bold'

plt.figure(figsize=(15, 9))
plt.plot(feature_numbers, mean_accuracies, 'o-', label='Accuracy', markersize=15, color=line_color, linewidth=5)  # Make the plot line thicker

max_accuracy_index = mean_accuracies.index(max(mean_accuracies))
max_accuracy_scaling = 5  # Scaling factor for showing the highest accuracy value

for i in range(len(feature_numbers)):
    color = highlight_color if i == max_accuracy_index else 'black'
    fontsize = 20 if i == max_accuracy_index else 10

    # Alternate between placing values above and below the points
    vertical_alignment = 'bottom' if i % 2 == 0 else 'top'

    # Check if the point is the one with the highest accuracy and meets the scaling condition
    if i == max_accuracy_index:
        plt.scatter(
            feature_numbers[max_accuracy_index],
            mean_accuracies[max_accuracy_index],
            color=highlight_color,  # Change entire color of the highest point to red
            s=200,  # Increase marker size for the highest accuracy point
            label=f'Highest Accuracy: {mean_accuracies[i]:.4f} ± {std_accuracies[i]:.4f}',
        )

# Increase the font size of x-axis and y-axis labels
plt.xlabel('Number of Features', fontweight='bold', fontsize=20)
plt.ylabel('Mean Accuracy', fontweight='bold', fontsize=20)

# Adjusting tick labels
plt.xticks(fontweight='bold', fontsize=20)
plt.yticks(fontweight='bold', fontsize=20)

# Display the highest accuracy and variance as a label below the x-axis label
plt.text(
    0.5, -0.15,
    f'Highest Accuracy: {mean_accuracies[max_accuracy_index]:.4f} ± {std_accuracies[max_accuracy_index]:.4f}',
    transform=plt.gca().transAxes,
    fontsize=18,  # Increase font size
    fontweight='bold',  # Make font bold
    ha='center'
)

plt.grid(True)
plt.show()

# %%
# Specify colors for the line plot and text boxes
line_color = 'blue'
box_color = 'lightgray'
highlight_color = 'red'  # Color for the point with the highest accuracy

plt.figure(figsize=(15, 9))
plt.plot(feature_numbers, mean_accuracies, 'o-', label='Accuracy', markersize=8, color=line_color)

# Find the index of the point with the highest accuracy
max_accuracy_index = mean_accuracies.index(max(mean_accuracies))

# Annotate each point with its accuracy and std inside a colored box
for i in range(len(feature_numbers)):
    box_properties = dict(boxstyle='round', facecolor=box_color, alpha=0.7)
    
    # Use highlight_color for the point with the highest accuracy
    color = highlight_color if i == max_accuracy_index else 'black'
    fontsize = 11 if i == max_accuracy_index else 10
    
    plt.text(
        feature_numbers[i],
        mean_accuracies[i],
        f'{mean_accuracies[i]:.4f}\n±{std_accuracies[i]:.4f}',
        fontsize=fontsize,
        ha='right',
        va='bottom',
        bbox=box_properties,
        color=color  # Text color
    )

plt.title('Mean Accuracy with Std Dev for each Feature Number (Chi-squared + Undersampling + SVM with 5-Fold Cross-Validation)')
plt.xlabel('Number of Features')
plt.ylabel('Mean Accuracy')
plt.legend()
plt.grid(True)
plt.show()
