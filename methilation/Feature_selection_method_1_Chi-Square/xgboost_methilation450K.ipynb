# %%
import pandas as pd

# %%
file_path = "G:/academic/sem 7/Research - Multi-omic data in the cervical cancer studies/notebooks/New folder/methilation\Feature_selection_method_1/200_features_methilation450K.csv" 
df = pd.read_csv(file_path)

# %%
df.drop(df.columns[0], axis=1, inplace=True)
df
# Out:
#                   id  histological_type  cg26961332  cg01847620  cg01814098  \
# 0    TCGA-EK-A3GK-01                  1      0.9904      0.9860      0.0247
# 1    TCGA-GH-A9DA-01                  0      0.9910      0.9909      0.0150
# 2    TCGA-VS-A94Y-01                  0      0.9883      0.9424      0.0174
# 3    TCGA-MY-A5BF-11                  0      0.9901      0.9858      0.0174
# 4    TCGA-VS-A94Z-01                  0      0.8803      0.6852      0.0172
# ..               ...                ...         ...         ...         ...
# 300  TCGA-C5-A1MF-01                  0      0.9870      0.9878      0.0217
# 301  TCGA-C5-A1BF-01                  0      0.9801      0.9022      0.0208
# 302  TCGA-C5-A1BK-01                  0      0.9879      0.6833      0.1408
# 303  TCGA-C5-A1BI-01                  0      0.9434      0.9259      0.0244
# 304  TCGA-C5-A1M9-01                  1      0.9896      0.9833      0.0207
#
#      cg17812026  cg25800170  cg13682477  cg23889391  cg26082557  ...  \
# 0        0.9570      0.0166      0.0166      0.0158      0.0160  ...
# 1        0.9914      0.0139      0.0172      0.6539      0.0113  ...
# 2        0.9776      0.2976      0.6157      0.0132      0.0454  ...
# 3        0.9898      0.0137      0.0211      0.0169      0.0147  ...
# 4        0.5670      0.2188      0.5187      0.4858      0.4888  ...
# ..          ...         ...         ...         ...         ...  ...
# 300      0.7349      0.0180      0.0252      0.0168      0.6354  ...
# 301      0.9823      0.0190      0.0239      0.0146      0.0140  ...
# 302      0.8738      0.0223      0.4855      0.1336      0.5528  ...
# 303      0.7724      0.2028      0.0350      0.4781      0.0268  ...
# 304      0.9896      0.0278      0.0202      0.0149      0.0159  ...
#
#      cg08643007  cg08367083  cg00810836  cg04087237  cg25379026  cg08839858  \
# 0        0.0317      0.0183      0.0621      0.0652      0.0122      0.0224
# 1        0.0377      0.0147      0.0170      0.0191      0.0162      0.6017
# 2        0.0257      0.0224      0.0190      0.0687      0.4693      0.5097
# 3        0.0208      0.0264      0.0267      0.0112      0.0208      0.0193
# 4        0.0282      0.2056      0.0174      0.0142      0.5561      0.4190
# ..          ...         ...         ...         ...         ...         ...
# 300      0.0292      0.0340      0.0227      0.0179      0.3376      0.0217
# 301      0.0362      0.0259      0.0416      0.0232      0.0197      0.5360
# 302      0.0244      0.0297      0.0349      0.1042      0.0997      0.2280
# 303      0.0463      0.0372      0.1238      0.0198      0.5899      0.3088
# 304      0.0285      0.0168      0.0329      0.3369      0.0174      0.0167
#
#      cg15794252  cg09806118  cg04020999  cg06960784
# 0        0.0124      0.0120      0.9778      0.0128
# 1        0.0623      0.4581      0.9914      0.3205
# 2        0.0144      0.0115      0.9845      0.0163
# 3        0.0158      0.0144      0.9860      0.0212
# 4        0.0168      0.0121      0.9844      0.0603
# ..          ...         ...         ...         ...
# 300      0.0150      0.0149      0.9810      0.0186
# 301      0.0134      0.4100      0.9786      0.0184
# 302      0.2108      0.3921      0.9809      0.5083
# 303      0.2795      0.0145      0.9673      0.0293
# 304      0.0177      0.0143      0.9846      0.3213
#
# [305 rows x 202 columns]

# %%
column_values = df['histological_type']
total_count = column_values.count()
value_counts = column_values.value_counts()
value_counts
# Out:
# histological_type
# 0    257
# 1     48
# Name: count, dtype: int64

# %%
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from sklearn.feature_selection import chi2
from sklearn.model_selection import cross_val_score
from sklearn.utils import resample
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Assuming df is your DataFrame

xgb_classifier = XGBClassifier(objective='binary:logistic', random_state=42)  # Use binary:logistic for binary classification
K = np.arange(start=5, stop=90, step=5)
iterations = 10  # Number of iterations
feature_numbers = []
mean_accuracies = []
std_accuracies = []

# Loop through the selected features
for idx, k in enumerate(K):
    accuracies_iter = []

    for iteration in range(iterations):
        # Feature selection using Chi-squared
        X = df.iloc[:, 2:202]
        y = df["histological_type"]

        # Calculate chi-squared scores for each feature
        chi2_scores, _ = chi2(X, y)

        # Select the top k features based on chi-squared scores
        selected_features_idx = np.argsort(chi2_scores)[-k:]
        selected_features = X.columns[selected_features_idx]

        df_selected = df[['id', 'histological_type'] + list(selected_features)].copy()

        # Undersample the dataset with a random seed between 0 and 100 for each iteration
        undersample_seed = np.random.randint(101)  # Generate a random seed between 0 and 100
        cervical_squamous_df = df_selected[df_selected['histological_type'] == 0]
        if len(cervical_squamous_df) > 48:
            cervical_squamous_df = resample(cervical_squamous_df, n_samples=48, random_state=undersample_seed)
        adeno_df = df_selected[df_selected['histological_type'] == 1]
        df2 = pd.concat([cervical_squamous_df, adeno_df])

        # Split the data into features (X) and target (y)
        X_selected = df2.iloc[:, 2:]
        y_selected = df2["histological_type"]

        # Perform 5-fold cross-validation
        scores = cross_val_score(xgb_classifier, X_selected, y_selected, cv=5, scoring='accuracy')

        # Calculate average accuracy and standard deviation across folds
        accuracy = np.mean(scores)
        std_accuracy = np.std(scores)
        accuracies_iter.append(accuracy)

        # Print update after each iteration
        print(f"Iteration {iteration + 1}/{iterations} for k={k}: Accuracy = {accuracy:.4f}, Std Dev = {std_accuracy:.4f}, Undersample Seed = {undersample_seed}")

    # Store the feature number and its mean accuracy and standard deviation across iterations
    feature_numbers.append(k)
    mean_accuracies.append(np.mean(accuracies_iter))
    std_accuracies.append(np.std(accuracies_iter))

    # Print update after each feature number
    print(f"Finished iteration for k={k}: Mean Accuracy = {mean_accuracies[-1]:.4f}, Mean Std Dev = {std_accuracies[-1]:.4f}\n")

# Increase the width and height of the graph
plt.figure(figsize=(10, 6))

# Plotting the feature numbers, mean accuracies, and standard deviations
plt.errorbar(feature_numbers, mean_accuracies, yerr=std_accuracies, fmt='o-', label='Accuracy', capsize=5, markersize=8)

# Annotate each point with its accuracy and std inside a colored box
for i in range(len(feature_numbers)):
    box_properties = dict(boxstyle='round', facecolor='lightgray', alpha=0.7)
    plt.text(
        feature_numbers[i],
        mean_accuracies[i],
        f'{mean_accuracies[i]:.4f}\n±{std_accuracies[i]:.4f}',
        fontsize=8,
        ha='right',
        va='bottom',
        bbox=box_properties
    )

plt.title('Mean Accuracy with Std Dev for each Feature Number (Chi-squared + Undersampling + XGBoost with 5-Fold Cross-Validation)')
plt.xlabel('Number of Features')
plt.ylabel('Mean Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Iteration 1/10 for k=5: Accuracy = 0.7711, Std Dev = 0.1025, Undersample Seed = 63
# Iteration 2/10 for k=5: Accuracy = 0.7295, Std Dev = 0.0493, Undersample Seed = 71
# Iteration 3/10 for k=5: Accuracy = 0.8542, Std Dev = 0.0513, Undersample Seed = 62
# Iteration 4/10 for k=5: Accuracy = 0.8232, Std Dev = 0.0706, Undersample Seed = 98
# Iteration 5/10 for k=5: Accuracy = 0.8005, Std Dev = 0.1131, Undersample Seed = 8
# Iteration 6/10 for k=5: Accuracy = 0.7495, Std Dev = 0.0534, Undersample Seed = 54
# Iteration 7/10 for k=5: Accuracy = 0.8232, Std Dev = 0.0706, Undersample Seed = 98
# Iteration 8/10 for k=5: Accuracy = 0.8226, Std Dev = 0.0544, Undersample Seed = 38
# Iteration 9/10 for k=5: Accuracy = 0.8547, Std Dev = 0.0361, Undersample Seed = 82
# Iteration 10/10 for k=5: Accuracy = 0.8537, Std Dev = 0.1078, Undersample Seed = 7
# Finished iteration for k=5: Mean Accuracy = 0.8082, Mean Std Dev = 0.0425
#
# Iteration 1/10 for k=10: Accuracy = 0.8958, Std Dev = 0.0334, Undersample Seed = 1
# Iteration 2/10 for k=10: Accuracy = 0.8437, Std Dev = 0.0577, Undersample Seed = 83
# Iteration 3/10 for k=10: Accuracy = 0.6984, Std Dev = 0.1054, Undersample Seed = 30
# Iteration 4/10 for k=10: Accuracy = 0.8432, Std Dev = 0.0483, Undersample Seed = 39
# Iteration 5/10 for k=10: Accuracy = 0.7605, Std Dev = 0.0782, Undersample Seed = 29
# Iteration 6/10 for k=10: Accuracy = 0.8242, Std Dev = 0.0933, Undersample Seed = 42
# Iteration 7/10 for k=10: Accuracy = 0.8326, Std Dev = 0.0913, Undersample Seed = 7
# Iteration 8/10 for k=10: Accuracy = 0.8542, Std Dev = 0.0697, Undersample Seed = 40
# Iteration 9/10 for k=10: Accuracy = 0.8326, Std Dev = 0.1027, Undersample Seed = 18
# Iteration 10/10 for k=10: Accuracy = 0.8242, Std Dev = 0.0933, Undersample Seed = 42
# Finished iteration for k=10: Mean Accuracy = 0.8209, Mean Std Dev = 0.0516
#
# Iteration 1/10 for k=15: Accuracy = 0.8332, Std Dev = 0.0908, Undersample Seed = 25
# Iteration 2/10 for k=15: Accuracy = 0.8116, Std Dev = 0.1279, Undersample Seed = 84
# Iteration 3/10 for k=15: Accuracy = 0.7495, Std Dev = 0.1226, Undersample Seed = 35
# Iteration 4/10 for k=15: Accuracy = 0.7811, Std Dev = 0.0619, Undersample Seed = 8
# Iteration 5/10 for k=15: Accuracy = 0.8332, Std Dev = 0.1023, Undersample Seed = 32
# Iteration 6/10 for k=15: Accuracy = 0.8221, Std Dev = 0.0984, Undersample Seed = 7
# Iteration 7/10 for k=15: Accuracy = 0.7705, Std Dev = 0.1514, Undersample Seed = 15
# Iteration 8/10 for k=15: Accuracy = 0.8542, Std Dev = 0.0391, Undersample Seed = 91
# Iteration 9/10 for k=15: Accuracy = 0.8432, Std Dev = 0.1109, Undersample Seed = 50
# Iteration 10/10 for k=15: Accuracy = 0.8105, Std Dev = 0.1356, Undersample Seed = 31
# Finished iteration for k=15: Mean Accuracy = 0.8109, Mean Std Dev = 0.0321
#
# Iteration 1/10 for k=20: Accuracy = 0.8332, Std Dev = 0.0701, Undersample Seed = 96
# Iteration 2/10 for k=20: Accuracy = 0.8232, Std Dev = 0.0706, Undersample Seed = 61
# Iteration 3/10 for k=20: Accuracy = 0.7805, Std Dev = 0.0787, Undersample Seed = 55
# Iteration 4/10 for k=20: Accuracy = 0.7389, Std Dev = 0.1255, Undersample Seed = 86
# Iteration 5/10 for k=20: Accuracy = 0.8121, Std Dev = 0.0862, Undersample Seed = 32
# Iteration 6/10 for k=20: Accuracy = 0.7811, Std Dev = 0.0619, Undersample Seed = 45
# Iteration 7/10 for k=20: Accuracy = 0.7805, Std Dev = 0.1227, Undersample Seed = 35
# Iteration 8/10 for k=20: Accuracy = 0.8442, Std Dev = 0.0869, Undersample Seed = 6
# Iteration 9/10 for k=20: Accuracy = 0.7800, Std Dev = 0.0716, Undersample Seed = 72
# Iteration 10/10 for k=20: Accuracy = 0.8742, Std Dev = 0.0430, Undersample Seed = 23
# Finished iteration for k=20: Mean Accuracy = 0.8048, Mean Std Dev = 0.0378
#
# Iteration 1/10 for k=25: Accuracy = 0.8447, Std Dev = 0.1080, Undersample Seed = 54
# Iteration 2/10 for k=25: Accuracy = 0.9063, Std Dev = 0.0392, Undersample Seed = 87
# Iteration 3/10 for k=25: Accuracy = 0.8953, Std Dev = 0.0477, Undersample Seed = 12
# Iteration 4/10 for k=25: Accuracy = 0.8753, Std Dev = 0.0528, Undersample Seed = 89
# Iteration 5/10 for k=25: Accuracy = 0.8753, Std Dev = 0.0528, Undersample Seed = 89
# Iteration 6/10 for k=25: Accuracy = 0.8537, Std Dev = 0.0406, Undersample Seed = 68
# Iteration 7/10 for k=25: Accuracy = 0.8958, Std Dev = 0.0471, Undersample Seed = 77
# Iteration 8/10 for k=25: Accuracy = 0.8647, Std Dev = 0.0973, Undersample Seed = 81
# Iteration 9/10 for k=25: Accuracy = 0.8442, Std Dev = 0.0931, Undersample Seed = 5
# Iteration 10/10 for k=25: Accuracy = 0.8958, Std Dev = 0.0471, Undersample Seed = 77
# Finished iteration for k=25: Mean Accuracy = 0.8751, Mean Std Dev = 0.0216
#
# Iteration 1/10 for k=30: Accuracy = 0.8442, Std Dev = 0.0559, Undersample Seed = 22
# Iteration 2/10 for k=30: Accuracy = 0.8953, Std Dev = 0.0944, Undersample Seed = 18
# Iteration 3/10 for k=30: Accuracy = 0.8442, Std Dev = 0.0559, Undersample Seed = 22
# Iteration 4/10 for k=30: Accuracy = 0.9374, Std Dev = 0.0395, Undersample Seed = 73
# Iteration 5/10 for k=30: Accuracy = 0.9374, Std Dev = 0.0213, Undersample Seed = 94
# Iteration 6/10 for k=30: Accuracy = 0.8537, Std Dev = 0.0780, Undersample Seed = 85
# Iteration 7/10 for k=30: Accuracy = 0.8632, Std Dev = 0.0918, Undersample Seed = 66
# Iteration 8/10 for k=30: Accuracy = 0.8753, Std Dev = 0.0410, Undersample Seed = 46
# Iteration 9/10 for k=30: Accuracy = 0.9068, Std Dev = 0.0497, Undersample Seed = 87
# Iteration 10/10 for k=30: Accuracy = 0.8321, Std Dev = 0.0781, Undersample Seed = 14
# Finished iteration for k=30: Mean Accuracy = 0.8789, Mean Std Dev = 0.0366
#
# Iteration 1/10 for k=35: Accuracy = 0.9274, Std Dev = 0.0246, Undersample Seed = 1
# Iteration 2/10 for k=35: Accuracy = 0.8326, Std Dev = 0.0782, Undersample Seed = 41
# Iteration 3/10 for k=35: Accuracy = 0.8232, Std Dev = 0.0848, Undersample Seed = 9
# Iteration 4/10 for k=35: Accuracy = 0.9063, Std Dev = 0.0392, Undersample Seed = 60
# Iteration 5/10 for k=35: Accuracy = 0.9068, Std Dev = 0.0598, Undersample Seed = 42
# Iteration 6/10 for k=35: Accuracy = 0.8542, Std Dev = 0.0772, Undersample Seed = 33
# Iteration 7/10 for k=35: Accuracy = 0.8853, Std Dev = 0.0518, Undersample Seed = 59
# Iteration 8/10 for k=35: Accuracy = 0.8753, Std Dev = 0.0850, Undersample Seed = 92
# Iteration 9/10 for k=35: Accuracy = 0.8647, Std Dev = 0.0710, Undersample Seed = 8
# Iteration 10/10 for k=35: Accuracy = 0.9068, Std Dev = 0.0598, Undersample Seed = 42
# Finished iteration for k=35: Mean Accuracy = 0.8783, Mean Std Dev = 0.0328
#
# Iteration 1/10 for k=40: Accuracy = 0.8426, Std Dev = 0.1158, Undersample Seed = 57
# Iteration 2/10 for k=40: Accuracy = 0.8116, Std Dev = 0.0985, Undersample Seed = 17
# Iteration 3/10 for k=40: Accuracy = 0.8532, Std Dev = 0.0780, Undersample Seed = 28
# Iteration 4/10 for k=40: Accuracy = 0.8642, Std Dev = 0.1087, Undersample Seed = 24
# Iteration 5/10 for k=40: Accuracy = 0.8437, Std Dev = 0.0666, Undersample Seed = 16
# Iteration 6/10 for k=40: Accuracy = 0.8537, Std Dev = 0.0911, Undersample Seed = 9
# Iteration 7/10 for k=40: Accuracy = 0.8858, Std Dev = 0.0766, Undersample Seed = 88
# Iteration 8/10 for k=40: Accuracy = 0.8537, Std Dev = 0.1025, Undersample Seed = 37
# Iteration 9/10 for k=40: Accuracy = 0.8547, Std Dev = 0.0361, Undersample Seed = 22
# Iteration 10/10 for k=40: Accuracy = 0.8226, Std Dev = 0.1185, Undersample Seed = 11
# Finished iteration for k=40: Mean Accuracy = 0.8486, Mean Std Dev = 0.0196
#
# Iteration 1/10 for k=45: Accuracy = 0.8532, Std Dev = 0.0970, Undersample Seed = 99
# Iteration 2/10 for k=45: Accuracy = 0.9058, Std Dev = 0.0776, Undersample Seed = 40
# Iteration 3/10 for k=45: Accuracy = 0.9163, Std Dev = 0.0634, Undersample Seed = 89
# Iteration 4/10 for k=45: Accuracy = 0.8011, Std Dev = 0.0917, Undersample Seed = 57
# Iteration 5/10 for k=45: Accuracy = 0.9063, Std Dev = 0.0697, Undersample Seed = 100
# Iteration 6/10 for k=45: Accuracy = 0.8753, Std Dev = 0.0913, Undersample Seed = 88
# Iteration 7/10 for k=45: Accuracy = 0.8753, Std Dev = 0.0624, Undersample Seed = 45
# Iteration 8/10 for k=45: Accuracy = 0.9068, Std Dev = 0.0598, Undersample Seed = 42
# Iteration 9/10 for k=45: Accuracy = 0.8853, Std Dev = 0.0518, Undersample Seed = 49
# Iteration 10/10 for k=45: Accuracy = 0.8747, Std Dev = 0.0717, Undersample Seed = 61
# Finished iteration for k=45: Mean Accuracy = 0.8800, Mean Std Dev = 0.0323
#
# Iteration 1/10 for k=50: Accuracy = 0.8853, Std Dev = 0.0518, Undersample Seed = 56
# Iteration 2/10 for k=50: Accuracy = 0.8647, Std Dev = 0.0710, Undersample Seed = 45
# Iteration 3/10 for k=50: Accuracy = 0.8947, Std Dev = 0.1104, Undersample Seed = 34
# Iteration 4/10 for k=50: Accuracy = 0.8342, Std Dev = 0.1051, Undersample Seed = 98
# Iteration 5/10 for k=50: Accuracy = 0.8968, Std Dev = 0.0919, Undersample Seed = 78
# Iteration 6/10 for k=50: Accuracy = 0.8847, Std Dev = 0.0402, Undersample Seed = 62
# Iteration 7/10 for k=50: Accuracy = 0.8221, Std Dev = 0.0926, Undersample Seed = 41
# Iteration 8/10 for k=50: Accuracy = 0.8858, Std Dev = 0.0504, Undersample Seed = 7
# Iteration 9/10 for k=50: Accuracy = 0.8853, Std Dev = 0.0518, Undersample Seed = 56
# Iteration 10/10 for k=50: Accuracy = 0.8326, Std Dev = 0.0625, Undersample Seed = 82
# Finished iteration for k=50: Mean Accuracy = 0.8686, Mean Std Dev = 0.0269
#
# Iteration 1/10 for k=55: Accuracy = 0.8537, Std Dev = 0.0621, Undersample Seed = 8
# Iteration 2/10 for k=55: Accuracy = 0.8326, Std Dev = 0.0529, Undersample Seed = 51
# Iteration 3/10 for k=55: Accuracy = 0.8747, Std Dev = 0.0541, Undersample Seed = 63
# Iteration 4/10 for k=55: Accuracy = 0.8747, Std Dev = 0.0541, Undersample Seed = 38
# Iteration 5/10 for k=55: Accuracy = 0.8442, Std Dev = 0.0988, Undersample Seed = 6
# Iteration 6/10 for k=55: Accuracy = 0.7905, Std Dev = 0.0683, Undersample Seed = 93
# Iteration 7/10 for k=55: Accuracy = 0.9163, Std Dev = 0.0540, Undersample Seed = 67
# Iteration 8/10 for k=55: Accuracy = 0.8437, Std Dev = 0.0472, Undersample Seed = 47
# Iteration 9/10 for k=55: Accuracy = 0.8321, Std Dev = 0.1027, Undersample Seed = 41
# Iteration 10/10 for k=55: Accuracy = 0.8321, Std Dev = 0.1027, Undersample Seed = 41
# Finished iteration for k=55: Mean Accuracy = 0.8495, Mean Std Dev = 0.0319
#
# Iteration 1/10 for k=60: Accuracy = 0.8753, Std Dev = 0.0410, Undersample Seed = 61
# Iteration 2/10 for k=60: Accuracy = 0.9374, Std Dev = 0.0395, Undersample Seed = 60
# Iteration 3/10 for k=60: Accuracy = 0.8647, Std Dev = 0.0973, Undersample Seed = 70
# Iteration 4/10 for k=60: Accuracy = 0.9063, Std Dev = 0.0697, Undersample Seed = 98
# Iteration 5/10 for k=60: Accuracy = 0.8226, Std Dev = 0.0860, Undersample Seed = 52
# Iteration 6/10 for k=60: Accuracy = 0.8637, Std Dev = 0.0981, Undersample Seed = 99
# Iteration 7/10 for k=60: Accuracy = 0.9163, Std Dev = 0.0716, Undersample Seed = 18
# Iteration 8/10 for k=60: Accuracy = 0.8947, Std Dev = 0.0744, Undersample Seed = 21
# Iteration 9/10 for k=60: Accuracy = 0.8637, Std Dev = 0.0981, Undersample Seed = 99
# Iteration 10/10 for k=60: Accuracy = 0.8242, Std Dev = 0.0933, Undersample Seed = 78
# Finished iteration for k=60: Mean Accuracy = 0.8769, Mean Std Dev = 0.0355
#
# Iteration 1/10 for k=65: Accuracy = 0.8963, Std Dev = 0.0454, Undersample Seed = 87
# Iteration 2/10 for k=65: Accuracy = 0.8963, Std Dev = 0.0309, Undersample Seed = 42
# Iteration 3/10 for k=65: Accuracy = 0.8532, Std Dev = 0.0622, Undersample Seed = 23
# Iteration 4/10 for k=65: Accuracy = 0.8953, Std Dev = 0.0884, Undersample Seed = 34
# Iteration 5/10 for k=65: Accuracy = 0.8116, Std Dev = 0.0985, Undersample Seed = 25
# Iteration 6/10 for k=65: Accuracy = 0.8537, Std Dev = 0.0780, Undersample Seed = 55
# Iteration 7/10 for k=65: Accuracy = 0.9068, Std Dev = 0.0598, Undersample Seed = 50
# Iteration 8/10 for k=65: Accuracy = 0.8542, Std Dev = 0.0391, Undersample Seed = 17
# Iteration 9/10 for k=65: Accuracy = 0.8753, Std Dev = 0.0410, Undersample Seed = 37
# Iteration 10/10 for k=65: Accuracy = 0.9068, Std Dev = 0.0598, Undersample Seed = 50
# Finished iteration for k=65: Mean Accuracy = 0.8749, Mean Std Dev = 0.0296
#
# Iteration 1/10 for k=70: Accuracy = 0.8126, Std Dev = 0.0413, Undersample Seed = 69
# Iteration 2/10 for k=70: Accuracy = 0.8532, Std Dev = 0.0705, Undersample Seed = 23
# Iteration 3/10 for k=70: Accuracy = 0.8642, Std Dev = 0.0429, Undersample Seed = 17
# Iteration 4/10 for k=70: Accuracy = 0.8647, Std Dev = 0.0531, Undersample Seed = 46
# Iteration 5/10 for k=70: Accuracy = 0.8326, Std Dev = 0.0625, Undersample Seed = 28
# Iteration 6/10 for k=70: Accuracy = 0.8332, Std Dev = 0.0845, Undersample Seed = 70
# Iteration 7/10 for k=70: Accuracy = 0.8216, Std Dev = 0.0863, Undersample Seed = 31
# Iteration 8/10 for k=70: Accuracy = 0.8742, Std Dev = 0.0544, Undersample Seed = 62
# Iteration 9/10 for k=70: Accuracy = 0.8642, Std Dev = 0.0637, Undersample Seed = 71
# Iteration 10/10 for k=70: Accuracy = 0.8642, Std Dev = 0.0429, Undersample Seed = 17
# Finished iteration for k=70: Mean Accuracy = 0.8485, Mean Std Dev = 0.0205
#
# Iteration 1/10 for k=75: Accuracy = 0.8226, Std Dev = 0.0430, Undersample Seed = 47
# Iteration 2/10 for k=75: Accuracy = 0.8332, Std Dev = 0.1023, Undersample Seed = 74
# Iteration 3/10 for k=75: Accuracy = 0.8737, Std Dev = 0.0855, Undersample Seed = 26
# Iteration 4/10 for k=75: Accuracy = 0.8437, Std Dev = 0.0472, Undersample Seed = 27
# Iteration 5/10 for k=75: Accuracy = 0.7811, Std Dev = 0.0846, Undersample Seed = 48
# Iteration 6/10 for k=75: Accuracy = 0.8642, Std Dev = 0.0719, Undersample Seed = 58
# Iteration 7/10 for k=75: Accuracy = 0.8116, Std Dev = 0.0727, Undersample Seed = 41
# Iteration 8/10 for k=75: Accuracy = 0.8737, Std Dev = 0.0855, Undersample Seed = 26
# Iteration 9/10 for k=75: Accuracy = 0.8537, Std Dev = 0.0406, Undersample Seed = 44
# Iteration 10/10 for k=75: Accuracy = 0.8637, Std Dev = 0.0860, Undersample Seed = 66
# Finished iteration for k=75: Mean Accuracy = 0.8421, Mean Std Dev = 0.0286
#
# Iteration 1/10 for k=80: Accuracy = 0.8742, Std Dev = 0.0430, Undersample Seed = 95
# Iteration 2/10 for k=80: Accuracy = 0.8332, Std Dev = 0.0399, Undersample Seed = 22
# Iteration 3/10 for k=80: Accuracy = 0.8958, Std Dev = 0.0745, Undersample Seed = 56
# Iteration 4/10 for k=80: Accuracy = 0.8858, Std Dev = 0.0689, Undersample Seed = 92
# Iteration 5/10 for k=80: Accuracy = 0.8747, Std Dev = 0.0541, Undersample Seed = 71
# Iteration 6/10 for k=80: Accuracy = 0.8853, Std Dev = 0.0397, Undersample Seed = 96
# Iteration 7/10 for k=80: Accuracy = 0.7911, Std Dev = 0.0592, Undersample Seed = 99
# Iteration 8/10 for k=80: Accuracy = 0.8853, Std Dev = 0.0397, Undersample Seed = 89
# Iteration 9/10 for k=80: Accuracy = 0.8326, Std Dev = 0.0782, Undersample Seed = 25
# Iteration 10/10 for k=80: Accuracy = 0.8858, Std Dev = 0.0378, Undersample Seed = 0
# Finished iteration for k=80: Mean Accuracy = 0.8644, Mean Std Dev = 0.0322
#
# Iteration 1/10 for k=85: Accuracy = 0.8853, Std Dev = 0.0397, Undersample Seed = 96
# Iteration 2/10 for k=85: Accuracy = 0.8753, Std Dev = 0.0708, Undersample Seed = 15
# Iteration 3/10 for k=85: Accuracy = 0.8858, Std Dev = 0.0378, Undersample Seed = 0
# Iteration 4/10 for k=85: Accuracy = 0.8753, Std Dev = 0.0624, Undersample Seed = 87
# Iteration 5/10 for k=85: Accuracy = 0.9058, Std Dev = 0.0400, Undersample Seed = 77
# Iteration 6/10 for k=85: Accuracy = 0.8847, Std Dev = 0.0619, Undersample Seed = 76
# Iteration 7/10 for k=85: Accuracy = 0.8442, Std Dev = 0.0650, Undersample Seed = 22
# Iteration 8/10 for k=85: Accuracy = 0.8532, Std Dev = 0.0848, Undersample Seed = 66
# Iteration 9/10 for k=85: Accuracy = 0.8642, Std Dev = 0.0271, Undersample Seed = 63
# Iteration 10/10 for k=85: Accuracy = 0.8221, Std Dev = 0.1039, Undersample Seed = 35
# Finished iteration for k=85: Mean Accuracy = 0.8696, Mean Std Dev = 0.0230

# %%
import matplotlib.pyplot as plt

line_color = 'black'
box_color = 'lightgray'
highlight_color = 'red'  # Color for the point with the highest accuracy
fontweight = 'bold'

plt.figure(figsize=(15, 9))
plt.plot(feature_numbers, mean_accuracies, 'o-', label='Accuracy', markersize=15, color=line_color, linewidth=5)  # Make the plot line thicker

max_accuracy_index = mean_accuracies.index(max(mean_accuracies))
max_accuracy_scaling = 5  # Scaling factor for showing the highest accuracy value

for i in range(len(feature_numbers)):
    color = highlight_color if i == max_accuracy_index else 'black'
    fontsize = 20 if i == max_accuracy_index else 10

    # Alternate between placing values above and below the points
    vertical_alignment = 'bottom' if i % 2 == 0 else 'top'

    # Check if the point is the one with the highest accuracy and meets the scaling condition
    if i == max_accuracy_index:
        plt.scatter(
            feature_numbers[max_accuracy_index],
            mean_accuracies[max_accuracy_index],
            color=highlight_color,  # Change entire color of the highest point to red
            s=200,  # Increase marker size for the highest accuracy point
            label=f'Highest Accuracy: {mean_accuracies[i]:.4f} ± {std_accuracies[i]:.4f}',
        )

# Increase the font size of x-axis and y-axis labels
plt.xlabel('Number of Features', fontweight='bold', fontsize=20)
plt.ylabel('Mean Accuracy', fontweight='bold', fontsize=20)

# Adjusting tick labels
plt.xticks(fontweight='bold', fontsize=20)
plt.yticks(fontweight='bold', fontsize=20)

# Display the highest accuracy and variance as a label below the x-axis label
plt.text(
    0.5, -0.15,
    f'Highest Accuracy: {mean_accuracies[max_accuracy_index]:.4f} ± {std_accuracies[max_accuracy_index]:.4f}',
    transform=plt.gca().transAxes,
    fontsize=18,  # Increase font size
    fontweight='bold',  # Make font bold
    ha='center'
)

plt.grid(True)
plt.show()

# %%
# Specify colors for the line plot and text boxes
line_color = 'blue'
box_color = 'lightgray'
highlight_color = 'red'  # Color for the point with the highest accuracy

plt.figure(figsize=(15, 9))
plt.plot(feature_numbers, mean_accuracies, 'o-', label='Accuracy', markersize=8, color=line_color)

# Find the index of the point with the highest accuracy
max_accuracy_index = mean_accuracies.index(max(mean_accuracies))

# Annotate each point with its accuracy and std inside a colored box
for i in range(len(feature_numbers)):
    box_properties = dict(boxstyle='round', facecolor=box_color, alpha=0.7)
    
    # Use highlight_color for the point with the highest accuracy
    color = highlight_color if i == max_accuracy_index else 'black'
    fontsize = 11 if i == max_accuracy_index else 10
    
    plt.text(
        feature_numbers[i],
        mean_accuracies[i],
        f'{mean_accuracies[i]:.4f}\n±{std_accuracies[i]:.4f}',
        fontsize=fontsize,
        ha='right',
        va='bottom',
        bbox=box_properties,
        color=color  # Text color
    )

plt.title('Mean Accuracy with Std Dev for each Feature Number (Chi-squared + Undersampling + SVM with 5-Fold Cross-Validation)')
plt.xlabel('Number of Features')
plt.ylabel('Mean Accuracy')
plt.legend()
plt.grid(True)
plt.show()
