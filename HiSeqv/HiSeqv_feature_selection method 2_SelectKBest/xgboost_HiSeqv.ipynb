# %%
import pandas as pd

# %%
file_path = "G:/academic/sem 7/Research - Multi-omic data in the cervical cancer studies/notebooks/HiSeqv/After_feature_selection_HiSeqV2.csv" 
df = pd.read_csv(file_path)

# %%
target_column = df['histological_type']
df.drop(columns=['histological_type'], inplace=True)
df.insert(1, 'histological_type', target_column)

# %%
df
# Out:
#             SampleID  histological_type     GSDMC   C3orf54   SLC6A20  \
# 0    TCGA-EA-A3HT-01                  1  0.709353  0.652032  0.090343
# 1    TCGA-FU-A3HZ-01                  1  0.160065  0.293488  0.653409
# 2    TCGA-FU-A3TQ-01                  1  0.831683  0.824732  0.071678
# 3    TCGA-DS-A0VK-01                  1  0.712076  0.644784  0.135371
# 4    TCGA-UC-A7PG-01                  1  0.867126  0.697611  0.143535
# ..               ...                ...       ...       ...       ...
# 296  TCGA-MY-A5BF-01                  1  0.881797  0.708422  0.000000
# 297  TCGA-EA-A556-01                  0  0.220582  0.451836  0.476113
# 298  TCGA-IR-A3LA-01                  0  0.434788  0.195506  0.914774
# 299  TCGA-VS-AA62-01                  1  0.882569  0.511788  0.200539
# 300  TCGA-ZJ-AAXB-01                  0  0.233310  0.346170  0.452796
#
#         TDGF1   GAL3ST1    TMEM40     FRMD6  LOC285419  ...     GPR35  \
# 0    0.060730  0.118578  0.885699  0.817381   0.000000  ...  0.244387
# 1    0.639983  0.555581  0.484731  0.639293   0.307465  ...  0.181811
# 2    0.116498  0.000000  0.877721  0.832013   0.102324  ...  0.292865
# 3    0.222575  0.130827  0.742933  0.806825   0.181618  ...  0.168169
# 4    0.089301  0.088979  0.892027  0.807141   0.246001  ...  0.156347
# ..        ...       ...       ...       ...        ...  ...       ...
# 296  0.000000  0.049943  0.864172  0.830253   0.198762  ...  0.227046
# 297  0.431445  0.279527  0.254032  0.508379   0.498222  ...  0.342961
# 298  0.527432  0.151622  0.242383  0.321279   0.919733  ...  0.217509
# 299  0.000000  0.092012  0.765320  0.692125   0.159689  ...  0.251542
# 300  0.428567  0.092049  0.222472  0.422424   0.159753  ...  0.209434
#
#          AQP2  SERPINB13   GPR109B   GPR109A      GM2A      CSTA      GBP6  \
# 0    0.000000   0.884182  0.676681  0.749775  0.699953  0.875863  0.819877
# 1    0.000000   0.573198  0.214068  0.088439  0.355800  0.270775  0.224542
# 2    0.000000   0.859455  0.766740  0.850171  0.723523  0.851215  0.905796
# 3    0.100271   0.731714  0.563554  0.654232  0.512496  0.731634  0.701208
# 4    0.000000   0.874281  0.682460  0.859215  0.779807  0.881679  0.872696
# ..        ...        ...       ...       ...       ...       ...       ...
# 296  0.000000   0.919418  0.635748  0.733523  0.584097  0.748760  0.936933
# 297  0.490783   0.063557  0.383411  0.427903  0.151816  0.074788  0.189608
# 298  0.549759   0.281378  0.232428  0.294316  0.369993  0.321596  0.335246
# 299  0.000000   0.751158  0.685906  0.702059  0.792558  0.724265  0.705419
# 300  0.438532   0.206953  0.231669  0.226664  0.039651  0.423567  0.071488
#
#      C17orf28  C1orf194
# 0    0.443851  0.000000
# 1    0.741448  0.192540
# 2    0.626684  0.000000
# 3    0.717317  0.396425
# 4    0.224682  0.056307
# ..        ...       ...
# 296  0.319019  0.054279
# 297  0.828038  0.690552
# 298  0.713487  0.724628
# 299  0.495662  0.000000
# 300  0.692190  0.100040
#
# [301 rows x 92 columns]

# %%
column_values = df['histological_type']
total_count = column_values.count()
value_counts = column_values.value_counts()
value_counts
# Out:
# histological_type
# 1    253
# 0     48
# Name: count, dtype: int64

# %%
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import cross_val_score
from sklearn.utils import resample
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Assuming df is your DataFrame

xgb_classifier = XGBClassifier(objective='binary:logistic', random_state=42)  # Use binary:logistic for binary classification
K = np.arange(start=5, stop=90, step=5)
iterations = 10  # Number of iterations
feature_numbers = []
mean_accuracies = []

# Loop through the selected features
for idx, k in enumerate(K):
    accuracies_iter = []

    for iteration in range(iterations):
        # Feature selection using SelectKBest
        X = df.iloc[:, 2:92]
        y = df["histological_type"]

        selector = SelectKBest(f_classif, k=k)
        X_selected = selector.fit_transform(X, y)
        selected_features = X.columns[selector.get_support(indices=True)]

        df_selected = df[['SampleID', 'histological_type'] + list(selected_features)].copy()

        # Undersample the dataset with a random seed between 0 and 100 for each iteration
        undersample_seed = np.random.randint(101)  # Generate a random seed between 0 and 100
        cervical_squamous_df = df_selected[df_selected['histological_type'] == 0]
        if len(cervical_squamous_df) > 48:
            cervical_squamous_df = resample(cervical_squamous_df, n_samples=48, random_state=undersample_seed)
        adeno_df = df_selected[df_selected['histological_type'] == 1]
        df2 = pd.concat([cervical_squamous_df, adeno_df])

        # Split the data into features (X) and target (y)
        X_selected = df2.iloc[:, 2:]
        y_selected = df2["histological_type"]

        # Perform 5-fold cross-validation
        scores = cross_val_score(xgb_classifier, X_selected, y_selected, cv=5, scoring='accuracy')

        # Calculate average accuracy across folds
        accuracy = np.mean(scores)
        accuracies_iter.append(accuracy)

        # Print update after each iteration
        print(f"Iteration {iteration + 1}/{iterations} for k={k}: Accuracy = {accuracy:.4f}, Undersample Seed = {undersample_seed}")

    # Store the feature number and its mean accuracy across iterations
    feature_numbers.append(k)
    mean_accuracies.append(np.mean(accuracies_iter))

    # Print update after each feature number
    print(f"Finished iteration for k={k}: Mean Accuracy = {mean_accuracies[-1]:.4f}\n")

# Plotting the feature numbers and their corresponding mean accuracies
plt.figure(figsize=(10, 6))
plt.plot(feature_numbers, mean_accuracies, marker='o', linestyle='-')

# Annotate each point with its accuracy
for i in range(len(feature_numbers)):
    plt.text(feature_numbers[i], mean_accuracies[i], f'{mean_accuracies[i]:.4f}', fontsize=8, ha='right', va='bottom')

plt.title('Mean Accuracy for each Feature Number (SelectKBest + Undersampling + XGBoost with 5-Fold Cross-Validation)')
plt.xlabel('Number of Features')
plt.ylabel('Mean Accuracy')
plt.grid(True)
plt.show()
# Out:
# Iteration 1/10 for k=5: Accuracy = 0.9303, Undersample Seed = 11
# Iteration 2/10 for k=5: Accuracy = 0.9303, Undersample Seed = 3
# Iteration 3/10 for k=5: Accuracy = 0.9303, Undersample Seed = 53
# Iteration 4/10 for k=5: Accuracy = 0.9303, Undersample Seed = 54
# Iteration 5/10 for k=5: Accuracy = 0.9303, Undersample Seed = 88
# Iteration 6/10 for k=5: Accuracy = 0.9303, Undersample Seed = 33
# Iteration 7/10 for k=5: Accuracy = 0.9303, Undersample Seed = 34
# Iteration 8/10 for k=5: Accuracy = 0.9303, Undersample Seed = 69
# Iteration 9/10 for k=5: Accuracy = 0.9303, Undersample Seed = 9
# Iteration 10/10 for k=5: Accuracy = 0.9303, Undersample Seed = 97
# Finished iteration for k=5: Mean Accuracy = 0.9303
#
# Iteration 1/10 for k=10: Accuracy = 0.9468, Undersample Seed = 2
# Iteration 2/10 for k=10: Accuracy = 0.9468, Undersample Seed = 60
# Iteration 3/10 for k=10: Accuracy = 0.9468, Undersample Seed = 7
# Iteration 4/10 for k=10: Accuracy = 0.9468, Undersample Seed = 19
# Iteration 5/10 for k=10: Accuracy = 0.9468, Undersample Seed = 0
# Iteration 6/10 for k=10: Accuracy = 0.9468, Undersample Seed = 29
# Iteration 7/10 for k=10: Accuracy = 0.9468, Undersample Seed = 96
# Iteration 8/10 for k=10: Accuracy = 0.9468, Undersample Seed = 30
# Iteration 9/10 for k=10: Accuracy = 0.9468, Undersample Seed = 35
# Iteration 10/10 for k=10: Accuracy = 0.9468, Undersample Seed = 57
# Finished iteration for k=10: Mean Accuracy = 0.9468
#
# Iteration 1/10 for k=15: Accuracy = 0.9468, Undersample Seed = 3
# Iteration 2/10 for k=15: Accuracy = 0.9468, Undersample Seed = 52
# Iteration 3/10 for k=15: Accuracy = 0.9468, Undersample Seed = 74
# Iteration 4/10 for k=15: Accuracy = 0.9468, Undersample Seed = 3
# Iteration 5/10 for k=15: Accuracy = 0.9468, Undersample Seed = 32
# Iteration 6/10 for k=15: Accuracy = 0.9468, Undersample Seed = 64
# Iteration 7/10 for k=15: Accuracy = 0.9468, Undersample Seed = 5
# Iteration 8/10 for k=15: Accuracy = 0.9468, Undersample Seed = 17
# Iteration 9/10 for k=15: Accuracy = 0.9468, Undersample Seed = 6
# Iteration 10/10 for k=15: Accuracy = 0.9468, Undersample Seed = 55
# Finished iteration for k=15: Mean Accuracy = 0.9468
#
# Iteration 1/10 for k=20: Accuracy = 0.9602, Undersample Seed = 77
# Iteration 2/10 for k=20: Accuracy = 0.9602, Undersample Seed = 74
# Iteration 3/10 for k=20: Accuracy = 0.9602, Undersample Seed = 28
# Iteration 4/10 for k=20: Accuracy = 0.9602, Undersample Seed = 59
# Iteration 5/10 for k=20: Accuracy = 0.9602, Undersample Seed = 84
# Iteration 6/10 for k=20: Accuracy = 0.9602, Undersample Seed = 41
# Iteration 7/10 for k=20: Accuracy = 0.9602, Undersample Seed = 97
# Iteration 8/10 for k=20: Accuracy = 0.9602, Undersample Seed = 10
# Iteration 9/10 for k=20: Accuracy = 0.9602, Undersample Seed = 36
# Iteration 10/10 for k=20: Accuracy = 0.9602, Undersample Seed = 81
# Finished iteration for k=20: Mean Accuracy = 0.9602
#
# Iteration 1/10 for k=25: Accuracy = 0.9568, Undersample Seed = 47
# Iteration 2/10 for k=25: Accuracy = 0.9568, Undersample Seed = 59
# Iteration 3/10 for k=25: Accuracy = 0.9568, Undersample Seed = 69
# Iteration 4/10 for k=25: Accuracy = 0.9568, Undersample Seed = 54
# Iteration 5/10 for k=25: Accuracy = 0.9568, Undersample Seed = 92
# Iteration 6/10 for k=25: Accuracy = 0.9568, Undersample Seed = 19
# Iteration 7/10 for k=25: Accuracy = 0.9568, Undersample Seed = 6
# Iteration 8/10 for k=25: Accuracy = 0.9568, Undersample Seed = 55
# Iteration 9/10 for k=25: Accuracy = 0.9568, Undersample Seed = 56
# Iteration 10/10 for k=25: Accuracy = 0.9568, Undersample Seed = 53
# Finished iteration for k=25: Mean Accuracy = 0.9568
#
# Iteration 1/10 for k=30: Accuracy = 0.9435, Undersample Seed = 8
# Iteration 2/10 for k=30: Accuracy = 0.9435, Undersample Seed = 4
# Iteration 3/10 for k=30: Accuracy = 0.9435, Undersample Seed = 60
# Iteration 4/10 for k=30: Accuracy = 0.9435, Undersample Seed = 90
# Iteration 5/10 for k=30: Accuracy = 0.9435, Undersample Seed = 33
# Iteration 6/10 for k=30: Accuracy = 0.9435, Undersample Seed = 50
# Iteration 7/10 for k=30: Accuracy = 0.9435, Undersample Seed = 89
# Iteration 8/10 for k=30: Accuracy = 0.9435, Undersample Seed = 48
# Iteration 9/10 for k=30: Accuracy = 0.9435, Undersample Seed = 97
# Iteration 10/10 for k=30: Accuracy = 0.9435, Undersample Seed = 22
# Finished iteration for k=30: Mean Accuracy = 0.9435
#
# Iteration 1/10 for k=35: Accuracy = 0.9502, Undersample Seed = 13
# Iteration 2/10 for k=35: Accuracy = 0.9502, Undersample Seed = 37
# Iteration 3/10 for k=35: Accuracy = 0.9502, Undersample Seed = 43
# Iteration 4/10 for k=35: Accuracy = 0.9502, Undersample Seed = 31
# Iteration 5/10 for k=35: Accuracy = 0.9502, Undersample Seed = 32
# Iteration 6/10 for k=35: Accuracy = 0.9502, Undersample Seed = 59
# Iteration 7/10 for k=35: Accuracy = 0.9502, Undersample Seed = 1
# Iteration 8/10 for k=35: Accuracy = 0.9502, Undersample Seed = 71
# Iteration 9/10 for k=35: Accuracy = 0.9502, Undersample Seed = 43
# Iteration 10/10 for k=35: Accuracy = 0.9502, Undersample Seed = 83
# Finished iteration for k=35: Mean Accuracy = 0.9502
#
# Iteration 1/10 for k=40: Accuracy = 0.9268, Undersample Seed = 13
# Iteration 2/10 for k=40: Accuracy = 0.9268, Undersample Seed = 65
# Iteration 3/10 for k=40: Accuracy = 0.9268, Undersample Seed = 6
# Iteration 4/10 for k=40: Accuracy = 0.9268, Undersample Seed = 16
# Iteration 5/10 for k=40: Accuracy = 0.9268, Undersample Seed = 18
# Iteration 6/10 for k=40: Accuracy = 0.9268, Undersample Seed = 41
# Iteration 7/10 for k=40: Accuracy = 0.9268, Undersample Seed = 61
# Iteration 8/10 for k=40: Accuracy = 0.9268, Undersample Seed = 13
# Iteration 9/10 for k=40: Accuracy = 0.9268, Undersample Seed = 52
# Iteration 10/10 for k=40: Accuracy = 0.9268, Undersample Seed = 58
# Finished iteration for k=40: Mean Accuracy = 0.9268
#
# Iteration 1/10 for k=45: Accuracy = 0.9302, Undersample Seed = 47
# Iteration 2/10 for k=45: Accuracy = 0.9302, Undersample Seed = 91
# Iteration 3/10 for k=45: Accuracy = 0.9302, Undersample Seed = 25
# Iteration 4/10 for k=45: Accuracy = 0.9302, Undersample Seed = 10
# Iteration 5/10 for k=45: Accuracy = 0.9302, Undersample Seed = 80
# Iteration 6/10 for k=45: Accuracy = 0.9302, Undersample Seed = 84
# Iteration 7/10 for k=45: Accuracy = 0.9302, Undersample Seed = 66
# Iteration 8/10 for k=45: Accuracy = 0.9302, Undersample Seed = 80
# Iteration 9/10 for k=45: Accuracy = 0.9302, Undersample Seed = 94
# Iteration 10/10 for k=45: Accuracy = 0.9302, Undersample Seed = 49
# Finished iteration for k=45: Mean Accuracy = 0.9302
#
# Iteration 1/10 for k=50: Accuracy = 0.9302, Undersample Seed = 2
# Iteration 2/10 for k=50: Accuracy = 0.9302, Undersample Seed = 83
# Iteration 3/10 for k=50: Accuracy = 0.9302, Undersample Seed = 23
# Iteration 4/10 for k=50: Accuracy = 0.9302, Undersample Seed = 37
# Iteration 5/10 for k=50: Accuracy = 0.9302, Undersample Seed = 26
# Iteration 6/10 for k=50: Accuracy = 0.9302, Undersample Seed = 35
# Iteration 7/10 for k=50: Accuracy = 0.9302, Undersample Seed = 37
# Iteration 8/10 for k=50: Accuracy = 0.9302, Undersample Seed = 62
# Iteration 9/10 for k=50: Accuracy = 0.9302, Undersample Seed = 82
# Iteration 10/10 for k=50: Accuracy = 0.9302, Undersample Seed = 27
# Finished iteration for k=50: Mean Accuracy = 0.9302
#
# Iteration 1/10 for k=55: Accuracy = 0.9369, Undersample Seed = 47
# Iteration 2/10 for k=55: Accuracy = 0.9369, Undersample Seed = 98
# Iteration 3/10 for k=55: Accuracy = 0.9369, Undersample Seed = 63
# Iteration 4/10 for k=55: Accuracy = 0.9369, Undersample Seed = 83
# Iteration 5/10 for k=55: Accuracy = 0.9369, Undersample Seed = 28
# Iteration 6/10 for k=55: Accuracy = 0.9369, Undersample Seed = 19
# Iteration 7/10 for k=55: Accuracy = 0.9369, Undersample Seed = 51
# Iteration 8/10 for k=55: Accuracy = 0.9369, Undersample Seed = 94
# Iteration 9/10 for k=55: Accuracy = 0.9369, Undersample Seed = 70
# Iteration 10/10 for k=55: Accuracy = 0.9369, Undersample Seed = 19
# Finished iteration for k=55: Mean Accuracy = 0.9369
#
# Iteration 1/10 for k=60: Accuracy = 0.9368, Undersample Seed = 76
# Iteration 2/10 for k=60: Accuracy = 0.9368, Undersample Seed = 27
# Iteration 3/10 for k=60: Accuracy = 0.9368, Undersample Seed = 25
# Iteration 4/10 for k=60: Accuracy = 0.9368, Undersample Seed = 49
# Iteration 5/10 for k=60: Accuracy = 0.9368, Undersample Seed = 78
# Iteration 6/10 for k=60: Accuracy = 0.9368, Undersample Seed = 91
# Iteration 7/10 for k=60: Accuracy = 0.9368, Undersample Seed = 93
# Iteration 8/10 for k=60: Accuracy = 0.9368, Undersample Seed = 31
# Iteration 9/10 for k=60: Accuracy = 0.9368, Undersample Seed = 11
# Iteration 10/10 for k=60: Accuracy = 0.9368, Undersample Seed = 12
# Finished iteration for k=60: Mean Accuracy = 0.9368
#
# Iteration 1/10 for k=65: Accuracy = 0.9335, Undersample Seed = 79
# Iteration 2/10 for k=65: Accuracy = 0.9335, Undersample Seed = 94
# Iteration 3/10 for k=65: Accuracy = 0.9335, Undersample Seed = 23
# Iteration 4/10 for k=65: Accuracy = 0.9335, Undersample Seed = 93
# Iteration 5/10 for k=65: Accuracy = 0.9335, Undersample Seed = 46
# Iteration 6/10 for k=65: Accuracy = 0.9335, Undersample Seed = 58
# Iteration 7/10 for k=65: Accuracy = 0.9335, Undersample Seed = 77
# Iteration 8/10 for k=65: Accuracy = 0.9335, Undersample Seed = 58
# Iteration 9/10 for k=65: Accuracy = 0.9335, Undersample Seed = 43
# Iteration 10/10 for k=65: Accuracy = 0.9335, Undersample Seed = 46
# Finished iteration for k=65: Mean Accuracy = 0.9335
#
# Iteration 1/10 for k=70: Accuracy = 0.9335, Undersample Seed = 91
# Iteration 2/10 for k=70: Accuracy = 0.9335, Undersample Seed = 84
# Iteration 3/10 for k=70: Accuracy = 0.9335, Undersample Seed = 18
# Iteration 4/10 for k=70: Accuracy = 0.9335, Undersample Seed = 24
# Iteration 5/10 for k=70: Accuracy = 0.9335, Undersample Seed = 83
# Iteration 6/10 for k=70: Accuracy = 0.9335, Undersample Seed = 65
# Iteration 7/10 for k=70: Accuracy = 0.9335, Undersample Seed = 94
# Iteration 8/10 for k=70: Accuracy = 0.9335, Undersample Seed = 56
# Iteration 9/10 for k=70: Accuracy = 0.9335, Undersample Seed = 35
# Iteration 10/10 for k=70: Accuracy = 0.9335, Undersample Seed = 8
# Finished iteration for k=70: Mean Accuracy = 0.9335
#
# Iteration 1/10 for k=75: Accuracy = 0.9402, Undersample Seed = 77
# Iteration 2/10 for k=75: Accuracy = 0.9402, Undersample Seed = 55
# Iteration 3/10 for k=75: Accuracy = 0.9402, Undersample Seed = 24
# Iteration 4/10 for k=75: Accuracy = 0.9402, Undersample Seed = 31
# Iteration 5/10 for k=75: Accuracy = 0.9402, Undersample Seed = 39
# Iteration 6/10 for k=75: Accuracy = 0.9402, Undersample Seed = 28
# Iteration 7/10 for k=75: Accuracy = 0.9402, Undersample Seed = 59
# Iteration 8/10 for k=75: Accuracy = 0.9402, Undersample Seed = 12
# Iteration 9/10 for k=75: Accuracy = 0.9402, Undersample Seed = 66
# Iteration 10/10 for k=75: Accuracy = 0.9402, Undersample Seed = 61
# Finished iteration for k=75: Mean Accuracy = 0.9402
#
# Iteration 1/10 for k=80: Accuracy = 0.9436, Undersample Seed = 45
# Iteration 2/10 for k=80: Accuracy = 0.9436, Undersample Seed = 97
# Iteration 3/10 for k=80: Accuracy = 0.9436, Undersample Seed = 39
# Iteration 4/10 for k=80: Accuracy = 0.9436, Undersample Seed = 50
# Iteration 5/10 for k=80: Accuracy = 0.9436, Undersample Seed = 94
# Iteration 6/10 for k=80: Accuracy = 0.9436, Undersample Seed = 73
# Iteration 7/10 for k=80: Accuracy = 0.9436, Undersample Seed = 38
# Iteration 8/10 for k=80: Accuracy = 0.9436, Undersample Seed = 60
# Iteration 9/10 for k=80: Accuracy = 0.9436, Undersample Seed = 14
# Iteration 10/10 for k=80: Accuracy = 0.9436, Undersample Seed = 37
# Finished iteration for k=80: Mean Accuracy = 0.9436
#
# Iteration 1/10 for k=85: Accuracy = 0.9468, Undersample Seed = 48
# Iteration 2/10 for k=85: Accuracy = 0.9468, Undersample Seed = 4
# Iteration 3/10 for k=85: Accuracy = 0.9468, Undersample Seed = 29
# Iteration 4/10 for k=85: Accuracy = 0.9468, Undersample Seed = 69
# Iteration 5/10 for k=85: Accuracy = 0.9468, Undersample Seed = 72
# Iteration 6/10 for k=85: Accuracy = 0.9468, Undersample Seed = 4
# Iteration 7/10 for k=85: Accuracy = 0.9468, Undersample Seed = 75
# Iteration 8/10 for k=85: Accuracy = 0.9468, Undersample Seed = 91
# Iteration 9/10 for k=85: Accuracy = 0.9468, Undersample Seed = 33
# Iteration 10/10 for k=85: Accuracy = 0.9468, Undersample Seed = 42
# Finished iteration for k=85: Mean Accuracy = 0.9468
