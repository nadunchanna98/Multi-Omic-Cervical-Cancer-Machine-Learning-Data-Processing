# %%
import pandas as pd

# %%
file_path = "G:/academic/sem 7/Research - Multi-omic data in the cervical cancer studies/notebooks/New folder/HiSeqv/HiSeqv_feature_selection method 1/Before_undersample_HiSeqv.csv" 
df = pd.read_csv(file_path)

# %%
df
# Out:
#             SampleID  histological_type  ARHGEF10L     HIF3A     RNF17  \
# 0    TCGA-EA-A3HT-01                  1   0.725318  0.189987  0.174594
# 1    TCGA-FU-A3HZ-01                  1   0.444151  0.248211  0.000000
# 2    TCGA-FU-A3TQ-01                  1   0.837766  0.230985  0.374522
# 3    TCGA-DS-A0VK-01                  1   0.564916  0.389652  0.450002
# 4    TCGA-UC-A7PG-01                  1   0.772081  0.413758  0.088769
# ..               ...                ...        ...       ...       ...
# 296  TCGA-MY-A5BF-01                  1   0.556710  0.122052  0.147576
# 297  TCGA-EA-A556-01                  0   0.388797  0.809501  0.000000
# 298  TCGA-IR-A3LA-01                  0   0.576657  0.273252  0.000000
# 299  TCGA-VS-AA62-01                  1   0.364161  0.200194  0.092233
# 300  TCGA-ZJ-AAXB-01                  0   0.513390  0.456903  0.000000
#
#         RNF10     RNF11     RNF13   GTF2IP1      REM1  ...     TULP2  \
# 0    0.496180  0.617883  0.637369  0.565425  0.609614  ...  0.296442
# 1    0.561269  0.463589  0.230653  0.652436  0.324709  ...  0.000000
# 2    0.554383  0.829937  0.389478  0.630412  0.516601  ...  0.000000
# 3    0.518949  0.531938  0.716303  0.719264  0.379869  ...  0.000000
# 4    0.665259  0.608024  0.331768  0.661789  0.486976  ...  0.000000
# ..        ...       ...       ...       ...       ...  ...       ...
# 296  0.556544  0.713526  0.665668  0.259738  0.277640  ...  0.000000
# 297  0.687726  0.501289  0.308968  0.821602  0.682432  ...  0.000000
# 298  0.478287  0.494694  0.659674  0.769528  0.449023  ...  0.117572
# 299  0.569914  0.392592  0.609657  0.604375  0.396689  ...  0.156602
# 300  0.706474  0.475114  0.558343  0.420908  0.573749  ...  0.000000
#
#         NPY5R     GNGT2     GNGT1     TULP3      PTRF     BCL6B     GSTK1  \
# 0    0.000000  0.560584  0.255231  0.497724  0.626944  0.515713  0.222879
# 1    0.290987  0.506421  0.479059  0.400047  0.302075  0.322926  0.267669
# 2    0.000000  0.582022  0.705226  0.578096  0.420560  0.428795  0.444500
# 3    0.000000  0.446650  0.000000  0.369243  0.522974  0.751170  0.513679
# 4    0.115226  0.426500  0.225709  0.499123  0.588495  0.450644  0.511162
# ..        ...       ...       ...       ...       ...       ...       ...
# 296  0.000000  0.540330  0.000000  0.538678  0.523095  0.698141  0.184597
# 297  0.000000  0.280758  0.661005  0.545202  0.493125  0.562874  0.430963
# 298  0.089884  0.340676  0.224760  0.635093  0.261346  0.323549  0.764273
# 299  0.000000  0.703145  0.475191  0.476143  0.684026  0.480346  0.681699
# 300  0.000000  0.391511  0.279055  0.328899  0.556499  0.561019  0.458749
#
#          SELP      SELS
# 0    0.316847  0.405340
# 1    0.313092  0.530207
# 2    0.612588  0.361471
# 3    0.660377  0.407865
# 4    0.432341  0.405667
# ..        ...       ...
# 296  0.233885  0.423132
# 297  0.260699  0.485921
# 298  0.388770  0.801592
# 299  0.480234  0.454319
# 300  0.265134  0.592224
#
# [301 rows x 20132 columns]

# %%
column_values = df['histological_type']
total_count = column_values.count()
value_counts = column_values.value_counts()
value_counts
# Out:
# histological_type
# 1    253
# 0     48
# Name: count, dtype: int64

# %%
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_selection import chi2
from sklearn.model_selection import cross_val_score
from sklearn.utils import resample
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Assuming df is your DataFrame

dt_classifier = DecisionTreeClassifier(random_state=42)  # Use Decision Tree
K = np.arange(start=5, stop=90, step=5)
iterations = 10  # Number of iterations
feature_numbers = []
mean_accuracies = []
std_accuracies = []

# Loop through the selected features
for idx, k in enumerate(K):
    accuracies_iter = []

    for iteration in range(iterations):
        # Feature selection using Chi-squared
        X = df.iloc[:, 2:20132]
        y = df["histological_type"]

        # Calculate chi-squared scores for each feature
        chi2_scores, _ = chi2(X, y)

        # Select the top k features based on chi-squared scores
        selected_features_idx = np.argsort(chi2_scores)[-k:]
        selected_features = X.columns[selected_features_idx]

        df_selected = df[['SampleID', 'histological_type'] + list(selected_features)].copy()

        # Undersample the dataset with a random seed between 0 and 100 for each iteration
        undersample_seed = np.random.randint(101)  # Generate a random seed between 0 and 100
        cervical_squamous_df = df_selected[df_selected['histological_type'] == 0]
        if len(cervical_squamous_df) > 48:
            cervical_squamous_df = resample(cervical_squamous_df, n_samples=48, random_state=undersample_seed)
        adeno_df = df_selected[df_selected['histological_type'] == 1]
        df2 = pd.concat([cervical_squamous_df, adeno_df])

        # Split the data into features (X) and target (y)
        X_selected = df2.iloc[:, 2:]
        y_selected = df2["histological_type"]

        # Perform 5-fold cross-validation
        scores = cross_val_score(dt_classifier, X_selected, y_selected, cv=5, scoring='accuracy')

        # Calculate average accuracy and standard deviation across folds
        accuracy = np.mean(scores)
        std_accuracy = np.std(scores)
        accuracies_iter.append(accuracy)

        # Print update after each iteration
        print(f"Iteration {iteration + 1}/{iterations} for k={k}: Accuracy = {accuracy:.4f}, Std Dev = {std_accuracy:.4f}, Undersample Seed = {undersample_seed}")

    # Store the feature number and its mean accuracy and standard deviation across iterations
    feature_numbers.append(k)
    mean_accuracies.append(np.mean(accuracies_iter))
    std_accuracies.append(np.std(accuracies_iter))

    # Print update after each feature number
    print(f"Finished iteration for k={k}: Mean Accuracy = {mean_accuracies[-1]:.4f}, Mean Std Dev = {std_accuracies[-1]:.4f}\n")

# Increase the width and height of the graph
plt.figure(figsize=(10, 6))

# Plotting the feature numbers, mean accuracies, and standard deviations
plt.errorbar(feature_numbers, mean_accuracies, yerr=std_accuracies, fmt='o-', label='Accuracy', capsize=5, markersize=8)

# Annotate each point with its accuracy and std inside a colored box
for i in range(len(feature_numbers)):
    box_properties = dict(boxstyle='round', facecolor='lightgray', alpha=0.7)
    plt.text(
        feature_numbers[i],
        mean_accuracies[i],
        f'{mean_accuracies[i]:.4f}\n±{std_accuracies[i]:.4f}',
        fontsize=8,
        ha='right',
        va='bottom',
        bbox=box_properties
    )

plt.title('Mean Accuracy with Std Dev for each Feature Number (Chi-squared + Undersampling + Decision Tree with 5-Fold Cross-Validation)')
plt.xlabel('Number of Features')
plt.ylabel('Mean Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Iteration 1/10 for k=5: Accuracy = 0.8405, Std Dev = 0.0078, Undersample Seed = 96
# Iteration 2/10 for k=5: Accuracy = 0.8405, Std Dev = 0.0078, Undersample Seed = 50
# Iteration 3/10 for k=5: Accuracy = 0.8405, Std Dev = 0.0078, Undersample Seed = 42
# Iteration 4/10 for k=5: Accuracy = 0.8405, Std Dev = 0.0078, Undersample Seed = 4
# Iteration 5/10 for k=5: Accuracy = 0.8405, Std Dev = 0.0078, Undersample Seed = 28
# Iteration 6/10 for k=5: Accuracy = 0.8405, Std Dev = 0.0078, Undersample Seed = 84
# Iteration 7/10 for k=5: Accuracy = 0.8405, Std Dev = 0.0078, Undersample Seed = 14
# Iteration 8/10 for k=5: Accuracy = 0.8405, Std Dev = 0.0078, Undersample Seed = 94
# Iteration 9/10 for k=5: Accuracy = 0.8405, Std Dev = 0.0078, Undersample Seed = 25
# Iteration 10/10 for k=5: Accuracy = 0.8405, Std Dev = 0.0078, Undersample Seed = 95
# Finished iteration for k=5: Mean Accuracy = 0.8405, Mean Std Dev = 0.0000
#
# Iteration 1/10 for k=10: Accuracy = 0.9102, Std Dev = 0.0173, Undersample Seed = 34
# Iteration 2/10 for k=10: Accuracy = 0.9102, Std Dev = 0.0173, Undersample Seed = 92
# Iteration 3/10 for k=10: Accuracy = 0.9102, Std Dev = 0.0173, Undersample Seed = 52
# Iteration 4/10 for k=10: Accuracy = 0.9102, Std Dev = 0.0173, Undersample Seed = 62
# Iteration 5/10 for k=10: Accuracy = 0.9102, Std Dev = 0.0173, Undersample Seed = 38
# Iteration 6/10 for k=10: Accuracy = 0.9102, Std Dev = 0.0173, Undersample Seed = 96
# Iteration 7/10 for k=10: Accuracy = 0.9102, Std Dev = 0.0173, Undersample Seed = 52
# Iteration 8/10 for k=10: Accuracy = 0.9102, Std Dev = 0.0173, Undersample Seed = 34
# Iteration 9/10 for k=10: Accuracy = 0.9102, Std Dev = 0.0173, Undersample Seed = 36
# Iteration 10/10 for k=10: Accuracy = 0.9102, Std Dev = 0.0173, Undersample Seed = 42
# Finished iteration for k=10: Mean Accuracy = 0.9102, Mean Std Dev = 0.0000
#
# Iteration 1/10 for k=15: Accuracy = 0.8970, Std Dev = 0.0219, Undersample Seed = 25
# Iteration 2/10 for k=15: Accuracy = 0.8970, Std Dev = 0.0219, Undersample Seed = 45
# Iteration 3/10 for k=15: Accuracy = 0.8970, Std Dev = 0.0219, Undersample Seed = 78
# Iteration 4/10 for k=15: Accuracy = 0.8970, Std Dev = 0.0219, Undersample Seed = 63
# Iteration 5/10 for k=15: Accuracy = 0.8970, Std Dev = 0.0219, Undersample Seed = 59
# Iteration 6/10 for k=15: Accuracy = 0.8970, Std Dev = 0.0219, Undersample Seed = 33
# Iteration 7/10 for k=15: Accuracy = 0.8970, Std Dev = 0.0219, Undersample Seed = 31
# Iteration 8/10 for k=15: Accuracy = 0.8970, Std Dev = 0.0219, Undersample Seed = 0
# Iteration 9/10 for k=15: Accuracy = 0.8970, Std Dev = 0.0219, Undersample Seed = 74
# Iteration 10/10 for k=15: Accuracy = 0.8970, Std Dev = 0.0219, Undersample Seed = 1
# Finished iteration for k=15: Mean Accuracy = 0.8970, Mean Std Dev = 0.0000
#
# Iteration 1/10 for k=20: Accuracy = 0.9169, Std Dev = 0.0279, Undersample Seed =
10 for k=65: Accuracy = 0.9138, Std Dev = 0.0363, Undersample Seed = 76
# Iteration 10/10 for k=65: Accuracy = 0.9138, Std Dev = 0.0363, Undersample Seed = 21
# Finished iteration for k=65: Mean Accuracy = 0.9138, Mean Std Dev = 0.0000
#
# Iteration 1/10 for k=70: Accuracy = 0.8971, Std Dev = 0.0215, Undersample Seed = 22
# Iteration 2/10 for k=70: Accuracy = 0.8971, Std Dev = 0.0215, Undersample Seed = 33
# Iteration 3/10 for k=70: Accuracy = 0.8971, Std Dev = 0.0215, Undersample Seed = 20
# Iteration 4/10 for k=70: Accuracy = 0.8971, Std Dev = 0.0215, Undersample Seed = 30
# Iteration 5/10 for k=70: Accuracy = 0.8971, Std Dev = 0.0215, Undersample Seed = 100
# Iteration 6/10 for k=70: Accuracy = 0.8971, Std Dev = 0.0215, Undersample Seed = 46
# Iteration 7/10 for k=70: Accuracy = 0.8971, Std Dev = 0.0215, Undersample Seed = 81
# Iteration 8/10 for k=70: Accuracy = 0.8971, Std Dev = 0.0215, Undersample Seed = 69
# Iteration 9/10 for k=70: Accuracy = 0.8971, Std Dev = 0.0215, Undersample Seed = 89
# Iteration 10/10 for k=70: Accuracy = 0.8971, Std Dev = 0.0215, Undersample Seed = 90
# Finished iteration for k=70: Mean Accuracy = 0.8971, Mean Std Dev = 0.0000
#
# Iteration 1/10 for k=75: Accuracy = 0.9005, Std Dev = 0.0416, Undersample Seed = 77
# Iteration 2/10 for k=75: Accuracy = 0.9005, Std Dev = 0.0416, Undersample Seed = 19
# Iteration 3/10 for k=75: Accuracy = 0.9005, Std Dev = 0.0416, Undersample Seed = 75
# Iteration 4/10 for k=75: Accuracy = 0.9005, Std Dev = 0.0416, Undersample Seed = 50
# Iteration 5/10 for k=75: Accuracy = 0.9005, Std Dev = 0.0416, Undersample Seed = 47
# Iteration 6/10 for k=75: Accuracy = 0.9005, Std Dev = 0.0416, Undersample Seed = 88
# Iteration 7/10 for k=75: Accuracy = 0.9005, Std Dev = 0.0416, Undersample Seed = 41
# Iteration 8/10 for k=75: Accuracy = 0.9005, Std Dev = 0.0416, Undersample Seed = 56
# Iteration 9/10 for k=75: Accuracy = 0.9005, Std Dev = 0.0416, Undersample Seed = 15
# Iteration 10/10 for k=75: Accuracy = 0.9005, Std Dev = 0.0416, Undersample Seed = 1
# Finished iteration for k=75: Mean Accuracy = 0.9005, Mean Std Dev = 0.0000
#
# Iteration 1/10 for k=80: Accuracy = 0.9005, Std Dev = 0.0399, Undersample Seed = 33
# Iteration 2/10 for k=80: Accuracy = 0.9005, Std Dev = 0.0399, Undersample Seed = 36
# Iteration 3/10 for k=80: Accuracy = 0.9005, Std Dev = 0.0399, Undersample Seed = 22
# Iteration 4/10 for k=80: Accuracy = 0.9005, Std Dev = 0.0399, Undersample Seed = 15
# Iteration 5/10 for k=80: Accuracy = 0.9005, Std Dev = 0.0399, Undersample Seed = 85
# Iteration 6/10 for k=80: Accuracy = 0.9005, Std Dev = 0.0399, Undersample Seed = 12
# Iteration 7/10 for k=80: Accuracy = 0.9005, Std Dev = 0.0399, Undersample Seed = 4
# Iteration 8/10 for k=80: Accuracy = 0.9005, Std Dev = 0.0399, Undersample Seed = 55
# Iteration 9/10 for k=80: Accuracy = 0.9005, Std Dev = 0.0399, Undersample Seed = 31
# Iteration 10/10 for k=80: Accuracy = 0.9005, Std Dev = 0.0399, Undersample Seed = 8
# Finished iteration for k=80: Mean Accuracy = 0.9005, Mean Std Dev = 0.0000
#
# Iteration 1/10 for k=85: Accuracy = 0.9205, Std Dev = 0.0362, Undersample Seed = 31
# Iteration 2/10 for k=85: Accuracy = 0.9205, Std Dev = 0.0362, Undersample Seed = 18
# Iteration 3/10 for k=85: Accuracy = 0.9205, Std Dev = 0.0362, Undersample Seed = 59
# Iteration 4/10 for k=85: Accuracy = 0.9205, Std Dev = 0.0362, Undersample Seed = 8
# Iteration 5/10 for k=85: Accuracy = 0.9205, Std Dev = 0.0362, Undersample Seed = 2
# Iteration 6/10 for k=85: Accuracy = 0.9205, Std Dev = 0.0362, Undersample Seed = 62
# Iteration 7/10 for k=85: Accuracy = 0.9205, Std Dev = 0.0362, Undersample Seed = 72
# Iteration 8/10 for k=85: Accuracy = 0.9205, Std Dev = 0.0362, Undersample Seed = 34
# Iteration 9/10 for k=85: Accuracy = 0.9205, Std Dev = 0.0362, Undersample Seed = 61
# Iteration 10/10 for k=85: Accuracy = 0.9205, Std Dev = 0.0362, Undersample Seed = 32
# Finished iteration for k=85: Mean Accuracy = 0.9205, Mean Std Dev = 0.0000

# %%
# Specify colors for the line plot and text boxes
line_color = 'blue'
box_color = 'lightgray'
highlight_color = 'red'  # Color for the point with the highest accuracy

plt.figure(figsize=(15, 9))
plt.plot(feature_numbers, mean_accuracies, 'o-', label='Accuracy', markersize=8, color=line_color)

# Find the index of the point with the highest accuracy
max_accuracy_index = mean_accuracies.index(max(mean_accuracies))

# Annotate each point with its accuracy and std inside a colored box
for i in range(len(feature_numbers)):
    box_properties = dict(boxstyle='round', facecolor=box_color, alpha=0.7)
    
    # Use highlight_color for the point with the highest accuracy
    color = highlight_color if i == max_accuracy_index else 'black'
    fontsize = 11 if i == max_accuracy_index else 10
    
    plt.text(
        feature_numbers[i],
        mean_accuracies[i],
        f'{mean_accuracies[i]:.4f}\n±{std_accuracies[i]:.4f}',
        fontsize=fontsize,
        ha='right',
        va='bottom',
        bbox=box_properties,
        color=color  # Text color
    )

plt.title('Mean Accuracy with Std Dev for each Feature Number (Chi-squared + Undersampling + SVM with 5-Fold Cross-Validation)')
plt.xlabel('Number of Features')
plt.ylabel('Mean Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

line_color = 'black'
box_color = 'lightgray'
highlight_color = 'red'  # Color for the point with the highest accuracy
fontweight = 'bold'

plt.figure(figsize=(15, 9))
plt.plot(feature_numbers, mean_accuracies, 'o-', label='Accuracy', markersize=15, color=line_color, linewidth=5)  # Make the plot line thicker

max_accuracy_index = mean_accuracies.index(max(mean_accuracies))
max_accuracy_scaling = 5  # Scaling factor for showing the highest accuracy value

for i in range(len(feature_numbers)):
    color = highlight_color if i == max_accuracy_index else 'black'
    fontsize = 20 if i == max_accuracy_index else 10

    # Alternate between placing values above and below the points
    vertical_alignment = 'bottom' if i % 2 == 0 else 'top'

    # Check if the point is the one with the highest accuracy and meets the scaling condition
    if i == max_accuracy_index:
        plt.scatter(
            feature_numbers[max_accuracy_index],
            mean_accuracies[max_accuracy_index],
            color=highlight_color,  # Change entire color of the highest point to red
            s=200,  # Increase marker size for the highest accuracy point
            label=f'Highest Accuracy: {mean_accuracies[i]:.4f} ± {std_accuracies[i]:.4f}',
        )

# Increase the font size of x-axis and y-axis labels
plt.xlabel('Number of Features', fontweight='bold', fontsize=20)
plt.ylabel('Mean Accuracy', fontweight='bold', fontsize=20)

# Adjusting tick labels
plt.xticks(fontweight='bold', fontsize=20)
plt.yticks(fontweight='bold', fontsize=20)

# Display the highest accuracy and variance as a label below the x-axis label
plt.text(
    0.5, -0.15,
    f'Highest Accuracy: {mean_accuracies[max_accuracy_index]:.4f} ± {std_accuracies[max_accuracy_index]:.4f}',
    transform=plt.gca().transAxes,
    fontsize=18,  # Increase font size
    fontweight='bold',  # Make font bold
    ha='center'
)

plt.grid(True)
plt.show()
