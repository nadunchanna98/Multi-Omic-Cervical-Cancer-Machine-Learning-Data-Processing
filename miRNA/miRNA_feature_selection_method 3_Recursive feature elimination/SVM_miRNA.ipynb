# %%
import pandas as pd

# %%
file_path = "C:/Users/nadun/Desktop/Data_Preprosessing_miRNA_HiSeq_gene.csv" 
df = pd.read_csv(file_path)

# %%
df
# Out:
#             SampleID  histological_type  MIMAT0000765  MIMAT0000764  \
# 0    TCGA-BI-A0VS-01                  0      0.412676      0.234523
# 1    TCGA-C5-A1MP-01                  0      0.332881      0.285390
# 2    TCGA-C5-A2M1-01                  1      0.487423      0.482132
# 3    TCGA-VS-A94Z-01                  0      0.318592      0.551453
# 4    TCGA-C5-A2M2-01                  1      0.594883      0.638666
# ..               ...                ...           ...           ...
# 299  TCGA-EA-A3HU-01                  0      0.236040      0.763625
# 300  TCGA-WL-A834-01                  0      0.357760      0.367862
# 301  TCGA-VS-A8EC-01                  0      0.697154      0.442425
# 302  TCGA-ZJ-AAXA-01                  0      0.283158      0.169528
# 303  TCGA-C5-A7CM-01                  1      0.379568      0.602023
#
#      MIMAT0000761  MIMAT0000760  MIMAT0000763  MIMAT0000762  MIMAT0004801  \
# 0        0.486516      0.683406      0.209727      0.690080      0.684106
# 1        0.209401      0.392064      0.215805      0.365511      0.407754
# 2        0.478659      0.575281      0.278825      0.406200      0.778967
# 3        0.336966      0.418413      0.388311      0.275500      0.581153
# 4        0.629775      0.600272      0.495089      0.573584      0.373874
# ..            ...           ...           ...           ...           ...
# 299      0.821156      0.868616      0.293131      0.650181      0.340509
# 300      0.547514      0.329164      0.411073      0.421059      0.332519
# 301      0.633982      0.754317      0.425059      0.827213      0.814336
# 302      0.401465      0.418699      0.273184      0.458708      0.464586
# 303      0.552459      0.477361      0.412978      0.329283      0.088827
#
#      MIMAT0004808  ...  MIMAT0004909  MIMAT0004693  MIMAT0004694  \
# 0        0.541690  ...      0.473144      0.648230      0.560659
# 1        0.487104  ...      0.621209      0.370813      0.414391
# 2        0.507400  ...      0.398459      0.556792      0.511486
# 3        0.706636  ...      0.481115      0.527729      0.727992
# 4        0.421536  ...      0.388516      0.493193      0.285916
# ..            ...  ...           ...           ...           ...
# 299      0.856783  ...      0.226240      0.832434      1.000000
# 300      0.350095  ...      0.399973      0.580465      0.331809
# 301      0.886936  ...      0.599713      0.493908      0.502921
# 302      0.092154  ...      0.510476      0.458162      0.278482
# 303      0.483027  ...      0.170284      0.304870      0.000000
#
#      MIMAT0004697  MIMAT0004673  MIMAT0004672  MIMAT0004585  MIMAT0004584  \
# 0        0.694225      0.478191      0.658248      0.545532      0.715326
# 1        0.245057      0.455777      0.403442      0.512926      0.429133
# 2        0.663908      0.755702      0.764377      0.589761      0.895005
# 3        0.655850      0.566144      0.505499      0.598856      0.659320
# 4        0.714417      0.630250      0.597119      0.467308      0.819023
# ..            ...           ...           ...           ...           ...
# 299      0.805439      0.820129      0.742673      0.859848      0.492608
# 300      0.631820      0.510831      0.591734      0.408373      0.588792
# 301      0.745486      0.417547      0.662996      0.303265      0.470317
# 302      0.425477      0.413978      0.602164      0.154091      0.744570
# 303      0.592703      0.788023      0.771430      0.734425      0.631786
#
#      MIMAT0004586  MIMAT0003298
# 0        0.574467      0.528334
# 1        0.560717      0.391146
# 2        0.633164      0.739321
# 3        0.576727      0.546617
# 4        0.871465      0.634001
# ..            ...           ...
# 299      0.753517      0.905557
# 300      0.544816      0.281708
# 301      0.604966      0.703511
# 302      0.517015      0.483252
# 303      0.618848      0.463249
#
# [304 rows x 276 columns]

# %%
column_values = df['histological_type']
total_count = column_values.count()
value_counts = column_values.value_counts()
value_counts
# Out:
# histological_type
# 0    257
# 1     47
# Name: count, dtype: int64

# %%
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC  # Import SVM
from sklearn.feature_selection import RFE
from sklearn.model_selection import cross_val_score
from sklearn.utils import resample
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Assuming df is your DataFrame

svm_classifier = SVC(kernel='linear', random_state=42)  # Use linear kernel for simplicity
K = np.arange(start=5, stop=90, step=5)
iterations = 10  # Number of iterations
feature_numbers = []
mean_accuracies = []

# Loop through the selected features
for idx, k in enumerate(K):
    accuracies_iter = []

    for iteration in range(iterations):
        # Feature selection using RFE
        X = df.iloc[:, 2:276]
        y = df["histological_type"]

        selector = RFE(svm_classifier, n_features_to_select=k)
        X_selected = selector.fit_transform(X, y)
        selected_features = X.columns[selector.support_]

        df_selected = df[['SampleID', 'histological_type'] + list(selected_features)].copy()

        # Undersample the dataset with a random seed between 0 and 100 for each iteration
        undersample_seed = np.random.randint(101)  # Generate a random seed between 0 and 100
        cervical_squamous_df = df_selected[df_selected['histological_type'] == 0]
        if len(cervical_squamous_df) > 47:
            cervical_squamous_df = resample(cervical_squamous_df, n_samples=47, random_state=undersample_seed)
        adeno_df = df_selected[df_selected['histological_type'] == 1]
        df2 = pd.concat([cervical_squamous_df, adeno_df])

        # Split the data into features (X) and target (y)
        X_selected = df2.iloc[:, 2:]
        y_selected = df2["histological_type"]

        # Perform 5-fold cross-validation
        scores = cross_val_score(svm_classifier, X_selected, y_selected, cv=5, scoring='accuracy')

        # Calculate average accuracy across folds
        accuracy = np.mean(scores)
        accuracies_iter.append(accuracy)

        # Print update after each iteration
        print(f"Iteration {iteration + 1}/{iterations} for k={k}: Accuracy = {accuracy:.4f}, Undersample Seed = {undersample_seed}")

    # Store the feature number and its mean accuracy across iterations
    feature_numbers.append(k)
    mean_accuracies.append(np.mean(accuracies_iter))

    # Print update after each feature number
    print(f"Finished iteration for k={k}: Mean Accuracy = {mean_accuracies[-1]:.4f}\n")

# Plotting the feature numbers and their corresponding mean accuracies
plt.figure(figsize=(10, 6))
plt.plot(feature_numbers, mean_accuracies, marker='o', linestyle='-')

# Annotate each point with its accuracy
for i in range(len(feature_numbers)):
    plt.text(feature_numbers[i], mean_accuracies[i], f'{mean_accuracies[i]:.4f}', fontsize=8, ha='right', va='bottom')

plt.title('Mean Accuracy for each Feature Number (RFE + Undersampling + SVM with 5-Fold Cross-Validation)')
plt.xlabel('Number of Features')
plt.ylabel('Mean Accuracy')
plt.grid(True)
plt.show()
# Out:
# Iteration 1/10 for k=5: Accuracy = 0.9257, Undersample Seed = 63
# Iteration 2/10 for k=5: Accuracy = 0.9146, Undersample Seed = 39
# Iteration 3/10 for k=5: Accuracy = 0.9257, Undersample Seed = 99
# Iteration 4/10 for k=5: Accuracy = 0.8930, Undersample Seed = 2
# Iteration 5/10 for k=5: Accuracy = 0.9146, Undersample Seed = 58
# Iteration 6/10 for k=5: Accuracy = 0.9468, Undersample Seed = 76
# Iteration 7/10 for k=5: Accuracy = 0.8819, Undersample Seed = 84
# Iteration 8/10 for k=5: Accuracy = 0.9363, Undersample Seed = 81
# Iteration 9/10 for k=5: Accuracy = 0.9468, Undersample Seed = 18
# Iteration 10/10 for k=5: Accuracy = 0.9462, Undersample Seed = 10
# Finished iteration for k=5: Mean Accuracy = 0.9232
#
# Iteration 1/10 for k=10: Accuracy = 0.9041, Undersample Seed = 40
# Iteration 2/10 for k=10: Accuracy = 0.9251, Undersample Seed = 65
# Iteration 3/10 for k=10: Accuracy = 0.9357, Undersample Seed = 66
# Iteration 4/10 for k=10: Accuracy = 0.9462, Undersample Seed = 33
# Iteration 5/10 for k=10: Accuracy = 0.9146, Undersample Seed = 87
# Iteration 6/10 for k=10: Accuracy = 0.8930, Undersample Seed = 19
# Iteration 7/10 for k=10: Accuracy = 0.8830, Undersample Seed = 37
# Iteration 8/10 for k=10: Accuracy = 0.9146, Undersample Seed = 87
# Iteration 9/10 for k=10: Accuracy = 0.9257, Undersample Seed = 90
# Iteration 10/10 for k=10: Accuracy = 0.9468, Undersample Seed = 0
# Finished iteration for k=10: Mean Accuracy = 0.9189
#
# Iteration 1/10 for k=15: Accuracy = 0.9462, Undersample Seed = 49
# Iteration 2/10 for k=15: Accuracy = 0.9468, Undersample Seed = 22
# Iteration 3/10 for k=15: Accuracy = 0.9047, Undersample Seed = 17
# Iteration 4/10 for k=15: Accuracy = 0.9257, Undersample Seed = 58
# Iteration 5/10 for k=15: Accuracy = 0.9363, Undersample Seed = 55
# Iteration 6/10 for k=15: Accuracy = 0.9363, Undersample Seed = 44
# Iteration 7/10 for k=15: Accuracy = 0.9257, Undersample Seed = 91
# Iteration 8/10 for k=15: Accuracy = 0.9357, Undersample Seed = 78
# Iteration 9/10 for k=15: Accuracy = 0.9468, Undersample Seed = 54
# Iteration 10/10 for k=15: Accuracy = 0.9573, Undersample Seed = 11
# Finished iteration for k=15: Mean Accuracy = 0.9361
#
# Iteration 1/10 for k=20: Accuracy = 0.9035, Undersample Seed = 84
# Iteration 2/10 for k=20: Accuracy = 0.9251, Undersample Seed = 25
# Iteration 3/10 for k=20: Accuracy = 0.9363, Undersample Seed = 1
# Iteration 4/10 for k=20: Accuracy = 0.9363, Undersample Seed = 48
# Iteration 5/10 for k=20: Accuracy = 0.9251, Undersample Seed = 65
# Iteration 6/10 for k=20: Accuracy = 0.9468, Undersample Seed = 33
# Iteration 7/10 for k=20: Accuracy = 0.9251, Undersample Seed = 25
# Iteration 8/10 for k=20: Accuracy = 0.9257, Undersample Seed = 13
# Iteration 9/10 for k=20: Accuracy = 0.9474, Undersample Seed = 26
# Iteration 10/10 for k=20: Accuracy = 0.9251, Undersample Seed = 91
# Finished iteration for k=20: Mean Accuracy = 0.9296
#
# Iteration 1/10 for k=25: Accuracy = 0.9889, Undersample Seed = 56
# Iteration 2/10 for k=25: Accuracy = 0.9251, Undersample Seed = 99
# Iteration 3/10 for k=25: Accuracy = 0.9573, Undersample Seed = 43
# Iteration 4/10 for k=25: Accuracy = 0.9678, Undersample Seed = 28
# Iteration 5/10 for k=25: Accuracy = 0.9684, Undersample Seed = 33
# Iteration 6/10 for k=25: Accuracy = 0.9363, Undersample Seed = 30
# Iteration 7/10 for k=25: Accuracy = 0.9047, Undersample Seed = 72
# Iteration 8/10 for k=25: Accuracy = 0.9573, Undersample Seed = 42
# Iteration 9/10 for k=25: Accuracy = 0.9678, Undersample Seed = 95
# Iteration 10/10 for k=25: Accuracy = 0.9684, Undersample Seed = 94
# Finished iteration for k=25: Mean Accuracy = 0.9542
#
# Iteration 1/10 for k=30: Accuracy = 0.9462, Undersample Seed = 47
# Iteration 2/10 for k=30: Accuracy = 0.9468, Undersample Seed = 64
# Iteration 3/10 for k=30: Accuracy = 0.9146, Undersample Seed = 25
# Iteration 4/10 for k=30: Accuracy = 0.9573, Undersample Seed = 22
# Iteration 5/10 for k=30: Accuracy = 0.9474, Undersample Seed = 17
# Iteration 6/10 for k=30: Accuracy = 0.9573, Undersample Seed = 52
# Iteration 7/10 for k=30: Accuracy = 0.9363, Undersample Seed = 31
# Iteration 8/10 for k=30: Accuracy = 0.9146, Undersample Seed = 25
# Iteration 9/10 for k=30: Accuracy = 0.9889, Undersample Seed = 96
# Iteration 10/10 for k=30: Accuracy = 0.9678, Undersample Seed = 57
# Finished iteration for k=30: Mean Accuracy = 0.9477
#
# Iteration 1/10 for k=35: Accuracy = 0.9468, Undersample Seed = 12
# Iteration 2/10 for k=35: Accuracy = 0.9789, Undersample Seed = 97
# Iteration 3/10 for k=35: Accuracy = 0.9363, Undersample Seed = 19
# Iteration 4/10 for k=35: Accuracy = 0.9363, Undersample Seed = 19
# Iteration 5/10 for k=35: Accuracy = 0.9474, Undersample Seed = 48
# Iteration 6/10 for k=35: Accuracy = 0.9263, Undersample Seed = 72
# Iteration 7/10 for k=35: Accuracy = 0.9567, Undersample Seed = 69
# Iteration 8/10 for k=35: Accuracy = 0.9579, Undersample Seed = 27
# Iteration 9/10 for k=35: Accuracy = 0.9567, Undersample Seed = 66
# Iteration 10/10 for k=35: Accuracy = 0.9573, Undersample Seed = 68
# Finished iteration for k=35: Mean Accuracy = 0.9501
#
# Iteration 1/10 for k=40: Accuracy = 0.9784, Undersample Seed = 57
# Iteration 2/10 for k=40: Accuracy = 0.9246, Undersample Seed = 46
# Iteration 3/10 for k=40: Accuracy = 0.9357, Undersample Seed = 0
# Iteration 4/10 for k=40: Accuracy = 0.9251, Undersample Seed = 9
# Iteration 5/10 for k=40: Accuracy = 0.9567, Undersample Seed = 51
# Iteration 6/10 for k=40: Accuracy = 0.9357, Undersample Seed = 0
# Iteration 7/10 for k=40: Accuracy = 0.9363, Undersample Seed = 67
# Iteration 8/10 for k=40: Accuracy = 0.9152, Undersample Seed = 37
# Iteration 9/10 for k=40: Accuracy = 0.9462, Undersample Seed = 68
# Iteration 10/10 for k=40: Accuracy = 0.9363, Undersample Seed = 63
# Finished iteration for k=40: Mean Accuracy = 0.9390
#
# Iteration 1/10 for k=45: Accuracy = 0.9363, Undersample Seed = 19
# Iteration 2/10 for k=45: Accuracy = 0.9468, Undersample Seed = 82
# Iteration 3/10 for k=45: Accuracy = 0.9789, Undersample Seed = 33
# Iteration 4/10 for k=45: Accuracy = 0.9363, Undersample Seed = 91
# Iteration 5/10 for k=45: Accuracy = 0.9351, Undersample Seed = 75
# Iteration 6/10 for k=45: Accuracy = 0.9567, Undersample Seed = 76
# Iteration 7/10 for k=45: Accuracy = 0.9573, Undersample Seed = 59
# Iteration 8/10 for k=45: Accuracy = 0.9363, Undersample Seed = 89
# Iteration 9/10 for k=45: Accuracy = 0.9895, Undersample Seed = 97
# Iteration 10/10 for k=45: Accuracy = 0.9789, Undersample Seed = 100
# Finished iteration for k=45: Mean Accuracy = 0.9552
#
# Iteration 1/10 for k=50: Accuracy = 0.9573, Undersample Seed = 92
# Iteration 2/10 for k=50: Accuracy = 0.9468, Undersample Seed = 72
# Iteration 3/10 for k=50: Accuracy = 0.9140, Undersample Seed = 95
# Iteration 4/10 for k=50: Accuracy = 0.9789, Undersample Seed = 71
# Iteration 5/10 for k=50: Accuracy = 0.9573, Undersample Seed = 20
# Iteration 6/10 for k=50: Accuracy = 0.9573, Undersample Seed = 49
# Iteration 7/10 for k=50: Accuracy = 0.9257, Undersample Seed = 65
# Iteration 8/10 for k=50: Accuracy = 0.9678, Undersample Seed = 35
# Iteration 9/10 for k=50: Accuracy = 0.9567, Undersample Seed = 56
# Iteration 10/10 for k=50: Accuracy = 0.9567, Undersample Seed = 56
# Finished iteration for k=50: Mean Accuracy = 0.9519
#
# Iteration 1/10 for k=55: Accuracy = 0.9363, Undersample Seed = 1
# Iteration 2/10 for k=55: Accuracy = 0.9573, Undersample Seed = 54
# Iteration 3/10 for k=55: Accuracy = 0.9357, Undersample Seed = 30
# Iteration 4/10 for k=55: Accuracy = 0.9363, Undersample Seed = 85
# Iteration 5/10 for k=55: Accuracy = 0.9140, Undersample Seed = 95
# Iteration 6/10 for k=55: Accuracy = 0.9468, Undersample Seed = 12
# Iteration 7/10 for k=55: Accuracy = 0.9152, Undersample Seed = 61
# Iteration 8/10 for k=55: Accuracy = 0.9895, Undersample Seed = 23
# Iteration 9/10 for k=55: Accuracy = 0.9351, Undersample Seed = 55
# Iteration 10/10 for k=55: Accuracy = 0.9573, Undersample Seed = 81
# Finished iteration for k=55: Mean Accuracy = 0.9423
#
# Iteration 1/10 for k=60: Accuracy = 0.9567, Undersample Seed = 7
# Iteration 2/10 for k=60: Accuracy = 0.9363, Undersample Seed = 74
# Iteration 3/10 for k=60: Accuracy = 0.9152, Undersample Seed = 32
# Iteration 4/10 for k=60: Accuracy = 0.9047, Undersample Seed = 91
# Iteration 5/10 for k=60: Accuracy = 0.9363, Undersample Seed = 89
# Iteration 6/10 for k=60: Accuracy = 0.9468, Undersample Seed = 99
# Iteration 7/10 for k=60: Accuracy = 0.9257, Undersample Seed = 14
# Iteration 8/10 for k=60: Accuracy = 0.9468, Undersample Seed = 48
# Iteration 9/10 for k=60: Accuracy = 0.9784, Undersample Seed = 42
# Iteration 10/10 for k=60: Accuracy = 0.9678, Undersample Seed = 20
# Finished iteration for k=60: Mean Accuracy = 0.9415
#
# Iteration 1/10 for k=65: Accuracy = 0.9678, Undersample Seed = 71
# Iteration 2/10 for k=65: Accuracy = 0.9363, Undersample Seed = 63
# Iteration 3/10 for k=65: Accuracy = 0.9573, Undersample Seed = 94
# Iteration 4/10 for k=65: Accuracy = 0.9567, Undersample Seed = 3
# Iteration 5/10 for k=65: Accuracy = 0.9351, Undersample Seed = 55
# Iteration 6/10 for k=65: Accuracy = 0.9363, Undersample Seed = 64
# Iteration 7/10 for k=65: Accuracy = 0.9363, Undersample Seed = 85
# Iteration 8/10 for k=65: Accuracy = 0.9047, Undersample Seed = 37
# Iteration 9/10 for k=65: Accuracy = 0.9784, Undersample Seed = 33
# Iteration 10/10 for k=65: Accuracy = 0.9363, Undersample Seed = 67
# Finished iteration for k=65: Mean Accuracy = 0.9445
#
# Iteration 1/10 for k=70: Accuracy = 0.9468, Undersample Seed = 1
# Iteration 2/10 for k=70: Accuracy = 0.9363, Undersample Seed = 52
# Iteration 3/10 for k=70: Accuracy = 0.9363, Undersample Seed = 31
# Iteration 4/10 for k=70: Accuracy = 0.9573, Undersample Seed = 83
# Iteration 5/10 for k=70: Accuracy = 0.9573, Undersample Seed = 19
# Iteration 6/10 for k=70: Accuracy = 0.9567, Undersample Seed = 66
# Iteration 7/10 for k=70: Accuracy = 0.9573, Undersample Seed = 49
# Iteration 8/10 for k=70: Accuracy = 0.9678, Undersample Seed = 71
# Iteration 9/10 for k=70: Accuracy = 0.9152, Undersample Seed = 2
# Iteration 10/10 for k=70: Accuracy = 0.9363, Undersample Seed = 86
# Finished iteration for k=70: Mean Accuracy = 0.9467
#
# Iteration 1/10 for k=75: Accuracy = 0.9357, Undersample Seed = 69
# Iteration 2/10 for k=75: Accuracy = 0.9468, Undersample Seed = 88
# Iteration 3/10 for k=75: Accuracy = 0.9041, Undersample Seed = 17
# Iteration 4/10 for k=75: Accuracy = 0.9468, Undersample Seed = 64
# Iteration 5/10 for k=75: Accuracy = 0.9257, Undersample Seed = 73
# Iteration 6/10 for k=75: Accuracy = 0.9468, Undersample Seed = 88
# Iteration 7/10 for k=75: Accuracy = 0.9573, Undersample Seed = 18
# Iteration 8/10 for k=75: Accuracy = 0.9573, Undersample Seed = 83
# Iteration 9/10 for k=75: Accuracy = 0.9678, Undersample Seed = 45
# Iteration 10/10 for k=75: Accuracy = 0.9678, Undersample Seed = 41
# Finished iteration for k=75: Mean Accuracy = 0.9456
#
# Iteration 1/10 for k=80: Accuracy = 0.9357, Undersample Seed = 26
# Iteration 2/10 for k=80: Accuracy = 0.9573, Undersample Seed = 5
# Iteration 3/10 for k=80: Accuracy = 0.9573, Undersample Seed = 90
# Iteration 4/10 for k=80: Accuracy = 0.9573, Undersample Seed = 96
# Iteration 5/10 for k=80: Accuracy = 0.9567, Undersample Seed = 7
# Iteration 6/10 for k=80: Accuracy = 0.9363, Undersample Seed = 24
# Iteration 7/10 for k=80: Accuracy = 0.9257, Undersample Seed = 80
# Iteration 8/10 for k=80: Accuracy = 0.9468, Undersample Seed = 1
# Iteration 9/10 for k=80: Accuracy = 0.9567, Undersample Seed = 56
# Iteration 10/10 for k=80: Accuracy = 0.9468, Undersample Seed = 29
# Finished iteration for k=80: Mean Accuracy = 0.9477
#
# Iteration 1/10 for k=85: Accuracy = 0.9047, Undersample Seed = 44
# Iteration 2/10 for k=85: Accuracy = 0.9257, Undersample Seed = 91
# Iteration 3/10 for k=85: Accuracy = 0.9573, Undersample Seed = 96
# Iteration 4/10 for k=85: Accuracy = 0.9251, Undersample Seed = 21
# Iteration 5/10 for k=85: Accuracy = 0.9363, Undersample Seed = 61
# Iteration 6/10 for k=85: Accuracy = 0.9257, Undersample Seed = 93
# Iteration 7/10 for k=85: Accuracy = 0.9363, Undersample Seed = 0
# Iteration 8/10 for k=85: Accuracy = 0.9468, Undersample Seed = 19
# Iteration 9/10 for k=85: Accuracy = 0.9146, Undersample Seed = 16
# Iteration 10/10 for k=85: Accuracy = 0.9363, Undersample Seed = 31
# Finished iteration for k=85: Mean Accuracy = 0.9309
