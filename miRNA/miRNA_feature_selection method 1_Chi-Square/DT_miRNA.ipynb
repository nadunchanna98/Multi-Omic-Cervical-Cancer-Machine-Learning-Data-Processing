# %%
import pandas as pd

# %%
file_path = "G:/academic/sem 7/Research - Multi-omic data in the cervical cancer studies/notebooks/New folder/miRNA/miRNA_feature_selection method 1/Data_Preprosessing_miRNA_HiSeq_gene.csv" 
df = pd.read_csv(file_path)

# %%
df
# Out:
#             SampleID  histological_type  MIMAT0000765  MIMAT0000764  \
# 0    TCGA-BI-A0VS-01                  0      0.412676      0.234523
# 1    TCGA-C5-A1MP-01                  0      0.332881      0.285390
# 2    TCGA-C5-A2M1-01                  1      0.487423      0.482132
# 3    TCGA-VS-A94Z-01                  0      0.318592      0.551453
# 4    TCGA-C5-A2M2-01                  1      0.594883      0.638666
# ..               ...                ...           ...           ...
# 299  TCGA-EA-A3HU-01                  0      0.236040      0.763625
# 300  TCGA-WL-A834-01                  0      0.357760      0.367862
# 301  TCGA-VS-A8EC-01                  0      0.697154      0.442425
# 302  TCGA-ZJ-AAXA-01                  0      0.283158      0.169528
# 303  TCGA-C5-A7CM-01                  1      0.379568      0.602023
#
#      MIMAT0000761  MIMAT0000760  MIMAT0000763  MIMAT0000762  MIMAT0004801  \
# 0        0.486516      0.683406      0.209727      0.690080      0.684106
# 1        0.209401      0.392064      0.215805      0.365511      0.407754
# 2        0.478659      0.575281      0.278825      0.406200      0.778967
# 3        0.336966      0.418413      0.388311      0.275500      0.581153
# 4        0.629775      0.600272      0.495089      0.573584      0.373874
# ..            ...           ...           ...           ...           ...
# 299      0.821156      0.868616      0.293131      0.650181      0.340509
# 300      0.547514      0.329164      0.411073      0.421059      0.332519
# 301      0.633982      0.754317      0.425059      0.827213      0.814336
# 302      0.401465      0.418699      0.273184      0.458708      0.464586
# 303      0.552459      0.477361      0.412978      0.329283      0.088827
#
#      MIMAT0004808  ...  MIMAT0004909  MIMAT0004693  MIMAT0004694  \
# 0        0.541690  ...      0.473144      0.648230      0.560659
# 1        0.487104  ...      0.621209      0.370813      0.414391
# 2        0.507400  ...      0.398459      0.556792      0.511486
# 3        0.706636  ...      0.481115      0.527729      0.727992
# 4        0.421536  ...      0.388516      0.493193      0.285916
# ..            ...  ...           ...           ...           ...
# 299      0.856783  ...      0.226240      0.832434      1.000000
# 300      0.350095  ...      0.399973      0.580465      0.331809
# 301      0.886936  ...      0.599713      0.493908      0.502921
# 302      0.092154  ...      0.510476      0.458162      0.278482
# 303      0.483027  ...      0.170284      0.304870      0.000000
#
#      MIMAT0004697  MIMAT0004673  MIMAT0004672  MIMAT0004585  MIMAT0004584  \
# 0        0.694225      0.478191      0.658248      0.545532      0.715326
# 1        0.245057      0.455777      0.403442      0.512926      0.429133
# 2        0.663908      0.755702      0.764377      0.589761      0.895005
# 3        0.655850      0.566144      0.505499      0.598856      0.659320
# 4        0.714417      0.630250      0.597119      0.467308      0.819023
# ..            ...           ...           ...           ...           ...
# 299      0.805439      0.820129      0.742673      0.859848      0.492608
# 300      0.631820      0.510831      0.591734      0.408373      0.588792
# 301      0.745486      0.417547      0.662996      0.303265      0.470317
# 302      0.425477      0.413978      0.602164      0.154091      0.744570
# 303      0.592703      0.788023      0.771430      0.734425      0.631786
#
#      MIMAT0004586  MIMAT0003298
# 0        0.574467      0.528334
# 1        0.560717      0.391146
# 2        0.633164      0.739321
# 3        0.576727      0.546617
# 4        0.871465      0.634001
# ..            ...           ...
# 299      0.753517      0.905557
# 300      0.544816      0.281708
# 301      0.604966      0.703511
# 302      0.517015      0.483252
# 303      0.618848      0.463249
#
# [304 rows x 276 columns]

# %%
column_values = df['histological_type']
total_count = column_values.count()
value_counts = column_values.value_counts()
value_counts
# Out:
# histological_type
# 0    257
# 1     47
# Name: count, dtype: int64

# %%
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_selection import chi2
from sklearn.model_selection import cross_val_score
from sklearn.utils import resample
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Assuming df is your DataFrame

dt_classifier = DecisionTreeClassifier(random_state=42)  # Use Decision Tree
K = np.arange(start=5, stop=90, step=5)
iterations = 10  # Number of iterations
feature_numbers = []
mean_accuracies = []
std_accuracies = []

# Loop through the selected features
for idx, k in enumerate(K):
    accuracies_iter = []

    for iteration in range(iterations):
        # Feature selection using Chi-squared
        X = df.iloc[:, 2:276]
        y = df["histological_type"]

        # Calculate chi-squared scores for each feature
        chi2_scores, _ = chi2(X, y)

        # Select the top k features based on chi-squared scores
        selected_features_idx = np.argsort(chi2_scores)[-k:]
        selected_features = X.columns[selected_features_idx]

        df_selected = df[['SampleID', 'histological_type'] + list(selected_features)].copy()

        # Undersample the dataset with a random seed between 0 and 100 for each iteration
        undersample_seed = np.random.randint(101)  # Generate a random seed between 0 and 100
        cervical_squamous_df = df_selected[df_selected['histological_type'] == 0]
        if len(cervical_squamous_df) > 47:
            cervical_squamous_df = resample(cervical_squamous_df, n_samples=47, random_state=undersample_seed)
        adeno_df = df_selected[df_selected['histological_type'] == 1]
        df2 = pd.concat([cervical_squamous_df, adeno_df])

        # Split the data into features (X) and target (y)
        X_selected = df2.iloc[:, 2:]
        y_selected = df2["histological_type"]

        # Perform 5-fold cross-validation
        scores = cross_val_score(dt_classifier, X_selected, y_selected, cv=5, scoring='accuracy')

        # Calculate average accuracy and standard deviation across folds
        accuracy = np.mean(scores)
        std_accuracy = np.std(scores)
        accuracies_iter.append(accuracy)

        # Print update after each iteration
        print(f"Iteration {iteration + 1}/{iterations} for k={k}: Accuracy = {accuracy:.4f}, Std Dev = {std_accuracy:.4f}, Undersample Seed = {undersample_seed}")

    # Store the feature number and its mean accuracy and standard deviation across iterations
    feature_numbers.append(k)
    mean_accuracies.append(np.mean(accuracies_iter))
    std_accuracies.append(np.std(accuracies_iter))

    # Print update after each feature number
    print(f"Finished iteration for k={k}: Mean Accuracy = {mean_accuracies[-1]:.4f}, Mean Std Dev = {std_accuracies[-1]:.4f}\n")

# Increase the width and height of the graph
plt.figure(figsize=(10, 6))

# Plotting the feature numbers, mean accuracies, and standard deviations
plt.errorbar(feature_numbers, mean_accuracies, yerr=std_accuracies, fmt='o-', label='Accuracy', capsize=5, markersize=8)

# Annotate each point with its accuracy and std inside a colored box
for i in range(len(feature_numbers)):
    box_properties = dict(boxstyle='round', facecolor='lightgray', alpha=0.7)
    plt.text(
        feature_numbers[i],
        mean_accuracies[i],
        f'{mean_accuracies[i]:.4f}\n±{std_accuracies[i]:.4f}',
        fontsize=8,
        ha='right',
        va='bottom',
        bbox=box_properties
    )

plt.title('Mean Accuracy with Std Dev for each Feature Number (Chi-squared + Undersampling + Decision Tree with 5-Fold Cross-Validation)')
plt.xlabel('Number of Features')
plt.ylabel('Mean Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Iteration 1/10 for k=5: Accuracy = 0.8187, Std Dev = 0.0798, Undersample Seed = 70
# Iteration 2/10 for k=5: Accuracy = 0.8930, Std Dev = 0.0593, Undersample Seed = 50
# Iteration 3/10 for k=5: Accuracy = 0.8936, Std Dev = 0.0745, Undersample Seed = 0
# Iteration 4/10 for k=5: Accuracy = 0.9029, Std Dev = 0.0658, Undersample Seed = 23
# Iteration 5/10 for k=5: Accuracy = 0.8515, Std Dev = 0.0606, Undersample Seed = 30
# Iteration 6/10 for k=5: Accuracy = 0.8830, Std Dev = 0.0697, Undersample Seed = 5
# Iteration 7/10 for k=5: Accuracy = 0.7971, Std Dev = 0.0553, Undersample Seed = 73
# Iteration 8/10 for k=5: Accuracy = 0.8614, Std Dev = 0.0545, Undersample Seed = 31
# Iteration 9/10 for k=5: Accuracy = 0.9251, Std Dev = 0.0544, Undersample Seed = 49
# Iteration 10/10 for k=5: Accuracy = 0.8924, Std Dev = 0.0703, Undersample Seed = 93
# Finished iteration for k=5: Mean Accuracy = 0.8719, Mean Std Dev = 0.0377
#
# Iteration 1/10 for k=10: Accuracy = 0.9041, Std Dev = 0.0218, Undersample Seed = 8
# Iteration 2/10 for k=10: Accuracy = 0.8520, Std Dev = 0.0766, Undersample Seed = 31
# Iteration 3/10 for k=10: Accuracy = 0.8614, Std Dev = 0.0545, Undersample Seed = 78
# Iteration 4/10 for k=10: Accuracy = 0.8614, Std Dev = 0.0274, Undersample Seed = 10
# Iteration 5/10 for k=10: Accuracy = 0.8509, Std Dev = 0.0618, Undersample Seed = 48
# Iteration 6/10 for k=10: Accuracy = 0.8830, Std Dev = 0.0206, Undersample Seed = 77
# Iteration 7/10 for k=10: Accuracy = 0.9257, Std Dev = 0.0253, Undersample Seed = 20
# Iteration 8/10 for k=10: Accuracy = 0.9047, Std Dev = 0.0610, Undersample Seed = 34
# Iteration 9/10 for k=10: Accuracy = 0.8725, Std Dev = 0.0533, Undersample Seed = 83
# Iteration 10/10 for k=10: Accuracy = 0.7877, Std Dev = 0.0306, Undersample Seed = 72
# Finished iteration for k=10: Mean Accuracy = 0.8704, Mean Std Dev = 0.0364
#
# Iteration 1/10 for k=15: Accuracy = 0.8503, Std Dev = 0.0432, Undersample Seed = 46
# Iteration 2/10 for k=15: Accuracy = 0.9146, Std Dev = 0.0268, Undersample Seed = 59
# Iteration 3/10 for k=15: Accuracy = 0.8515, Std Dev = 0.0606, Undersample Seed = 61
# Iteration 4/10 for k=15: Accuracy = 0.8830, Std Dev = 0.0391, Undersample Seed = 31
# Iteration 5/10 for k=15: Accuracy = 0.8725, Std Dev = 0.0533, Undersample Seed = 39
# Iteration 6/10 for k=15: Accuracy = 0.8936, Std Dev = 0.0334, Undersample Seed = 83
# Iteration 7/10 for k=15: Accuracy = 0.8830, Std Dev = 0.0391, Undersample Seed = 82
# Iteration 8/10 for k=15: Accuracy = 0.9363, Std Dev = 0.0392, Undersample Seed = 24
# Iteration 9/10 for k=15: Accuracy = 0.8409, Std Dev = 0.0458, Undersample Seed = 19
# Iteration 10/10 for k=15: Accuracy = 0.8830, Std Dev = 0.0904, Undersample Seed = 79
# Finished iteration for k=15: Mean Accuracy = 0.8809, Mean Std Dev = 0.0280
#
# Iteration 1/10 for k=20: Accuracy = 0.8614, Std Dev = 0.0431, Undersample Seed = 38
# Iteration 2/10 for k=20: Accuracy = 0.9345, Std Dev = 0.0818, Undersample Seed = 92
# Iteration 3/10 for k=20: Accuracy = 0.8819, Std Dev = 0.0651, Undersample Seed = 46
# Iteration 4/10 for k=20: Accuracy = 0.9041, Std Dev = 0.0398, Undersample Seed = 60
# Iteration 5/10 for k=20: Accuracy = 0.9041, Std Dev = 0.0218, Undersample Seed = 6
# Iteration 6/10 for k=20: Accuracy = 0.8719, Std Dev = 0.0281, Undersample Seed = 17
# Iteration 7/10 for k=20: Accuracy = 0.9257, Std Dev = 0.0535, Undersample Seed = 15
# Iteration 8/10 for k=20: Accuracy = 0.8719, Std Dev = 0.0281, Undersample Seed = 17
# Iteration 9/10 for k=20: Accuracy = 0.9251, Std Dev = 0.0430, Undersample Seed = 28
# Iteration 10/10 for k=20: Accuracy = 0.9146, Std Dev = 0.0428, Undersample Seed = 54
# Finished iteration for k=20: Mean Accuracy = 0.8995, Mean Std Dev = 0.0247
#
# Iteration 1/10 for k=25: Accuracy = 0.9462, Std Dev = 0.0352, Undersample Seed = 76
# Iteration 2/10 for k=25: Accuracy = 0.8725, Std Dev = 0.0711, Undersample Seed = 79
# Iteration 3/10 for k=25: Accuracy = 0.9135, Std Dev = 0.0756, Undersample Seed = 23
# Iteration 4/10 for k=25: Accuracy = 0.8515, Std Dev = 0.0900, Undersample Seed = 31
# Iteration 5/10 for k=25: Accuracy = 0.9363, Std Dev = 0.0613, Undersample Seed = 66
# Iteration 6/10 for k=25: Accuracy = 0.8614, Std Dev = 0.0720, Undersample Seed = 19
# Iteration 7/10 for k=25: Accuracy = 0.9047, Std Dev = 0.0388, Undersample Seed = 20
# Iteration 8/10 for k=25: Accuracy = 0.9363, Std Dev = 0.0392, Undersample Seed = 55
# Iteration 9/10 for k=25: Accuracy = 0.8515, Std Dev = 0.0767, Undersample Seed = 47
# Iteration 10/10 for k=25: Accuracy = 0.8936, Std Dev = 0.0942, Undersample Seed = 80
# Finished iteration for k=25: Mean Accuracy = 0.8967, Mean Std Dev = 0.0344
#
# Iteration 1/10 for k=30: Accuracy = 0.9135, Std Dev = 0.0756, Undersample Seed = 97
# Iteration 2/10 for k=30: Accuracy = 0.8415, Std Dev = 0.0736, Undersample Seed = 17
# Iteration 3/10 for k=30: Accuracy = 0.9146, Std Dev = 0.0268, Undersample Seed = 59
# Iteration 4/10 for k=30: Accuracy = 0.9257, Std Dev = 0.0712, Undersample Seed = 45
# Iteration 5/10 for k=30: Accuracy = 0.8620, Std Dev = 0.0709, Undersample Seed = 53
# Iteration 6/10 for k=30: Accuracy = 0.9363, Std Dev = 0.0392, Undersample Seed = 50
# Iteration 7/10 for k=30: Accuracy = 0.9257, Std Dev = 0.0712, Undersample Seed = 45
# Iteration 8/10 for k=30: Accuracy = 0.8515, Std Dev = 0.0507, Undersample Seed = 64
# Iteration 9/10 for k=30: Accuracy = 0.8515, Std Dev = 0.0606, Undersample Seed = 32
# Iteration 10/10 for k=30: Accuracy = 0.8825, Std Dev = 0.0414, Undersample Seed = 74
# Finished iteration for k=30: Mean Accuracy = 0.8905, Mean Std Dev = 0.0347
#
# Iteration 1/10 for k=35: Accuracy = 0.8515, Std Dev = 0.0606, Undersample Seed = 79
# Iteration 2/10 for k=35: Accuracy = 0.8520, Std Dev = 0.0766, Undersample Seed = 30
# Iteration 3/10 for k=35: Accuracy = 0.8199, Std Dev = 0.0618, Undersample Seed = 77
# Iteration 4/10 for k=35: Accuracy = 0.8725, Std Dev = 0.1270, Undersample Seed = 9
# Iteration 5/10 for k=35: Accuracy = 0.9035, Std Dev = 0.0856, Undersample Seed = 47
# Iteration 6/10 for k=35: Accuracy = 0.8199, Std Dev = 0.0618, Undersample Seed = 77
# Iteration 7/10 for k=35: Accuracy = 0.9023, Std Dev = 0.0960, Undersample Seed = 3
# Iteration 8/10 for k=35: Accuracy = 0.9023, Std Dev = 0.0960, Undersample Seed = 3
# Iteration 9/10 for k=35: Accuracy = 0.9047, Std Dev = 0.0610, Undersample Seed = 17
# Iteration 10/10 for k=35: Accuracy = 0.8936, Std Dev = 0.0023, Undersample Seed = 64
# Finished iteration for k=35: Mean Accuracy = 0.8722, Mean Std Dev = 0.0326
#
# Iteration 1/10 for k=40: Accuracy = 0.9035, Std Dev = 0.0633, Undersample Seed = 25
# Iteration 2/10 for k=40: Accuracy = 0.9567, Std Dev = 0.0413, Undersample Seed = 49
# Iteration 3/10 for k=40: Accuracy = 0.7760, Std Dev = 0.0636, Undersample Seed = 73
# Iteration 4/10 for k=40: Accuracy = 0.8830, Std Dev = 0.0514, Undersample Seed = 86
# Iteration 5/10 for k=40: Accuracy = 0.8509, Std Dev = 0.0618, Undersample Seed = 2
# Iteration 6/10 for k=40: Accuracy = 0.8819, Std Dev = 0.0803, Undersample Seed = 74
# Iteration 7/10 for k=40: Accuracy = 0.8924, Std Dev = 0.0703, Undersample Seed = 3
# Iteration 8/10 for k=40: Accuracy = 0.8620, Std Dev = 0.0530, Undersample Seed = 32
# Iteration 9/10 for k=40: Accuracy = 0.8936, Std Dev = 0.0334, Undersample Seed = 42
# Iteration 10/10 for k=40: Accuracy = 0.8830, Std Dev = 0.0514, Undersample Seed = 41
# Finished iteration for k=40: Mean Accuracy = 0.8783, Mean Std Dev = 0.0433
#
# Iteration 1/10 for k=45: Accuracy = 0.8193, Std Dev = 0.1179, Undersample Seed = 34
# Iteration 2/10 for k=45: Accuracy = 0.9462, Std Dev = 0.0484, Undersample Seed = 26
# Iteration 3/10 for k=45: Accuracy = 0.9146, Std Dev = 0.0791, Undersample Seed = 79
# Iteration 4/10 for k=45: Accuracy = 0.8936, Std Dev = 0.0745, Undersample Seed = 25
# Iteration 5/10 for k=45: Accuracy = 0.9035, Std Dev = 0.0633, Undersample Seed = 41
# Iteration 6/10 for k=45: Accuracy = 0.8936, Std Dev = 0.0577, Undersample Seed = 65
# Iteration 7/10 for k=45: Accuracy = 0.9251, Std Dev = 0.0430, Undersample Seed = 33
# Iteration 8/10 for k=45: Accuracy = 0.9135, Std Dev = 0.0756, Undersample Seed = 97
# Iteration 9/10 for k=45: Accuracy = 0.8620, Std Dev = 0.1433, Undersample Seed = 0
# Iteration 10/10 for k=45: Accuracy = 0.8304, Std Dev = 0.1301, Undersample Seed = 60
# Finished iteration for k=45: Mean Accuracy = 0.8902, Mean Std Dev = 0.0388
#
# Iteration 1/10 for k=50: Accuracy = 0.8620, Std Dev = 0.0709, Undersample Seed = 5
# Iteration 2/10 for k=50: Accuracy = 0.9041, Std Dev = 0.0218, Undersample Seed = 48
# Iteration 3/10 for k=50: Accuracy = 0.9146, Std Dev = 0.0268, Undersample Seed = 99
# Iteration 4/10 for k=50: Accuracy = 0.9257, Std Dev = 0.0418, Undersample Seed = 20
# Iteration 5/10 for k=50: Accuracy = 0.7865, Std Dev = 0.0691, Undersample Seed = 73
# Iteration 6/10 for k=50: Accuracy = 0.9041, Std Dev = 0.0519, Undersample Seed = 55
# Iteration 7/10 for k=50: Accuracy = 0.8503, Std Dev = 0.0861, Undersample Seed = 91
# Iteration 8/10 for k=50: Accuracy = 0.9784, Std Dev = 0.0265, Undersample Seed = 57
# Iteration 9/10 for k=50: Accuracy = 0.8713, Std Dev = 0.0574, Undersample Seed = 29
# Iteration 10/10 for k=50: Accuracy = 0.8942, Std Dev = 0.0812, Undersample Seed = 16
# Finished iteration for k=50: Mean Accuracy = 0.8891, Mean Std Dev = 0.0485
#
# Iteration 1/10 for k=55: Accuracy = 0.8942, Std Dev = 0.0661, Undersample Seed = 27
# Iteration 2/10 for k=55: Accuracy = 0.8942, Std Dev = 0.0571, Undersample Seed = 94
# Iteration 3/10 for k=55: Accuracy = 0.8731, Std Dev = 0.0411, Undersample Seed = 64
# Iteration 4/10 for k=55: Accuracy = 0.9041, Std Dev = 0.0519, Undersample Seed = 39
# Iteration 5/10 for k=55: Accuracy = 0.8725, Std Dev = 0.0249, Undersample Seed = 8
# Iteration 6/10 for k=55: Accuracy = 0.9257, Std Dev = 0.0535, Undersample Seed = 7
# Iteration 7/10 for k=55: Accuracy = 0.9135, Std Dev = 0.0756, Undersample Seed = 97
# Iteration 8/10 for k=55: Accuracy = 0.9363, Std Dev = 0.0208, Undersample Seed = 96
# Iteration 9/10 for k=55: Accuracy = 0.8725, Std Dev = 0.0711, Undersample Seed = 53
# Iteration 10/10 for k=55: Accuracy = 0.9152, Std Dev = 0.0629, Undersample Seed = 66
# Finished iteration for k=55: Mean Accuracy = 0.9001, Mean Std Dev = 0.0217
#
# Iteration 1/10 for k=60: Accuracy = 0.8298, Std Dev = 0.1019, Undersample Seed = 72
# Iteration 2/10 for k=60: Accuracy = 0.8626, Std Dev = 0.0624, Undersample Seed = 1
# Iteration 3/10 for k=60: Accuracy = 0.7760, Std Dev = 0.1086, Undersample Seed = 70
# Iteration 4/10 for k=60: Accuracy = 0.8725, Std Dev = 0.1270, Undersample Seed = 9
# Iteration 5/10 for k=60: Accuracy = 0.9152, Std Dev = 0.0417, Undersample Seed = 15
# Iteration 6/10 for k=60: Accuracy = 0.9047, Std Dev = 0.0199, Undersample Seed = 8
# Iteration 7/10 for k=60: Accuracy = 0.8725, Std Dev = 0.1270, Undersample Seed = 9
# Iteration 8/10 for k=60: Accuracy = 0.7865, Std Dev = 0.1069, Undersample Seed = 73
# Iteration 9/10 for k=60: Accuracy = 0.9251, Std Dev = 0.0430, Undersample Seed = 89
# Iteration 10/10 for k=60: Accuracy = 0.9029, Std Dev = 0.0737, Undersample Seed = 97
# Finished iteration for k=60: Mean Accuracy = 0.8648, Mean Std Dev = 0.0496
#
# Iteration 1/10 for k=65: Accuracy = 0.8298, Std Dev = 0.1072, Undersample Seed = 0
# Iteration 2/10 for k=65: Accuracy = 0.9146, Std Dev = 0.0542, Undersample Seed = 33
# Iteration 3/10 for k=65: Accuracy = 0.8930, Std Dev = 0.0491, Undersample Seed = 19
# Iteration 4/10 for k=65: Accuracy = 0.8819, Std Dev = 0.0559, Undersample Seed = 56
# Iteration 5/10 for k=65: Accuracy = 0.8497, Std Dev = 0.0669, Undersample Seed = 67
# Iteration 6/10 for k=65: Accuracy = 0.8608, Std Dev = 0.0995, Undersample Seed = 84
# Iteration 7/10 for k=65: Accuracy = 0.8725, Std Dev = 0.0249, Undersample Seed = 77
# Iteration 8/10 for k=65: Accuracy = 0.9363, Std Dev = 0.0515, Undersample Seed = 20
# Iteration 9/10 for k=65: Accuracy = 0.9041, Std Dev = 0.0398, Undersample Seed = 16
# Iteration 10/10 for k=65: Accuracy = 0.8620, Std Dev = 0.0244, Undersample Seed = 10
# Finished iteration for k=65: Mean Accuracy = 0.8805, Mean Std Dev = 0.0305
#
# Iteration 1/10 for k=70: Accuracy = 0.8404, Std Dev = 0.0745, Undersample Seed = 40
# Iteration 2/10 for k=70: Accuracy = 0.8719, Std Dev = 0.0435, Undersample Seed = 41
# Iteration 3/10 for k=70: Accuracy = 0.8830, Std Dev = 0.0841, Undersample Seed = 69
# Iteration 4/10 for k=70: Accuracy = 0.8830, Std Dev = 0.0514, Undersample Seed = 83
# Iteration 5/10 for k=70: Accuracy = 0.9462, Std Dev = 0.0484, Undersample Seed = 82
# Iteration 6/10 for k=70: Accuracy = 0.8515, Std Dev = 0.0767, Undersample Seed = 34
# Iteration 7/10 for k=70: Accuracy = 0.8830, Std Dev = 0.0612, Undersample Seed = 59
# Iteration 8/10 for k=70: Accuracy = 0.8713, Std Dev = 0.0814, Undersample Seed = 5
# Iteration 9/10 for k=70: Accuracy = 0.8614, Std Dev = 0.0981, Undersample Seed = 2
# Iteration 10/10 for k=70: Accuracy = 0.9041, Std Dev = 0.0519, Undersample Seed = 65
# Finished iteration for k=70: Mean Accuracy = 0.8796, Mean Std Dev = 0.0280
#
# Iteration 1/10 for k=75: Accuracy = 0.8620, Std Dev = 0.1081, Undersample Seed = 80
# Iteration 2/10 for k=75: Accuracy = 0.9357, Std Dev = 0.0407, Undersample Seed = 63
# Iteration 3/10 for k=75: Accuracy = 0.8509, Std Dev = 0.0400, Undersample Seed = 58
# Iteration 4/10 for k=75: Accuracy = 0.8620, Std Dev = 0.0914, Undersample Seed = 27
# Iteration 5/10 for k=75: Accuracy = 0.8509, Std Dev = 0.0845, Undersample Seed = 19
# Iteration 6/10 for k=75: Accuracy = 0.8819, Std Dev = 0.0869, Undersample Seed = 97
# Iteration 7/10 for k=75: Accuracy = 0.9041, Std Dev = 0.0616, Undersample Seed = 39
# Iteration 8/10 for k=75: Accuracy = 0.9152, Std Dev = 0.0533, Undersample Seed = 17
# Iteration 9/10 for k=75: Accuracy = 0.9345, Std Dev = 0.0818, Undersample Seed = 95
# Iteration 10/10 for k=75: Accuracy = 0.8942, Std Dev = 0.0571, Undersample Seed = 4
# Finished iteration for k=75: Mean Accuracy = 0.8891, Mean Std Dev = 0.0310
#
# Iteration 1/10 for k=80: Accuracy = 0.9041, Std Dev = 0.0218, Undersample Seed = 6
# Iteration 2/10 for k=80: Accuracy = 0.9468, Std Dev = 0.0333, Undersample Seed = 20
# Iteration 3/10 for k=80: Accuracy = 0.8626, Std Dev = 0.0528, Undersample Seed = 30
# Iteration 4/10 for k=80: Accuracy = 0.8094, Std Dev = 0.0775, Undersample Seed = 61
# Iteration 5/10 for k=80: Accuracy = 0.9146, Std Dev = 0.0268, Undersample Seed = 33
# Iteration 6/10 for k=80: Accuracy = 0.8392, Std Dev = 0.0787, Undersample Seed = 46
# Iteration 7/10 for k=80: Accuracy = 0.9363, Std Dev = 0.0208, Undersample Seed = 99
# Iteration 8/10 for k=80: Accuracy = 0.9146, Std Dev = 0.0542, Undersample Seed = 79
# Iteration 9/10 for k=80: Accuracy = 0.8292, Std Dev = 0.0421, Undersample Seed = 77
# Iteration 10/10 for k=80: Accuracy = 0.9357, Std Dev = 0.0622, Undersample Seed = 35
# Finished iteration for k=80: Mean Accuracy = 0.8892, Mean Std Dev = 0.0473
#
# Iteration 1/10 for k=85: Accuracy = 0.8725, Std Dev = 0.0533, Undersample Seed = 90
# Iteration 2/10 for k=85: Accuracy = 0.9041, Std Dev = 0.0398, Undersample Seed = 48
# Iteration 3/10 for k=85: Accuracy = 0.9135, Std Dev = 0.0756, Undersample Seed = 26
# Iteration 4/10 for k=85: Accuracy = 0.8415, Std Dev = 0.0935, Undersample Seed = 60
# Iteration 5/10 for k=85: Accuracy = 0.8491, Std Dev = 0.0912, Undersample Seed = 46
# Iteration 6/10 for k=85: Accuracy = 0.8620, Std Dev = 0.0530, Undersample Seed = 58
# Iteration 7/10 for k=85: Accuracy = 0.8942, Std Dev = 0.0877, Undersample Seed = 80
# Iteration 8/10 for k=85: Accuracy = 0.8719, Std Dev = 0.0435, Undersample Seed = 23
# Iteration 9/10 for k=85: Accuracy = 0.8830, Std Dev = 0.0391, Undersample Seed = 11
# Iteration 10/10 for k=85: Accuracy = 0.9573, Std Dev = 0.0396, Undersample Seed = 82
# Finished iteration for k=85: Mean Accuracy = 0.8849, Mean Std Dev = 0.0324

# %%
import matplotlib.pyplot as plt

line_color = 'black'
box_color = 'lightgray'
highlight_color = 'red'  # Color for the point with the highest accuracy
fontweight = 'bold'

plt.figure(figsize=(15, 9))
plt.plot(feature_numbers, mean_accuracies, 'o-', label='Accuracy', markersize=15, color=line_color, linewidth=5)  # Make the plot line thicker

max_accuracy_index = mean_accuracies.index(max(mean_accuracies))
max_accuracy_scaling = 5  # Scaling factor for showing the highest accuracy value

for i in range(len(feature_numbers)):
    color = highlight_color if i == max_accuracy_index else 'black'
    fontsize = 20 if i == max_accuracy_index else 10

    # Alternate between placing values above and below the points
    vertical_alignment = 'bottom' if i % 2 == 0 else 'top'

    # Check if the point is the one with the highest accuracy and meets the scaling condition
    if i == max_accuracy_index:
        plt.scatter(
            feature_numbers[max_accuracy_index],
            mean_accuracies[max_accuracy_index],
            color=highlight_color,  # Change entire color of the highest point to red
            s=200,  # Increase marker size for the highest accuracy point
            label=f'Highest Accuracy: {mean_accuracies[i]:.4f} ± {std_accuracies[i]:.4f}',
        )

# Increase the font size of x-axis and y-axis labels
plt.xlabel('Number of Features', fontweight='bold', fontsize=20)
plt.ylabel('Mean Accuracy', fontweight='bold', fontsize=20)

# Adjusting tick labels
plt.xticks(fontweight='bold', fontsize=20)
plt.yticks(fontweight='bold', fontsize=20)

# Display the highest accuracy and variance as a label below the x-axis label
plt.text(
    0.5, -0.15,
    f'Highest Accuracy: {mean_accuracies[max_accuracy_index]:.4f} ± {std_accuracies[max_accuracy_index]:.4f}',
    transform=plt.gca().transAxes,
    fontsize=18,  # Increase font size
    fontweight='bold',  # Make font bold
    ha='center'
)

plt.grid(True)
plt.show()

# %%
# Specify colors for the line plot and text boxes
line_color = 'blue'
box_color = 'lightgray'
highlight_color = 'red'  # Color for the point with the highest accuracy

plt.figure(figsize=(15, 9))
plt.plot(feature_numbers, mean_accuracies, 'o-', label='Accuracy', markersize=8, color=line_color)

# Find the index of the point with the highest accuracy
max_accuracy_index = mean_accuracies.index(max(mean_accuracies))

# Annotate each point with its accuracy and std inside a colored box
for i in range(len(feature_numbers)):
    box_properties = dict(boxstyle='round', facecolor=box_color, alpha=0.7)
    
    # Use highlight_color for the point with the highest accuracy
    color = highlight_color if i == max_accuracy_index else 'black'
    fontsize = 11 if i == max_accuracy_index else 10
    
    plt.text(
        feature_numbers[i],
        mean_accuracies[i],
        f'{mean_accuracies[i]:.4f}\n±{std_accuracies[i]:.4f}',
        fontsize=fontsize,
        ha='right',
        va='bottom',
        bbox=box_properties,
        color=color  # Text color
    )

plt.title('Mean Accuracy with Std Dev for each Feature Number (Chi-squared + Undersampling + SVM with 5-Fold Cross-Validation)')
plt.xlabel('Number of Features')
plt.ylabel('Mean Accuracy')
plt.legend()
plt.grid(True)
plt.show()
