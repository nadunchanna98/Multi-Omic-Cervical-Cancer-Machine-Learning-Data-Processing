# %%
import pandas as pd

# %%
file_path = "G:/academic/sem 7/Research - Multi-omic data in the cervical cancer studies/notebooks/New folder/Multi/multi.csv"
df = pd.read_csv(file_path)

# %%
# file_path = "G:/academic/sem 7/Research - Multi-omic data in the cervical cancer studies/notebooks/New folder/Multi/90_Multi.csv"
# df = pd.read_csv(file_path)

# %%
df
# Out:
#             SampleID  histological_type    ANKS4B      MIA2    LRRC31  \
# 0    TCGA-C5-A3HF-01                  1  0.867005  0.866286  0.994298
# 1    TCGA-Q1-A6DT-01                  0  0.000000  0.000000  0.000000
# 2    TCGA-EA-A3HQ-01                  0  0.000000  0.000000  0.000000
# 3    TCGA-VS-A8Q8-01                  0  0.060650  0.000000  0.000000
# 4    TCGA-JX-A3Q8-01                  1  0.038103  0.000000  0.000000
# ..               ...                ...       ...       ...       ...
# 295  TCGA-LP-A4AV-01                  0  0.000000  0.179736  0.000000
# 296  TCGA-EK-A3GM-01                  1  0.916747  0.734386  0.972516
# 297  TCGA-ZX-AA5X-01                  0  0.123415  0.000000  0.000000
# 298  TCGA-C5-A1MJ-01                  1  0.849097  0.805456  1.000000
# 299  TCGA-Q1-A6DV-01                  1  0.000000  0.000000  0.078467
#
#         CLRN3     ARMC3    MS4A8B    TM4SF4     FOXA2  ...  cg01814098  \
# 0    0.822562  0.442743  0.781112  0.598209  0.661257  ...      0.0199
# 1    0.000000  0.057782  0.000000  0.000000  0.000000  ...      0.0189
# 2    0.066419  0.488123  0.000000  0.000000  0.064254  ...      0.6155
# 3    0.000000  0.000000  0.000000  0.000000  0.219233  ...      0.0173
# 4    0.000000  0.167467  0.000000  0.055477  0.330997  ...      0.0183
# ..        ...       ...       ...       ...       ...  ...         ...
# 295  0.079299  0.000000  0.000000  0.242032  0.000000  ...      0.0177
# 296  0.926244  0.208172  0.742700  0.232274  0.869284  ...      0.0174
# 297  0.156814  0.079515  0.000000  0.000000  0.000000  ...      0.1640
# 298  0.741361  0.116997  0.348013  0.474337  0.785770  ...      0.0206
# 299  0.331688  1.000000  0.797180  0.099410  0.537419  ...      0.0164
#
#      cg08273666  cg26082557  cg05963618  cg17900854  cg14114673  cg09644722  \
# 0        0.0163      0.0142      0.0168      0.0216      0.0170      0.0170
# 1        0.5729      0.6290      0.0140      0.4811      0.5718      0.4422
# 2        0.2773      0.0180      0.7356      0.7176      0.0134      0.0170
# 3        0.0124      0.0698      0.0174      0.0218      0.1811      0.0175
# 4        0.0212      0.0151      0.5565      0.8325      0.0162      0.0192
# ..          ...         ...         ...         ...         ...         ...
# 295      0.0172      0.0158      0.0230      0.5472      0.0194      0.0188
# 296      0.0160      0.0142      0.0204      0.0183      0.0144      0.0134
# 297      0.1868      0.2199      0.4693      0.4302      0.0183      0.1210
# 298      0.0211      0.0177      0.0995      0.0694      0.1926      0.0158
# 299      0.0152      0.0149      0.0149      0.0253      0.0159      0.0145
#
#      cg08967106  cg26058289  cg19908577
# 0        0.0133      0.9598      0.0190
# 1        0.5937      0.6056      0.4673
# 2        0.0267      0.5138      0.0278
# 3        0.0178      0.5506      0.0142
# 4        0.0133      0.9887      0.0143
# ..          ...         ...         ...
# 295      0.0149      0.5894      0.0162
# 296      0.0116      0.9921      0.0171
# 297      0.0279      0.6303      0.0182
# 298      0.2802      0.9629      0.0315
# 299      0.0132      0.9913      0.0107
#
# [300 rows x 92 columns]

# %%
column_values = df['histological_type']
total_count = column_values.count()
value_counts = column_values.value_counts()
value_counts
# Out:
# histological_type
# 0    253
# 1     47
# Name: count, dtype: int64

# %%
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from sklearn.feature_selection import chi2
from sklearn.model_selection import cross_val_score
from sklearn.utils import resample
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Assuming df is your DataFrame

xgb_classifier = XGBClassifier(objective='binary:logistic', random_state=42)  # Use binary:logistic for binary classification
K = np.arange(start=5, stop=90, step=5)
iterations = 10  # Number of iterations
feature_numbers = []
mean_accuracies = []
std_accuracies = []

# Loop through the selected features
for idx, k in enumerate(K):
    accuracies_iter = []

    for iteration in range(iterations):
        # Feature selection using Chi-squared
        X = df.iloc[:, 2:92]
        y = df["histological_type"]

        # Calculate chi-squared scores for each feature
        chi2_scores, _ = chi2(X, y)

        # Select the top k features based on chi-squared scores
        selected_features_idx = np.argsort(chi2_scores)[-k:]
        selected_features = X.columns[selected_features_idx]

        df_selected = df[['SampleID', 'histological_type'] + list(selected_features)].copy()

        # Undersample the dataset with a random seed between 0 and 100 for each iteration
        undersample_seed = np.random.randint(101)  # Generate a random seed between 0 and 100
        cervical_squamous_df = df_selected[df_selected['histological_type'] == 0]
        if len(cervical_squamous_df) > 47:
            cervical_squamous_df = resample(cervical_squamous_df, n_samples=47, random_state=undersample_seed)
        adeno_df = df_selected[df_selected['histological_type'] == 1]
        df2 = pd.concat([cervical_squamous_df, adeno_df])

        # Split the data into features (X) and target (y)
        X_selected = df2.iloc[:, 2:]
        y_selected = df2["histological_type"]

        # Perform 5-fold cross-validation
        scores = cross_val_score(xgb_classifier, X_selected, y_selected, cv=5, scoring='accuracy')

        # Calculate average accuracy and standard deviation across folds
        accuracy = np.mean(scores)
        std_accuracy = np.std(scores)
        accuracies_iter.append(accuracy)

        # Print update after each iteration
        print(f"Iteration {iteration + 1}/{iterations} for k={k}: Accuracy = {accuracy:.4f}, Std Dev = {std_accuracy:.4f}, Undersample Seed = {undersample_seed}")

    # Store the feature number and its mean accuracy and standard deviation across iterations
    feature_numbers.append(k)
    mean_accuracies.append(np.mean(accuracies_iter))
    std_accuracies.append(np.std(accuracies_iter))

    # Print update after each feature number
    print(f"Finished iteration for k={k}: Mean Accuracy = {mean_accuracies[-1]:.4f}, Mean Std Dev = {std_accuracies[-1]:.4f}\n")

# Increase the width and height of the graph
plt.figure(figsize=(10, 6))

# Plotting the feature numbers, mean accuracies, and standard deviations
plt.errorbar(feature_numbers, mean_accuracies, yerr=std_accuracies, fmt='o-', label='Accuracy', capsize=5, markersize=8)

# Annotate each point with its accuracy and std inside a colored box
for i in range(len(feature_numbers)):
    box_properties = dict(boxstyle='round', facecolor='lightgray', alpha=0.7)
    plt.text(
        feature_numbers[i],
        mean_accuracies[i],
        f'{mean_accuracies[i]:.4f}\n±{std_accuracies[i]:.4f}',
        fontsize=8,
        ha='right',
        va='bottom',
        bbox=box_properties
    )

plt.title('Mean Accuracy with Std Dev for each Feature Number (Chi-squared + Undersampling + XGBoost with 5-Fold Cross-Validation)')
plt.xlabel('Number of Features')
plt.ylabel('Mean Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Iteration 1/10 for k=5: Accuracy = 0.8304, Std Dev = 0.0602, Undersample Seed = 17
# Iteration 2/10 for k=5: Accuracy = 0.7339, Std Dev = 0.1202, Undersample Seed = 53
# Iteration 3/10 for k=5: Accuracy = 0.7895, Std Dev = 0.1104, Undersample Seed = 51
# Iteration 4/10 for k=5: Accuracy = 0.7655, Std Dev = 0.0930, Undersample Seed = 13
# Iteration 5/10 for k=5: Accuracy = 0.8409, Std Dev = 0.0874, Undersample Seed = 97
# Iteration 6/10 for k=5: Accuracy = 0.7895, Std Dev = 0.1104, Undersample Seed = 51
# Iteration 7/10 for k=5: Accuracy = 0.8316, Std Dev = 0.0842, Undersample Seed = 80
# Iteration 8/10 for k=5: Accuracy = 0.8404, Std Dev = 0.0578, Undersample Seed = 23
# Iteration 9/10 for k=5: Accuracy = 0.7468, Std Dev = 0.1339, Undersample Seed = 40
# Iteration 10/10 for k=5: Accuracy = 0.8205, Std Dev = 0.1175, Undersample Seed = 28
# Finished iteration for k=5: Mean Accuracy = 0.7989, Mean Std Dev = 0.0377
#
# Iteration 1/10 for k=10: Accuracy = 0.8404, Std Dev = 0.0745, Undersample Seed = 81
# Iteration 2/10 for k=10: Accuracy = 0.8509, Std Dev = 0.0702, Undersample Seed = 29
# Iteration 3/10 for k=10: Accuracy = 0.9152, Std Dev = 0.0251, Undersample Seed = 58
# Iteration 4/10 for k=10: Accuracy = 0.9053, Std Dev = 0.0774, Undersample Seed = 48
# Iteration 5/10 for k=10: Accuracy = 0.8725, Std Dev = 0.0249, Undersample Seed = 91
# Iteration 6/10 for k=10: Accuracy = 0.8836, Std Dev = 0.0838, Undersample Seed = 46
# Iteration 7/10 for k=10: Accuracy = 0.8836, Std Dev = 0.0838, Undersample Seed = 46
# Iteration 8/10 for k=10: Accuracy = 0.9047, Std Dev = 0.0388, Undersample Seed = 19
# Iteration 9/10 for k=10: Accuracy = 0.8620, Std Dev = 0.0626, Undersample Seed = 40
# Iteration 10/10 for k=10: Accuracy = 0.9041, Std Dev = 0.0218, Undersample Seed = 60
# Finished iteration for k=10: Mean Accuracy = 0.8822, Mean Std Dev = 0.0242
#
# Iteration 1/10 for k=15: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 44
# Iteration 2/10 for k=15: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 46
# Iteration 3/10 for k=15: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 1
# Iteration 4/10 for k=15: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 81
# Iteration 5/10 for k=15: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 21
# Iteration 6/10 for k=15: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 48
# Iteration 7/10 for k=15: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 46
# Iteration 8/10 for k=15: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 13
# Iteration 9/10 for k=15: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 15
# Iteration 10/10 for k=15: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 19
# Finished iteration for k=15: Mean Accuracy = 1.0000, Mean Std Dev = 0.0000
#
# Iteration 1/10 for k=20: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 52
# Iteration 2/10 for k=20: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 68
# Iteration 3/10 for k=20: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 98
# Iteration 4/10 for k=20: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 36
# Iteration 5/10 for k=20: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 58
# Iteration 6/10 for k=20: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 53
# Iteration 7/10 for k=20: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 19
# Iteration 8/10 for k=20: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 12
# Iteration 9/10 for k=20: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 56
# Iteration 10/10 for k=20: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 0
# Finished iteration for k=20: Mean Accuracy = 1.0000, Mean Std Dev = 0.0000
#
# Iteration 1/10 for k=25: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 76
# Iteration 2/10 for k=25: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 24
# Iteration 3/10 for k=25: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 31
# Iteration 4/10 for k=25: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 89
# Iteration 5/10 for k=25: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 55
# Iteration 6/10 for k=25: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 67
# Iteration 7/10 for k=25: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 59
# Iteration 8/10 for k=25: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 6
# Iteration 9/10 for k=25: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 70
# Iteration 10/10 for k=25: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 52
# Finished iteration for k=25: Mean Accuracy = 1.0000, Mean Std Dev = 0.0000
#
# Iteration 1/10 for k=30: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 61
# Iteration 2/10 for k=30: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 42
# Iteration 3/10 for k=30: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 94
# Iteration 4/10 for k=30: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 94
# Iteration 5/10 for k=30: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 26
# Iteration 6/10 for k=30: Accuracy = 0.9684, Std Dev = 0.0632, Undersample Seed = 99
# Iteration 7/10 for k=30: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 20
# Iteration 8/10 for k=30: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 74
# Iteration 9/10 for k=30: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 85
# Iteration 10/10 for k=30: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 58
# Finished iteration for k=30: Mean Accuracy = 0.9968, Mean Std Dev = 0.0095
#
# Iteration 1/10 for k=35: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 10
# Iteration 2/10 for k=35: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 42
# Iteration 3/10 for k=35: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 10
# Iteration 4/10 for k=35: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 52
# Iteration 5/10 for k=35: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 0
# Iteration 6/10 for k=35: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 86
# Iteration 7/10 for k=35: Accuracy = 0.9684, Std Dev = 0.0632, Undersample Seed = 99
# Iteration 8/10 for k=35: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 41
# Iteration 9/10 for k=35: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 90
# Iteration 10/10 for k=35: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 100
# Finished iteration for k=35: Mean Accuracy = 0.9968, Mean Std Dev = 0.0095
#
# Iteration 1/10 for k=40: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 4
# Iteration 2/10 for k=40: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 12
# Iteration 3/10 for k=40: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 1
# Iteration 4/10 for k=40: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 74
# Iteration 5/10 for k=40: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 18
# Iteration 6/10 for k=40: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 20
# Iteration 7/10 for k=40: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 71
# Iteration 8/10 for k=40: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 61
# Iteration 9/10 for k=40: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 45
# Iteration 10/10 for k=40: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 32
# Finished iteration for k=40: Mean Accuracy = 1.0000, Mean Std Dev = 0.0000
#
# Iteration 1/10 for k=45: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 6
# Iteration 2/10 for k=45: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 34
# Iteration 3/10 for k=45: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 90
# Iteration 4/10 for k=45: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 10
# Iteration 5/10 for k=45: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 8
# Iteration 6/10 for k=45: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 16
# Iteration 7/10 for k=45: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 24
# Iteration 8/10 for k=45: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 86
# Iteration 9/10 for k=45: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 62
# Iteration 10/10 for k=45: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 70
# Finished iteration for k=45: Mean Accuracy = 1.0000, Mean Std Dev = 0.0000
#
# Iteration 1/10 for k=50: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 66
# Iteration 2/10 for k=50: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 98
# Iteration 3/10 for k=50: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 27
# Iteration 4/10 for k=50: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 68
# Iteration 5/10 for k=50: Accuracy = 0.9684, Std Dev = 0.0632, Undersample Seed = 11
# Iteration 6/10 for k=50: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 66
# Iteration 7/10 for k=50: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 1
# Iteration 8/10 for k=50: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 21
# Iteration 9/10 for k=50: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 98
# Iteration 10/10 for k=50: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 24
# Finished iteration for k=50: Mean Accuracy = 0.9968, Mean Std Dev = 0.0095
#
# Iteration 1/10 for k=55: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 54
# Iteration 2/10 for k=55: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 44
# Iteration 3/10 for k=55: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 85
# Iteration 4/10 for k=55: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 81
# Iteration 5/10 for k=55: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 82
# Iteration 6/10 for k=55: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 77
# Iteration 7/10 for k=55: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 40
# Iteration 8/10 for k=55: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 86
# Iteration 9/10 for k=55: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 86
# Iteration 10/10 for k=55: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 27
# Finished iteration for k=55: Mean Accuracy = 1.0000, Mean Std Dev = 0.0000
#
# Iteration 1/10 for k=60: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 55
# Iteration 2/10 for k=60: Accuracy = 0.9684, Std Dev = 0.0632, Undersample Seed = 13
# Iteration 3/10 for k=60: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 44
# Iteration 4/10 for k=60: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 60
# Iteration 5/10 for k=60: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 24
# Iteration 6/10 for k=60: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 93
# Iteration 7/10 for k=60: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 61
# Iteration 8/10 for k=60: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 42
# Iteration 9/10 for k=60: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 51
# Iteration 10/10 for k=60: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 96
# Finished iteration for k=60: Mean Accuracy = 0.9968, Mean Std Dev = 0.0095
#
# Iteration 1/10 for k=65: Accuracy = 0.9778, Std Dev = 0.0444, Undersample Seed = 23
# Iteration 2/10 for k=65: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 8
# Iteration 3/10 for k=65: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 72
# Iteration 4/10 for k=65: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 30
# Iteration 5/10 for k=65: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 78
# Iteration 6/10 for k=65: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 18
# Iteration 7/10 for k=65: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 69
# Iteration 8/10 for k=65: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 73
# Iteration 9/10 for k=65: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 79
# Iteration 10/10 for k=65: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 29
# Finished iteration for k=65: Mean Accuracy = 0.9978, Mean Std Dev = 0.0067
#
# Iteration 1/10 for k=70: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 16
# Iteration 2/10 for k=70: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 17
# Iteration 3/10 for k=70: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 78
# Iteration 4/10 for k=70: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 14
# Iteration 5/10 for k=70: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 67
# Iteration 6/10 for k=70: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 34
# Iteration 7/10 for k=70: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 38
# Iteration 8/10 for k=70: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 3
# Iteration 9/10 for k=70: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 91
# Iteration 10/10 for k=70: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 6
# Finished iteration for k=70: Mean Accuracy = 1.0000, Mean Std Dev = 0.0000
#
# Iteration 1/10 for k=75: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 25
# Iteration 2/10 for k=75: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 44
# Iteration 3/10 for k=75: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 70
# Iteration 4/10 for k=75: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 49
# Iteration 5/10 for k=75: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 21
# Iteration 6/10 for k=75: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 25
# Iteration 7/10 for k=75: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 89
# Iteration 8/10 for k=75: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 94
# Iteration 9/10 for k=75: Accuracy = 0.9684, Std Dev = 0.0632, Undersample Seed = 11
# Iteration 10/10 for k=75: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 76
# Finished iteration for k=75: Mean Accuracy = 0.9968, Mean Std Dev = 0.0095
#
# Iteration 1/10 for k=80: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 22
# Iteration 2/10 for k=80: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 73
# Iteration 3/10 for k=80: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 40
# Iteration 4/10 for k=80: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 70
# Iteration 5/10 for k=80: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 67
# Iteration 6/10 for k=80: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 67
# Iteration 7/10 for k=80: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 53
# Iteration 8/10 for k=80: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 44
# Iteration 9/10 for k=80: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 32
# Iteration 10/10 for k=80: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 0
# Finished iteration for k=80: Mean Accuracy = 1.0000, Mean Std Dev = 0.0000
#
# Iteration 1/10 for k=85: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 37
# Iteration 2/10 for k=85: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 55
# Iteration 3/10 for k=85: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 24
# Iteration 4/10 for k=85: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 84
# Iteration 5/10 for k=85: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 18
# Iteration 6/10 for k=85: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 98
# Iteration 7/10 for k=85: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 61
# Iteration 8/10 for k=85: Accuracy = 0.9684, Std Dev = 0.0632, Undersample Seed = 13
# Iteration 9/10 for k=85: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 17
# Iteration 10/10 for k=85: Accuracy = 1.0000, Std Dev = 0.0000, Undersample Seed = 84
# Finished iteration for k=85: Mean Accuracy = 0.9968, Mean Std Dev = 0.0095

# %%
# Specify colors for the line plot and text boxes
line_color = 'blue'
box_color = 'lightgray'
highlight_color = 'red'  # Color for the point with the highest accuracy

plt.figure(figsize=(15, 9))
plt.plot(feature_numbers, mean_accuracies, 'o-', label='Accuracy', markersize=8, color=line_color)

# Find the index of the point with the highest accuracy
max_accuracy_index = mean_accuracies.index(max(mean_accuracies))

# Annotate each point with its accuracy and std inside a colored box
for i in range(len(feature_numbers)):
    box_properties = dict(boxstyle='round', facecolor=box_color, alpha=0.7)
    
    # Use highlight_color for the point with the highest accuracy
    color = highlight_color if i == max_accuracy_index else 'black'
    fontsize = 11 if i == max_accuracy_index else 10
    
    plt.text(
        feature_numbers[i],
        mean_accuracies[i],
        f'{mean_accuracies[i]:.4f}\n±{std_accuracies[i]:.4f}',
        fontsize=fontsize,
        ha='right',
        va='bottom',
        bbox=box_properties,
        color=color  # Text color
    )

plt.title('Mean Accuracy with Std Dev for each Feature Number (Chi-squared + Undersampling + SVM with 5-Fold Cross-Validation)')
plt.xlabel('Number of Features')
plt.ylabel('Mean Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

line_color = 'black'
box_color = 'lightgray'
highlight_color = 'red'  # Color for the point with the highest accuracy
fontweight = 'bold'

plt.figure(figsize=(15, 9))
plt.plot(feature_numbers, mean_accuracies, 'o-', label='Accuracy', markersize=15, color=line_color, linewidth=5)  # Make the plot line thicker

max_accuracy_index = mean_accuracies.index(max(mean_accuracies))
max_accuracy_scaling = 5  # Scaling factor for showing the highest accuracy value

for i in range(len(feature_numbers)):
    color = highlight_color if i == max_accuracy_index else 'black'
    fontsize = 20 if i == max_accuracy_index else 10

    # Alternate between placing values above and below the points
    vertical_alignment = 'bottom' if i % 2 == 0 else 'top'

    # Check if the point is the one with the highest accuracy and meets the scaling condition
    if i == max_accuracy_index:
        plt.scatter(
            feature_numbers[max_accuracy_index],
            mean_accuracies[max_accuracy_index],
            color=highlight_color,  # Change entire color of the highest point to red
            s=200,  # Increase marker size for the highest accuracy point
            label=f'Highest Accuracy: {mean_accuracies[i]:.4f} ± {std_accuracies[i]:.4f}',
        )

# Increase the font size of x-axis and y-axis labels
plt.xlabel('Number of Features', fontweight='bold', fontsize=20)
plt.ylabel('Mean Accuracy', fontweight='bold', fontsize=20)

# Adjusting tick labels
plt.xticks(fontweight='bold', fontsize=20)
plt.yticks(fontweight='bold', fontsize=20)

# Display the highest accuracy and variance as a label below the x-axis label
plt.text(
    0.5, -0.15,
    f'Highest Accuracy: {mean_accuracies[max_accuracy_index]:.4f} ± {std_accuracies[max_accuracy_index]:.4f}',
    transform=plt.gca().transAxes,
    fontsize=18,  # Increase font size
    fontweight='bold',  # Make font bold
    ha='center'
)

plt.grid(True)
plt.show()
